# %% [markdown]
# # position_dodge()
#
# Build a plot with `position_dodge()`.

# %%
import pandas as pd

from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="SNElvh"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://dl.bintray.com/jetbrains/lets-plot/lets-plot-1.5.6.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("SNElvh").appendChild(div);
#                     };
#                     var e = document.getElementById("SNElvh");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
df = pd.read_csv('https://raw.githubusercontent.com/HIL-HK/lets-plot-examples/master/data/mpg.csv')

# %%
ggplot(df, aes(x='fl', fill='drv')) + \
    geom_bar(position='dodge')
# Out:
#    <div id="KUDprY"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'data':{
# },
# 'mapping':{
# 'x':"fl",
# 'fill':"drv"
# },
# 'data_meta':{
# },
# 'kind':"plot",
# 'scales':[],
# 'layers':[{
# 'geom':"bar",
# 'mapping':{
# },
# 'position':"dodge",
# 'data_meta':{
# },
# 'data':{
# '..count..':[25.0,76.0,1.0,1.0,3.0,20.0,75.0,6.0,2.0,17.0,1.0,7.0],
# 'fl':["p","r","e","c","d","p","r","e","d","r","e","p"],
# 'drv':["f","f","f","f","f","4","4","4","4","r","r","r"]
# }
# }]
# };
#            var plotContainer = document.getElementById("KUDprY");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
ggplot(df, aes(x='fl', fill='drv')) + \
    geom_bar(position=position_dodge())
# Out:
#    <div id="x62F9M"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# 'data':{
# },
# 'mapping':{
# 'x':"fl",
# 'fill':"drv"
# },
# 'data_meta':{
# },
# 'kind':"plot",
# 'scales':[],
# 'layers':[{
# 'geom':"bar",
# 'mapping':{
# },
# 'position':{
# 'name':"dodge"
# },
# 'data_meta':{
# },
# 'data':{
# '..count..':[25.0,76.0,1.0,1.0,3.0,20.0,75.0,6.0,2.0,17.0,1.0,7.0],
# 'fl':["p","r","e","c","d","p","r","e","d","r","e","p"],
# 'drv':["f","f","f","f","f","4","4","4","4","r","r","r"]
# }
# }]
# };
#            var plotContainer = document.getElementById("x62F9M");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
