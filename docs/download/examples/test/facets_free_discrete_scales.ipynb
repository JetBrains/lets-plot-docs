# %%
import pandas as pd
from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#         <div id="F3WyhS"></div>
#         <script type="text/javascript" data-lets-plot-script="library">
#             if(!window.letsPlotCallQueue) {
#                 window.letsPlotCallQueue = [];
#             };
#             window.letsPlotCall = function(f) {
#                 window.letsPlotCallQueue.push(f);
#             };
#             (function() {
#                 var script = document.createElement("script");
#                 script.type = "text/javascript";
#                 script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.9.0/js-package/distr/lets-plot.min.js";
#                 script.onload = function() {
#                     window.letsPlotCall = function(f) {f();};
#                     window.letsPlotCallQueue.forEach(function(f) {f();});
#                     window.letsPlotCallQueue = [];
#
#                 };
#                 script.onerror = function(event) {
#                     window.letsPlotCall = function(f) {};    // noop
#                     window.letsPlotCallQueue = [];
#                     var div = document.createElement("div");
#                     div.style.color = 'darkred';
#                     div.textContent = 'Error loading Lets-Plot JS';
#                     document.getElementById("F3WyhS").appendChild(div);
#                 };
#                 var e = document.getElementById("F3WyhS");
#                 e.appendChild(script);
#             })()
#         </script>

# %%
plot_data = pd.DataFrame.from_records([
    ("pet", "cat", 5, "carnivore"),
    ("pet", "dog", 10, "carnivore"),
    ("pet", "rabbit", 2, "herbivore"),
    ("pet", "hamster", 1, "herbivore"),

    ("farm_animal", "cow", 500, "herbivore"),
    ("farm_animal", "pig", 100, "carnivore"),
    ("farm_animal", "horse", 700, "herbivore"),
])
plot_data.columns = ("animal_type", "animal", "weight", "diet")

# %%
plot = (
    ggplot(plot_data, aes(x="animal", y="weight"))
    + geom_bar(stat="identity")
    + theme_bw()
    + theme(
        panel_grid_minor=element_blank()
    )
)
plot
# Out:
#    <div id="PF4UF5" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("PF4UF5");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### Two facets, grid, free scales

# %%
plot + facet_grid(x = "animal_type", scales="free")
# Out:
#    <div id="fOmzz9" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("fOmzz9");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "x":"animal_type",
# "scales":"free",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"2"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### Two facets, wrap, free scales

# %%
plot + facet_wrap(facets="animal_type", ncol=2, scales="free")
# Out:
#    <div id="U5eR9M" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("U5eR9M");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":"animal_type",
# "ncol":2.0,
# "scales":"free",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"3"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### Four facets, grid, free x

# %%
plot + facet_grid(x="animal_type", y="diet", scales="free_x")
# Out:
#    <div id="iAWeRF" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("iAWeRF");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "x":"animal_type",
# "y":"diet",
# "scales":"free_x",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"4"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### Four facets, wrap, free x

# %%
plot + facet_wrap(facets=["animal_type", "diet"], ncol=2, scales="free_x")
# Out:
#    <div id="v8IK3G" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("v8IK3G");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":["animal_type","diet"],
# "ncol":2.0,
# "scales":"free_x",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"5"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### Four facets, grid, free y

# %%
plot + facet_grid(x="animal_type", y="diet", scales="free_y")
# Out:
#    <div id="DMrnhA" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("DMrnhA");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "x":"animal_type",
# "y":"diet",
# "scales":"free_y",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"6"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### Four facets, wrap, free y

# %%
plot + facet_wrap(facets=["animal_type", "diet"], ncol=2, scales="free_y")
# Out:
#    <div id="6KycFO" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("6KycFO");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":["animal_type","diet"],
# "ncol":2.0,
# "scales":"free_y",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"7"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### Four facets, grid, free scales

# %%
plot + facet_grid(x="animal_type", y="diet", scales="free")
# Out:
#    <div id="pcjfuc" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("pcjfuc");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "x":"animal_type",
# "y":"diet",
# "scales":"free",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"8"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### Four facets, wrap, free scales

# %%
plot + facet_wrap(facets=["animal_type", "diet"], ncol=2, scales="free")
# Out:
#    <div id="NsX7mr" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("NsX7mr");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":["animal_type","diet"],
# "ncol":2.0,
# "scales":"free",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"9"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ## Y-orientation

# %%
plot_y = (
    ggplot(plot_data, aes(x="weight", y="animal"))
    + geom_bar(stat="identity", orientation="y")
    + theme_bw()
    + theme(
        panel_grid_minor=element_blank()
    )
)
plot_y
# Out:
#    <div id="p0imra" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("p0imra");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"10"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### Two facets, grid, free scales

# %%
plot_y + facet_grid(y = "animal_type", scales="free_y")
# Out:
#    <div id="CmJ4LJ" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("CmJ4LJ");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "y":"animal_type",
# "scales":"free_y",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"11"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### Two facets, wrap, free scales

# %%
plot_y + facet_wrap(facets="animal_type", ncol=2, scales="free")
# Out:
#    <div id="1Jccar" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("1Jccar");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":"animal_type",
# "ncol":2.0,
# "scales":"free",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"12"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### Four facets, grid, free x

# %%
plot_y + facet_grid(y="animal_type", x="diet", scales="free_x")
# Out:
#    <div id="2fETTc" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("2fETTc");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "x":"diet",
# "y":"animal_type",
# "scales":"free_x",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"13"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### Four facets, wrap, free x

# %%
plot_y + facet_wrap(facets=["animal_type", "diet"], ncol=2, scales="free_x")
# Out:
#    <div id="ruNTvx" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("ruNTvx");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":["animal_type","diet"],
# "ncol":2.0,
# "scales":"free_x",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"14"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### Four facets, grid, free y

# %%
plot_y + facet_grid(y="animal_type", x="diet", scales="free_y")
# Out:
#    <div id="Xi1Iru" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("Xi1Iru");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "x":"diet",
# "y":"animal_type",
# "scales":"free_y",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"15"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### Four facets, wrap, free y

# %%
plot_y + facet_wrap(facets=["animal_type", "diet"], ncol=2, scales="free_y")
# Out:
#    <div id="kJklnx" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("kJklnx");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":["animal_type","diet"],
# "ncol":2.0,
# "scales":"free_y",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"16"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### Four facets, grid, free scales

# %%
plot_y + facet_grid(y="animal_type", x="diet", scales="free")
# Out:
#    <div id="OUAaXt" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("OUAaXt");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "x":"diet",
# "y":"animal_type",
# "scales":"free",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"17"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### Four facets, wrap, free scales

# %%
plot_y + facet_wrap(facets=["animal_type", "diet"], ncol=2, scales="free")
# Out:
#    <div id="6Es1sM" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("6Es1sM");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":["animal_type","diet"],
# "ncol":2.0,
# "scales":"free",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"18"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>
