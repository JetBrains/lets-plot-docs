# %%
import pandas as pd

from lets_plot.geo_data import *
from lets_plot import *

LetsPlot.setup_html()
# Out:
# The geodata is provided by © OpenStreetMap contributors and is made available here under the Open Database License (ODbL).
#             <div id="W3oFnW"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.0.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("W3oFnW").appendChild(div);
#                     };
#                     var e = document.getElementById("W3oFnW");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
cities = pd.read_csv("https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/cities.csv")
cities.head()
# Out:
#    Unnamed: 0         name               link  coutry_id   latitude  \
# 0           0      Algiers      /wiki/Algiers          1  36.776389
# 1           1       Annaba       /wiki/Annaba          1  36.900000
# 2           2        Batna        /wiki/Batna          1  35.550000
# 3           3       Bechar       /wiki/Bechar          1  31.633333
# 4           4  Constantine  /wiki/Constantine          1  36.365000
#
#    longitude                                               text
# 0   3.058611   — with nearly 3 million inhabitants, Algiers ...
# 1   7.766667   — a town with 200,000 inhabitants in the east...
# 2   6.166667                                                NaN
# 3  -2.200000   — small city in the Sahara, not far from the ...
# 4   6.614722   - Algeria's 3rd largest city with a canyon go...

# %%
czech_cities = cities.loc[cities['coutry_id'] == 144]
czech_cities
# Out:
#       Unnamed: 0              name                                   link  \
# 1044           0            Prague                           /wiki/Prague
# 1045           1              Brno                             /wiki/Brno
# 1046           2  České Budějovice  /wiki/%C4%8Cesk%C3%A9_Bud%C4%9Bjovice
# 1047           3     Český Krumlov          /wiki/%C4%8Cesk%C3%BD_Krumlov
# 1048           4      Karlovy Vary                     /wiki/Karlovy_Vary
# 1049           5        Kutná Hora                  /wiki/Kutn%C3%A1_Hora
# 1050           6           Olomouc                          /wiki/Olomouc
# 1051           7           Ostrava                          /wiki/Ostrava
# 1052           8            Pilsen                           /wiki/Pilsen
#
#       coutry_id   latitude  longitude  \
# 1044        144  50.083333  14.416667
# 1045        144  49.200000  16.616667
# 1046        144  48.974722  14.474722
# 1047        144  48.816667  14.316667
# 1048        144  50.233333  12.866667
# 1049        144  49.950000  15.266667
# 1050        144  49.600000  17.250000
# 1051        144  49.835556  18.292500
# 1052        144  49.747500  13.377500
#
#                                                    text
# 1044   () — the capital and largest city of the Czec...
# 1045   — the largest city in Moravia and its former ...
# 1046           – attractive large city in South Bohemia
# 1047   — beautiful old town in South Bohemia with th...
# 1048   () — historic (and biggest Czech) spa resort,...
# 1049   — historical town with famous Saint Barbara c...
# 1050   ( or ) — riverside university town with a tho...
# 1051   — a vibrant local subculture and long history...
# 1052   () — home of the original Pilsner Urquell bee...

# %%
country_gcoder = geocode_countries(['Czech'])
country_gcoder.get_geocodes()
# Out:
#       id country      found name                              centroid  \
# 0  51684   Czech  Czech Republic  [15.5282667270321, 49.8037022352219]
#
#                                             position  \
# 0  [12.0905895531178, 48.5518079996109, 18.859253...
#
#                                                limit
# 0  [12.0905895531178, 48.5518079996109, 18.859253...

# %%
# Automatic word wrap:
# the value string is limited by the number of characters in it,
# and description will be split into multiple lines.

(ggplot()
 + geom_livemap(location=[15.78,49.35], zoom=6)
 + geom_polygon(aes(fill='country'), 
                data=country_gcoder.inc_res(3).get_boundaries(), 
                alpha=.2)
 + geom_point(aes('longitude', 'latitude', color='name'),
                data=czech_cities,
                size=4, 
                tooltips=layer_tooltips()
                    .title('@name')
                    .line('Longitude|@longitude')
                    .line('Latitude|@latitude')
                    .line('Description|@text'))
 + theme(legend_position='none')
)
# Out:
#    <div id="EsT4mH"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "legend_position":"none"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[15.78,49.35]
# },
# "zoom":6.0,
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"Map: <a href=\"https://github.com/JetBrains/lets-plot\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"polygon",
# "data":{
# "country":["Czech"],
# "geometry":["{\"type\": \"MultiPolygon\", \"coordinates\": [[[[15.88623046875, 48.8357974624309], [15.88623046875, 48.8502581997215], [15.8642578125, 48.8502581997215], [15.8642578125, 48.8647147618028], [15.84228515625, 48.8647147618028], [15.84228515625, 48.8791671489602], [15.8203125, 48.8647147618028], [15.8203125, 48.8791671489602], [15.79833984375, 48.8791671489602], [15.7763671875, 48.8791671489602], [15.7763671875, 48.8647147618028], [15.75439453125, 48.8647147618028], [15.75439453125, 48.8502581997215], [15.732421875, 48.8502581997215], [15.71044921875, 48.8502581997215], [15.71044921875, 48.8647147618028], [15.6884765625, 48.8647147618028], [15.66650390625, 48.8647147618028], [15.66650390625, 48.8791671489602], [15.64453125, 48.8791671489602], [15.62255859375, 48.8791671489602], [15.62255859375, 48.8936153614802], [15.6005859375, 48.8936153614802], [15.57861328125, 48.8936153614802], [15.556640625, 48.8936153614802], [15.556640625, 48.9080593996501], [15.53466796875, 48.9080593996501], [15.5126953125, 48.9080593996501], [15.5126953125, 48.9224992637582], [15.5126953125, 48.936934954094], [15.49072265625, 48.936934954094], [15.46875, 48.9513664709477], [15.44677734375, 48.9513664709477], [15.4248046875, 48.9513664709477], [15.40283203125, 48.9513664709477], [15.40283203125, 48.9657938146106], [15.380859375, 48.9657938146106], [15.380859375, 48.980216985375], [15.35888671875, 48.980216985375], [15.3369140625, 48.980216985375], [15.31494140625, 48.980216985375], [15.29296875, 48.980216985375], [15.29296875, 48.9946359835341], [15.27099609375, 48.9946359835341], [15.27099609375, 48.980216985375], [15.27099609375, 48.9657938146106], [15.27099609375, 48.9513664709477], [15.2490234375, 48.9513664709477], [15.22705078125, 48.9513664709477], [15.22705078125, 48.9657938146106], [15.205078125, 48.9513664709477], [15.18310546875, 48.9513664709477], [15.1611328125, 48.9513664709477], [15.1611328125, 48.9657938146106], [15.1611328125, 48.980216985375], [15.1611328125, 48.9946359835341], [15.13916015625, 48.9946359835341], [15.1171875, 48.9946359835341], [15.09521484375, 48.9946359835341], [15.0732421875, 48.9946359835341], [15.0732421875, 49.009050809382], [15.05126953125, 49.009050809382], [15.029296875, 49.009050809382], [15.029296875, 49.0234614632141], [15.00732421875, 49.0234614632141], [15.00732421875, 49.009050809382], [15.00732421875, 48.9946359835341], [14.9853515625, 48.9946359835341], [14.9853515625, 48.980216985375], [14.9853515625, 48.9657938146106], [14.9853515625, 48.9513664709477], [14.9853515625, 48.936934954094], [14.9853515625, 48.9224992637582], [14.9853515625, 48.9080593996501], [14.9853515625, 48.8936153614802], [14.9853515625, 48.8791671489602], [14.96337890625, 48.8791671489602], [14.96337890625, 48.8647147618028], [14.96337890625, 48.8502581997215], [14.9853515625, 48.8502581997215], [14.9853515625, 48.8357974624309], [14.96337890625, 48.8357974624309], [14.96337890625, 48.8213325496466], [14.96337890625, 48.8068634610852], [14.96337890625, 48.7923901964641], [14.96337890625, 48.7779127555018], [14.9853515625, 48.7779127555018], [14.9853515625, 48.7634311379179], [14.96337890625, 48.7634311379179], [14.94140625, 48.7634311379179], [14.91943359375, 48.7634311379179], [14.8974609375, 48.7634311379179], [14.8974609375, 48.7779127555018], [14.87548828125, 48.7779127555018], [14.853515625, 48.7779127555018], [14.83154296875, 48.7779127555018], [14.8095703125, 48.7779127555018], [14.8095703125, 48.7634311379179], [14.8095703125, 48.7489453434329], [14.8095703125, 48.7344553717682], [14.78759765625, 48.7344553717682], [14.78759765625, 48.7199612226463], [14.765625, 48.7199612226463], [14.765625, 48.7054628957906], [14.74365234375, 48.7054628957906], [14.74365234375, 48.6909603909255], [14.7216796875, 48.6909603909255], [14.7216796875, 48.6764537077765], [14.7216796875, 48.6619428460701], [14.7216796875, 48.6474278055335], [14.7216796875, 48.6329085858953], [14.7216796875, 48.6183851868849], [14.7216796875, 48.603 ...
