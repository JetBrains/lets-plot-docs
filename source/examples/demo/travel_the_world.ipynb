# %%
import pandas as pd

from lets_plot.geo_data import *
from lets_plot import *

LetsPlot.setup_html()
# Out:
# The geodata is provided by © OpenStreetMap contributors and is made available here under the Open Database License (ODbL).
#             <div id="c6eUrN"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.4.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("c6eUrN").appendChild(div);
#                     };
#                     var e = document.getElementById("c6eUrN");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
cities = pd.read_csv("https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/cities.csv")
cities.head()
# Out:
#    Unnamed: 0         name               link  coutry_id   latitude  \
# 0           0      Algiers      /wiki/Algiers          1  36.776389
# 1           1       Annaba       /wiki/Annaba          1  36.900000
# 2           2        Batna        /wiki/Batna          1  35.550000
# 3           3       Bechar       /wiki/Bechar          1  31.633333
# 4           4  Constantine  /wiki/Constantine          1  36.365000
#
#    longitude                                               text
# 0   3.058611   — with nearly 3 million inhabitants, Algiers ...
# 1   7.766667   — a town with 200,000 inhabitants in the east...
# 2   6.166667                                                NaN
# 3  -2.200000   — small city in the Sahara, not far from the ...
# 4   6.614722   - Algeria's 3rd largest city with a canyon go...

# %%
czech_cities = cities.loc[cities['coutry_id'] == 144]
czech_cities
# Out:
#       Unnamed: 0              name                                   link  \
# 1044           0            Prague                           /wiki/Prague
# 1045           1              Brno                             /wiki/Brno
# 1046           2  České Budějovice  /wiki/%C4%8Cesk%C3%A9_Bud%C4%9Bjovice
# 1047           3     Český Krumlov          /wiki/%C4%8Cesk%C3%BD_Krumlov
# 1048           4      Karlovy Vary                     /wiki/Karlovy_Vary
# 1049           5        Kutná Hora                  /wiki/Kutn%C3%A1_Hora
# 1050           6           Olomouc                          /wiki/Olomouc
# 1051           7           Ostrava                          /wiki/Ostrava
# 1052           8            Pilsen                           /wiki/Pilsen
#
#       coutry_id   latitude  longitude  \
# 1044        144  50.083333  14.416667
# 1045        144  49.200000  16.616667
# 1046        144  48.974722  14.474722
# 1047        144  48.816667  14.316667
# 1048        144  50.233333  12.866667
# 1049        144  49.950000  15.266667
# 1050        144  49.600000  17.250000
# 1051        144  49.835556  18.292500
# 1052        144  49.747500  13.377500
#
#                                                    text
# 1044   () — the capital and largest city of the Czec...
# 1045   — the largest city in Moravia and its former ...
# 1046           – attractive large city in South Bohemia
# 1047   — beautiful old town in South Bohemia with th...
# 1048   () — historic (and biggest Czech) spa resort,...
# 1049   — historical town with famous Saint Barbara c...
# 1050   ( or ) — riverside university town with a tho...
# 1051   — a vibrant local subculture and long history...
# 1052   () — home of the original Pilsner Urquell bee...

# %%
country_gcoder = geocode_countries(['Czech'])
country_gcoder.get_geocodes()
# Out:
#       id country found name                              centroid  \
# 0  51684   Czech      Česko  [15.5282667270321, 49.8037022352219]
#
#                                             position  \
# 0  [12.0905895531178, 48.5518079996109, 18.859253...
#
#                                                limit
# 0  [12.0905895531178, 48.5518079996109, 18.859253...

# %%
# Automatic word wrap:
# the value string is limited by the number of characters in it,
# and description will be split into multiple lines.

(ggplot()
 + geom_livemap(location=[15.78,49.35], zoom=6)
 + geom_polygon(aes(fill='country'), 
                data=country_gcoder.get_boundaries(), 
                alpha=.2)
 + geom_point(aes('longitude', 'latitude', color='name'),
                data=czech_cities,
                size=4, 
                tooltips=layer_tooltips()
                    .title('@name')
                    .line('Longitude|@longitude')
                    .line('Latitude|@latitude')
                    .line('Description|@text'))
 + theme(legend_position='none')
)
# Out:
#    <div id="KAro0J"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "legend_position":"none"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[15.78,49.35]
# },
# "zoom":6,
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"Map: <a href=\"https://github.com/JetBrains/lets-plot\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"polygon",
# "data":{
# "country":["Czech"],
# "geometry":["{\"type\": \"MultiPolygon\", \"coordinates\": [[[[12.12890625, 50.176898122001], [12.12890625, 50.2893392532918], [12.3046875, 50.2893392532918], [12.48046875, 50.2893392532918], [12.48046875, 50.4015153227824], [12.65625, 50.4015153227824], [12.83203125, 50.4015153227824], [13.0078125, 50.4015153227824], [13.0078125, 50.5134265263396], [13.18359375, 50.5134265263396], [13.18359375, 50.6250730634144], [13.359375, 50.6250730634144], [13.53515625, 50.6250730634144], [13.53515625, 50.7364551370106], [13.7109375, 50.7364551370106], [13.88671875, 50.7364551370106], [13.88671875, 50.8475729536539], [14.0625, 50.8475729536539], [14.23828125, 50.8475729536539], [14.4140625, 50.8475729536539], [14.4140625, 50.9584267233599], [14.23828125, 50.9584267233599], [14.23828125, 51.0690166596039], [14.4140625, 51.0690166596039], [14.58984375, 51.0690166596039], [14.58984375, 50.9584267233599], [14.58984375, 50.8475729536539], [14.765625, 50.8475729536539], [14.94140625, 50.8475729536539], [14.94140625, 50.9584267233599], [14.94140625, 51.0690166596039], [15.1171875, 51.0690166596039], [15.1171875, 50.9584267233599], [15.29296875, 50.9584267233599], [15.29296875, 50.8475729536539], [15.29296875, 50.7364551370106], [15.46875, 50.7364551370106], [15.64453125, 50.7364551370106], [15.8203125, 50.7364551370106], [15.8203125, 50.6250730634144], [15.99609375, 50.6250730634144], [16.171875, 50.6250730634144], [16.34765625, 50.6250730634144], [16.34765625, 50.5134265263396], [16.171875, 50.5134265263396], [16.171875, 50.4015153227824], [16.34765625, 50.4015153227824], [16.34765625, 50.2893392532918], [16.5234375, 50.2893392532918], [16.5234375, 50.176898122001], [16.69921875, 50.176898122001], [16.875, 50.176898122001], [17.05078125, 50.176898122001], [16.875, 50.2893392532918], [16.875, 50.4015153227824], [17.05078125, 50.4015153227824], [17.2265625, 50.4015153227824], [17.2265625, 50.2893392532918], [17.40234375, 50.2893392532918], [17.578125, 50.2893392532918], [17.75390625, 50.2893392532918], [17.75390625, 50.176898122001], [17.578125, 50.176898122001], [17.578125, 50.0641917366591], [17.75390625, 50.0641917366591], [17.75390625, 49.951219908662], [17.9296875, 49.951219908662], [17.9296875, 50.0641917366591], [18.10546875, 50.0641917366591], [18.10546875, 49.951219908662], [18.28125, 49.951219908662], [18.45703125, 49.951219908662], [18.6328125, 49.951219908662], [18.6328125, 49.8379824530848], [18.6328125, 49.724479188713], [18.80859375, 49.724479188713], [18.80859375, 49.6107099380742], [18.80859375, 49.4966745274704], [18.6328125, 49.4966745274704], [18.45703125, 49.4966745274704], [18.45703125, 49.3823727870095], [18.28125, 49.3823727870095], [18.28125, 49.2678045506375], [18.10546875, 49.2678045506375], [18.10546875, 49.1529696561704], [18.10546875, 49.0378679453264], [17.9296875, 49.0378679453264], [17.9296875, 48.9224992637582], [17.75390625, 48.9224992637582], [17.75390625, 48.8068634610852], [17.578125, 48.8068634610852], [17.40234375, 48.8068634610852], [17.2265625, 48.8068634610852], [17.05078125, 48.8068634610852], [17.05078125, 48.6909603909255], [16.875, 48.6909603909255], [16.69921875, 48.6909603909255], [16.69921875, 48.8068634610852], [16.5234375, 48.8068634610852], [16.34765625, 48.8068634610852], [16.34765625, 48.6909603909255], [16.171875, 48.6909603909255], [16.171875, 48.8068634610852], [15.99609375, 48.8068634610852], [15.8203125, 48.8068634610852], [15.64453125, 48.8068634610852], [15.64453125, 48.9224992637582], [15.46875, 48.9224992637582], [15.29296875, 48.9224992637582], [15.1171875, 48.9224992637582], [15.1171875, 49.0378679453264], [14.94140625, 49.0378679453264], [14.94140625, 48.9224992637582], [14.94140625, 48.8068634610852], [14.765625, 48.8068634610852], [14.765625, 48.6909603909255], [14.765625, 48.5747899109288], [14.58984375, 48.5747899109288], [14.4140625, 48.5747899109288], [14.23828125, 48.5747899109288], [14.0625, 48.5747899109288], [14.0625, 48.6909603909255], [13.88671875, 48.6909603909255], [ ...
# },
# "mapping":{
# "fill":"country"
# },
# "data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# },
# "alpha":0.2
# },{
# "geom":"point",
# "data":{
# "name":["Prague","Brno","České Budějovice","Český Krumlov","Karlovy Vary","Kutná Hora","Olomouc","Ostrava","Pilsen"],
# "latitude":[50.083333,49.2,48.974722,48.816667,50.233333,49.95,49.6,49.835556,49.7475],
# "longitude":[14.416667,16.616667,14.474722,14.316667,12.866667,15.266667,17.25,18.2925,13.3775],
# "text":[" () — the capital and largest city of the Czech Republic with a large and beautiful historic centre"," — the largest city in Moravia and its former capital, it offers several excellent museums, annual Moto GP Grand Prix, annual international fireworks festival Ignis Brunensis, a large historical centre, the second-largest ossuary in Europe (after the Catacombs of Paris), one of the biggest exhibition centres in the Europe, the oldest theatre building in Central Europe, and many other things."," – attractive large city in South Bohemia"," — beautiful old town in South Bohemia with the country's second biggest chateau"," () — historic (and biggest Czech) spa resort, especially popular with German and Russian tourist groups"," — historical town with famous Saint Barbara cathedral, old silver mines and the Chapel of All Saints, which is decorated with thousands of human bones"," ( or ) — riverside university town with a thousand-year history and the second-largest historical centre in the Czech Republic"," — a vibrant local subculture and long history of coal mining and heavy industry"," () — home of the original Pilsner Urquell beer, and the largest city in West Bohemia"]
# },
# "mapping":{
# "x":"longitude",
# "y":"latitude",
# "color":"name"
# },
# "tooltips":{
# "tooltip_formats":[],
# "tooltip_lines":["Longitude|@longitude","Latitude|@latitude","Description|@text"],
# "tooltip_title":"@name"
# },
# "data_meta":{
# },
# "size":4
# }]
# };
#            var plotContainer = document.getElementById("KAro0J");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
