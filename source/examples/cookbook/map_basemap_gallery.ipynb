# %% [markdown]
# ## Configuring basemap tiles in [Lets-Plot](https://lets-plot.org)
#
#
# ### Configuring globally
#
# You can configure global Lets-Plot options using the `LestPlot.set(dictionary)` method.
#
# Where the `dictionary` can contain all sorts of Lets-Plot options, including basemap tiles configuration options.
#
# Lets-Plot provides a variety of constantas and functions which make configuring of basemap tiles simple:
#
# ```
# from lets_plot import tilesets
#
# LetsPlot.set(tilesets.LETS_PLOT_DARK)
# ```
#
# ### Configuring for a single plot
#
# Use `tiles` parameter in the `geom_livemap()` function:
# ```
# from lets_plot import tilesets
#
# ggplot() + geom_livemap(tiles=tilesets.LETS_PLOT_DARK)
# ```
#
#
# In this demo we will be using the `tiles` parameter because each plot here is using different map-tile service.

# %%
from lets_plot import *
from lets_plot import tilesets
LetsPlot.setup_html()
# Out:
#             <div id="mkheOu"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.2.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("mkheOu").appendChild(div);
#                     };
#                     var e = document.getElementById("mkheOu");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
def show_map(text, tiles=None):
    (ggplot() + geom_livemap(location=[13.3, 37.6], zoom=3, tiles=tiles) + 
     ggsize(500, 450) + 
     ggtitle(text)).show()

# %% [markdown]
# ### Lets-Plot vector tiles
#
# Lets-Plot provides its own vector basemap tiles available in three variants:
#
# - color
# - dark
# - light
#
# By default Lets-Plot uses its "color" tiles.

# %%
show_map("Lets-Plot vector tiles (default).")
show_map("Lets-Plot vector tiles (dark).", tilesets.LETS_PLOT_DARK)
show_map("Lets-Plot vector tiles (light).", tilesets.LETS_PLOT_LIGHT)
# Out:
#    <div id="WUG3MA"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"Lets-Plot vector tiles (default)."
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"Map: <a href=\"https://github.com/JetBrains/lets-plot\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("WUG3MA");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="762bAa"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"Lets-Plot vector tiles (dark)."
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"dark",
# "attribution":"Map: <a href=\"https://github.com/JetBrains/lets-plot\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("762bAa");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="8xyeSi"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"Lets-Plot vector tiles (light)."
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"light",
# "attribution":"Map: <a href=\"https://github.com/JetBrains/lets-plot\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("8xyeSi");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Raster tiles
#
# You can use `ZXY` raster tiles provided by 3rd party maptile services.
#
# Some services provide free of charge raster tilesets.
#
# The `tilesets` module in Lets-Plot contains many such tilesets pre-cofigured.

# %% [markdown]
# ### OpenStreetMap
#
# [© OpenStreetMap contributors](https://www.openstreetmap.org/copyright)

# %%
show_map("OpenStreetMap's Standard tile layer", tilesets.OSM)
# Out:
#    <div id="Kz4TBL"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"OpenStreetMap's Standard tile layer"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://[abc].tile.openstreetmap.org/{z}/{x}/{y}.png",
# "attribution":"<a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>",
# "min_zoom":1.0,
# "max_zoom":19.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("Kz4TBL");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### OpenTopoMap
#
# Map data: [© OpenStreetMap contributors](https://www.openstreetmap.org/copyright), [SRTM](http://viewfinderpanoramas.org/) | map style: [© OpenTopoMap](https://opentopomap.org/) ([CC-BY-SA](https://creativecommons.org/licenses/by-sa/3.0/))

# %%
show_map("OpenTopoMap", tilesets.OPEN_TOPO_MAP)
# Out:
#    <div id="qcJz9Q"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"OpenTopoMap"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://tile.opentopomap.org/{z}/{x}/{y}.png",
# "attribution":"Map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>, <a href=\"http://viewfinderpanoramas.org/\">SRTM</a> | map style: <a href=\"https://opentopomap.org/\">© OpenTopoMap</a> (<a href=\"https://creativecommons.org/licenses/by-sa/3.0/\">CC-BY-SA</a>) ",
# "min_zoom":1.0,
# "max_zoom":16.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("qcJz9Q");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Stamen Design
#
# ##### Toner and Terrain:
#
# Map tiles by <a href="http://stamen.com">Stamen Design</a>, under <a href="http://creativecommons.org/licenses/by/3.0">CC BY 3.0</a>. Data by <a href="http://openstreetmap.org">OpenStreetMap</a>, under <a href="http://www.openstreetmap.org/copyright">ODbL</a>.
#
# ##### Watercolor:
#
# Map tiles by <a href="http://stamen.com">Stamen Design</a>, under <a href="http://creativecommons.org/licenses/by/3.0">CC BY 3.0</a>. Data by <a href="http://openstreetmap.org">OpenStreetMap</a>, under <a href="http://creativecommons.org/licenses/by-sa/3.0">CC BY SA</a>.

# %%
show_map("Stamen Design - Toner", tilesets.STAMEN_DESIGN_TONER)
show_map("Stamen Design - Terrain", tilesets.STAMEN_DESIGN_TERRAIN_HIRES)
show_map("Stamen Design - Watercolor", tilesets.STAMEN_DESIGN_WATERCOLOR)
show_map("Stamen Design - Toner Labels", tilesets.STAMEN_DESIGN_TONER_LABELS_HIRES)
show_map("Stamen Design - Toner Light", tilesets.STAMEN_DESIGN_TONER_LIGHT)
# Out:
#    <div id="JGfrxe"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"Stamen Design - Toner"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://stamen-tiles-[abcd].a.ssl.fastly.net/toner/{z}/{x}/{y}.png",
# "attribution":"Map tiles by <a href=\"http://stamen.com\">Stamen Design</a>, under <a href=\"http://creativecommons.org/licenses/by/3.0\">CC BY 3.0</a>. Data by <a href=\"http://openstreetmap.org\">OpenStreetMap</a>, under <a href=\"http://www.openstreetmap.org/copyright\">ODbL</a>.",
# "min_zoom":1.0,
# "max_zoom":20.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("JGfrxe");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="pdrI62"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"Stamen Design - Terrain"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://stamen-tiles-[abcd].a.ssl.fastly.net/terrain/{z}/{x}/{y}@2x.png",
# "attribution":"Map tiles by <a href=\"http://stamen.com\">Stamen Design</a>, under <a href=\"http://creativecommons.org/licenses/by/3.0\">CC BY 3.0</a>. Data by <a href=\"http://openstreetmap.org\">OpenStreetMap</a>, under <a href=\"http://www.openstreetmap.org/copyright\">ODbL</a>.",
# "min_zoom":1.0,
# "max_zoom":18.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("pdrI62");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="KCuiQU"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"Stamen Design - Watercolor"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://stamen-tiles-[abcd].a.ssl.fastly.net/watercolor/{z}/{x}/{y}.png",
# "attribution":"Map tiles by <a href=\"http://stamen.com\">Stamen Design</a>, under <a href=\"http://creativecommons.org/licenses/by/3.0\">CC BY 3.0</a>. Data by <a href=\"http://openstreetmap.org\">OpenStreetMap</a>, under <a href=\"http://creativecommons.org/licenses/by-sa/3.0\">CC BY SA</a>.",
# "min_zoom":1.0,
# "max_zoom":18.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("KCuiQU");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="xDb84e"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"Stamen Design - Toner Labels"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://stamen-tiles-[abcd].a.ssl.fastly.net/toner-labels/{z}/{x}/{y}@2x.png",
# "attribution":"Map tiles by <a href=\"http://stamen.com\">Stamen Design</a>, under <a href=\"http://creativecommons.org/licenses/by/3.0\">CC BY 3.0</a>. Data by <a href=\"http://openstreetmap.org\">OpenStreetMap</a>, under <a href=\"http://www.openstreetmap.org/copyright\">ODbL</a>.",
# "min_zoom":1.0,
# "max_zoom":20.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("xDb84e");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="QgtTvB"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"Stamen Design - Toner Light"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://stamen-tiles-[abcd].a.ssl.fastly.net/toner-lite/{z}/{x}/{y}.png",
# "attribution":"Map tiles by <a href=\"http://stamen.com\">Stamen Design</a>, under <a href=\"http://creativecommons.org/licenses/by/3.0\">CC BY 3.0</a>. Data by <a href=\"http://openstreetmap.org\">OpenStreetMap</a>, under <a href=\"http://www.openstreetmap.org/copyright\">ODbL</a>.",
# "min_zoom":1.0,
# "max_zoom":20.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("QgtTvB");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### CARTO
#
# [© OpenStreetMap contributors](https://www.openstreetmap.org/copyright) [© CARTO](https://carto.com/attributions#basemaps), [© CARTO](https://carto.com/attributions)
#
# Free for none-commercial services only (see [Limitations](https://github.com/CartoDB/basemap-styles#1-web-raster-basemaps), [License](https://github.com/CartoDB/basemap-styles/blob/master/LICENSE.md)).

# %%
show_map("CARTO Positron", tilesets.CARTO_POSITRON_HIRES)
show_map("CARTO Positron (no labels)", tilesets.CARTO_POSITRON_NO_LABELS_HIRES)
show_map("CARTO Dark Matter (no labels)", tilesets.CARTO_DARK_MATTER_NO_LABELS_HIRES)
show_map("CARTO Voyager", tilesets.CARTO_VOYAGER_HIRES)
show_map("CARTO Flat Blue", tilesets.CARTO_FLAT_BLUE)
show_map("CARTO Midnight commander", tilesets.CARTO_MIDNIGHT_COMMANDER)
show_map("CARTO Antique", tilesets.CARTO_ANTIQUE_HIRES)
# Out:
#    <div id="IcED6c"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"CARTO Positron"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://[abc].basemaps.cartocdn.com/rastertiles/light_all/{z}/{x}/{y}@2x.png",
# "attribution":"<a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a> <a href=\"https://carto.com/attributions#basemaps\">© CARTO</a>, <a href=\"https://carto.com/attributions\">© CARTO</a>",
# "min_zoom":1.0,
# "max_zoom":20.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("IcED6c");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="FsU5VN"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"CARTO Positron (no labels)"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://[abc].basemaps.cartocdn.com/rastertiles/light_nolabels/{z}/{x}/{y}@2x.png",
# "attribution":"<a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a> <a href=\"https://carto.com/attributions#basemaps\">© CARTO</a>, <a href=\"https://carto.com/attributions\">© CARTO</a>",
# "min_zoom":1.0,
# "max_zoom":20.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("FsU5VN");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="tTknOy"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"CARTO Dark Matter (no labels)"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://[abc].basemaps.cartocdn.com/rastertiles/dark_nolabels/{z}/{x}/{y}@2x.png",
# "attribution":"<a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a> <a href=\"https://carto.com/attributions#basemaps\">© CARTO</a>, <a href=\"https://carto.com/attributions\">© CARTO</a>",
# "min_zoom":1.0,
# "max_zoom":20.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("tTknOy");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="LTBsLe"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"CARTO Voyager"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://[abc].basemaps.cartocdn.com/rastertiles/voyager/{z}/{x}/{y}@2x.png",
# "attribution":"<a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a> <a href=\"https://carto.com/attributions#basemaps\">© CARTO</a>, <a href=\"https://carto.com/attributions\">© CARTO</a>",
# "min_zoom":1.0,
# "max_zoom":20.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("LTBsLe");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="woejBx"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"CARTO Flat Blue"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://cartocdn_[abc].global.ssl.fastly.net/base-flatblue/{z}/{x}/{y}.png",
# "attribution":"<a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a> <a href=\"https://carto.com/attributions#basemaps\">© CARTO</a>, <a href=\"https://carto.com/attributions\">© CARTO</a>",
# "min_zoom":1.0,
# "max_zoom":20.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("woejBx");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="L4JkPZ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"CARTO Midnight commander"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://cartocdn_[abc].global.ssl.fastly.net/base-midnight/{z}/{x}/{y}.png",
# "attribution":"<a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a> <a href=\"https://carto.com/attributions#basemaps\">© CARTO</a>, <a href=\"https://carto.com/attributions\">© CARTO</a>",
# "min_zoom":1.0,
# "max_zoom":20.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("L4JkPZ");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="qScFFf"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"CARTO Antique"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://cartocdn_[abc].global.ssl.fastly.net/base-antique/{z}/{x}/{y}@2x.png",
# "attribution":"<a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a> <a href=\"https://carto.com/attributions#basemaps\">© CARTO</a>, <a href=\"https://carto.com/attributions\">© CARTO</a>",
# "min_zoom":1.0,
# "max_zoom":20.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("qScFFf");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### NASA's Global Imagery Browse Services (GIBS)
#
# Imagery provided by services from NASA's Global Imagery Browse Services ([GIBS](https://earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/gibs)), part of NASA's Earth Observing System Data and Information System ([EOSDIS](https://earthdata.nasa.gov)).
#
# [NASA's Global Imagery Browse Services (GIBS)](https://earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/gibs).
#
# Global Imagery Browse Services (GIBS) - [API for Developers](https://wiki.earthdata.nasa.gov/display/GIBS/GIBS+API+for+Developers).
#
# Global Imagery Browse Services (GIBS) API - [Generic XYZ Tile Access](https://wiki.earthdata.nasa.gov/display/GIBS/GIBS+API+for+Developers#GIBSAPIforDevelopers-GenericXYZTileAccess).
#
# [GIBS Available Imagery Products](https://wiki.earthdata.nasa.gov/display/GIBS/GIBS+Available+Imagery+Products).

# %%
show_map("NASA GIBS: CityLights 2012", tilesets.NASA_CITYLIGHTS_2012)
show_map("NASA GIBS: BlueMarble_NextGeneration", tilesets.NASA_BLUEMARBLE_NEXTGENERATION)
show_map("NASA GIBS: Greyscale Shaded Relief (30m)", tilesets.NASA_GREYSCALE_SHADED_RELIEF_30M)
show_map("NASA GIBS: Color Shaded Relief (30m)", tilesets.NASA_COLOR_SHADED_RELIEF_30M)
show_map("NASA GIBS: Terra TrueColor", tilesets.NASA_TERRA_TRUECOLOR)
# Out:
#    <div id="LDq7I3"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"NASA GIBS: CityLights 2012"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/VIIRS_CityLights_2012/default//GoogleMapsCompatible_Level8/{z}/{y}/{x}.jpg",
# "attribution":"<a href=\"https://earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/gibs\">© NASA Global Imagery Browse Services (GIBS)</a>",
# "min_zoom":1.0,
# "max_zoom":8.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("LDq7I3");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="fAOhnY"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"NASA GIBS: BlueMarble_NextGeneration"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/BlueMarble_NextGeneration/default//GoogleMapsCompatible_Level8/{z}/{y}/{x}.jpg",
# "attribution":"<a href=\"https://earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/gibs\">© NASA Global Imagery Browse Services (GIBS)</a>",
# "min_zoom":1.0,
# "max_zoom":8.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("fAOhnY");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="KArbUY"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"NASA GIBS: Greyscale Shaded Relief (30m)"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/ASTER_GDEM_Greyscale_Shaded_Relief/default//GoogleMapsCompatible_Level12/{z}/{y}/{x}.jpg",
# "attribution":"<a href=\"https://earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/gibs\">© NASA Global Imagery Browse Services (GIBS)</a>",
# "min_zoom":1.0,
# "max_zoom":12.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("KArbUY");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="DJoR4n"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"NASA GIBS: Color Shaded Relief (30m)"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/ASTER_GDEM_Color_Shaded_Relief/default//GoogleMapsCompatible_Level12/{z}/{y}/{x}.jpg",
# "attribution":"<a href=\"https://earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/gibs\">© NASA Global Imagery Browse Services (GIBS)</a>",
# "min_zoom":1.0,
# "max_zoom":12.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("DJoR4n");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
#    <div id="Cs1ZM3"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"NASA GIBS: Terra TrueColor"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/MODIS_Terra_CorrectedReflectance_TrueColor/default/2015-06-07/GoogleMapsCompatible_Level9/{z}/{y}/{x}.jpg",
# "attribution":"<a href=\"https://earthdata.nasa.gov/eosdis/science-system-description/eosdis-components/gibs\">© NASA Global Imagery Browse Services (GIBS)</a>",
# "min_zoom":1.0,
# "max_zoom":9.0
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("Cs1ZM3");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Configuring raster tiles manually
#
# In addition to pre-configured tilesets you can configure and use almost any other raster tilesets provided in `ZXY` format.
#
# You can do it with the help of the `LetsPlot.maptiles_zxy()` function.
#
# The following code will configure 'Stamen Design - Toner Hybrid' tiles:

# %%
settings = dict(
    url = "https://stamen-tiles.a.ssl.fastly.net/toner-hybrid/{z}/{x}/{y}@2x.png",
    attribution = 'Map tiles by <a href="http://stamen.com">Stamen Design</a>, under <a href="http://creativecommons.org/licenses/by/3.0">CC BY 3.0</a>. Data by <a href="http://openstreetmap.org">OpenStreetMap</a>, under <a href="http://www.openstreetmap.org/copyright">ODbL</a>.'
)

show_map("Stamen Design - Toner Hybrid", maptiles_zxy(**settings))
# Out:
#    <div id="3okcJL"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "ggsize":{
# "width":500.0,
# "height":450.0
# },
# "ggtitle":{
# "text":"Stamen Design - Toner Hybrid"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "location":{
# "type":"coordinates",
# "data":[13.3,37.6]
# },
# "zoom":3.0,
# "tiles":{
# "kind":"raster_zxy",
# "url":"https://stamen-tiles.a.ssl.fastly.net/toner-hybrid/{z}/{x}/{y}@2x.png",
# "attribution":"Map tiles by <a href=\"http://stamen.com\">Stamen Design</a>, under <a href=\"http://creativecommons.org/licenses/by/3.0\">CC BY 3.0</a>. Data by <a href=\"http://openstreetmap.org\">OpenStreetMap</a>, under <a href=\"http://www.openstreetmap.org/copyright\">ODbL</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("3okcJL");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
