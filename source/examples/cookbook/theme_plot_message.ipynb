# %% [markdown]
# # Option to show/hide plot messages
#
# The option `plot_message` allows to hide messages produced by sampling.

# %%
from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="mb0TjF"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.1.0rc1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("mb0TjF").appendChild(div);
#                     };
#                     var e = document.getElementById("mb0TjF");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
d = { 
    'x': [it for it in range(100)] 
}

# %%
p = ggplot(d) + geom_point(aes(x='x'), sampling=sampling_random(n=10))
p
# Out:
#    <div id="ReKMYA"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x"
# },
# "sampling":{
# "name":"random",
# "n":10.0
# },
# "data_meta":{
# },
# "data":{
# "x":[9.0,25.0,38.0,51.0,54.0,55.0,60.0,70.0,91.0,94.0]
# }
# }],
# "metainfo_list":[],
# "computation_messages":["sampling_random(n=10) was applied to [point/identity stat] layer"]
# };
#            var plotContainer = document.getElementById("ReKMYA");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Using the `plot_message` parameter

# %%
p + theme(plot_message='blank')
# Out:
#    <div id="bu5XjN"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "plot_message":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x"
# },
# "sampling":{
# "name":"random",
# "n":10.0
# },
# "data_meta":{
# },
# "data":{
# "x":[10.0,15.0,25.0,42.0,60.0,74.0,81.0,88.0,90.0,94.0]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("bu5XjN");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Hiding plot messages for the whole notebook
#
# Using the `LestPlot.set_theme(...)` function messages can be suppressed for the whole notebook.

# %%
LetsPlot.set_theme(theme(plot_message='blank'))
ggplot(d) + geom_point(aes(x='x'), sampling=sampling_random(n=10))
# Out:
#    <div id="kwm5GK"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "plot_message":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x"
# },
# "sampling":{
# "name":"random",
# "n":10.0
# },
# "data_meta":{
# },
# "data":{
# "x":[6.0,15.0,35.0,42.0,61.0,75.0,77.0,82.0,85.0,99.0]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("kwm5GK");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
