# %% [markdown]
# # Option to show/hide plot messages
#
# The option `plot_message` allows to hide messages produced by sampling.

# %%
from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="q7559n"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("q7559n").appendChild(div);
#                     };
#                     var e = document.getElementById("q7559n");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
d = { 
    'x': [it for it in range(100)] 
}

# %%
p = ggplot(d) + geom_point(aes(x='x'), sampling=sampling_random(n=10))
p
# Out:
#    <div id="cUZAw6"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x"
# },
# "sampling":{
# "name":"random",
# "n":10.0
# },
# "data_meta":{
# },
# "data":{
# "x":[12.0,17.0,18.0,36.0,50.0,52.0,68.0,71.0,92.0,95.0]
# }
# }],
# "metainfo_list":[],
# "computation_messages":["sampling_random(n=10) was applied to [point/identity stat] layer"]
# };
#            var plotContainer = document.getElementById("cUZAw6");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Using the `plot_message` parameter

# %%
p + theme(plot_message='blank')
# Out:
#    <div id="N4EmbY"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "plot_message":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x"
# },
# "sampling":{
# "name":"random",
# "n":10.0
# },
# "data_meta":{
# },
# "data":{
# "x":[1.0,2.0,4.0,14.0,15.0,37.0,44.0,60.0,80.0,81.0]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("N4EmbY");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Hiding plot messages for the whole notebook
#
# Using the `LestPlot.set_theme(...)` function messages can be suppressed for the whole notebook.

# %%
LetsPlot.set_theme(theme(plot_message='blank'))
ggplot(d) + geom_point(aes(x='x'), sampling=sampling_random(n=10))
# Out:
#    <div id="ft4WyJ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "plot_message":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x"
# },
# "sampling":{
# "name":"random",
# "n":10.0
# },
# "data_meta":{
# },
# "data":{
# "x":[8.0,10.0,17.0,34.0,46.0,53.0,61.0,65.0,73.0,84.0]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("ft4WyJ");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
