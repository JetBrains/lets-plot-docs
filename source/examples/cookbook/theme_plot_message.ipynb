# %% [markdown]
# # Option to show/hide plot messages
#
# The option `plot_message` allows to hide messages produced by sampling.

# %%
from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="q5OQ3u"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.1.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("q5OQ3u").appendChild(div);
#                     };
#                     var e = document.getElementById("q5OQ3u");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
d = { 
    'x': [it for it in range(100)] 
}

# %%
p = ggplot(d) + geom_point(aes(x='x'), sampling=sampling_random(n=10))
p
# Out:
#    <div id="kfHNB8"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x"
# },
# "sampling":{
# "name":"random",
# "n":10.0
# },
# "data_meta":{
# },
# "data":{
# "x":[2.0,8.0,23.0,33.0,38.0,66.0,69.0,70.0,78.0,97.0]
# }
# }],
# "metainfo_list":[],
# "computation_messages":["sampling_random(n=10) was applied to [point/identity stat] layer"]
# };
#            var plotContainer = document.getElementById("kfHNB8");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Using the `plot_message` parameter

# %%
p + theme(plot_message='blank')
# Out:
#    <div id="OBQtHr"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "plot_message":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x"
# },
# "sampling":{
# "name":"random",
# "n":10.0
# },
# "data_meta":{
# },
# "data":{
# "x":[0.0,5.0,7.0,20.0,30.0,35.0,70.0,72.0,77.0,92.0]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("OBQtHr");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Hiding plot messages for the whole notebook
#
# Using the `LestPlot.set_theme(...)` function messages can be suppressed for the whole notebook.

# %%
LetsPlot.set_theme(theme(plot_message='blank'))
ggplot(d) + geom_point(aes(x='x'), sampling=sampling_random(n=10))
# Out:
#    <div id="OKL8z5"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "plot_message":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x"
# },
# "sampling":{
# "name":"random",
# "n":10.0
# },
# "data_meta":{
# },
# "data":{
# "x":[3.0,12.0,14.0,17.0,18.0,24.0,26.0,78.0,91.0,93.0]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("OKL8z5");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
