# %%
import pandas as pd

from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="pXBgdf"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.3.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("pXBgdf").appendChild(div);
#                     };
#                     var e = document.getElementById("pXBgdf");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
df = {'cond': ['A', 'A', 'B', 'B', 'C', 'C'], \
      'x': [2, 3, 2, 3, 2, 3], \
      'y': [1.0, 1.5, 2.0, 1.0, 1.6, 1.8]}

# %%
# Let's plot default lines and points
ggplot(df) + geom_line(aes(x='x', y='y', group='cond')) + \
    geom_point(aes(x='x', y='y'))
# Out:
#    <div id="ASsxN3"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "cond":["A","A","B","B","C","C"],
# "x":[2.0,3.0,2.0,3.0,2.0,3.0],
# "y":[1.0,1.5,2.0,1.0,1.6,1.8]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"line",
# "mapping":{
# "x":"x",
# "y":"y",
# "group":"cond"
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("ASsxN3");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# Let's set dotted thicker line and hollow large squares
ggplot(df) + geom_line(aes(x='x', y='y', group='cond'), linetype='dotted', size = 1.5) + \
    geom_point(aes(x='x', y='y'), shape = 0, size = 4)
# Out:
#    <div id="LhFPeE"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "cond":["A","A","B","B","C","C"],
# "x":[2.0,3.0,2.0,3.0,2.0,3.0],
# "y":[1.0,1.5,2.0,1.0,1.6,1.8]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"line",
# "mapping":{
# "x":"x",
# "y":"y",
# "group":"cond"
# },
# "data_meta":{
# },
# "linetype":"dotted",
# "size":1.5,
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "shape":0,
# "size":4,
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("LhFPeE");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# We can make line type and shape of points depend on variable
ggplot(df) + geom_line(aes(x='x', y='y', group='cond', linetype='cond')) + \
    geom_point(aes(x='x', y='y', shape='cond'), size=4)
# Out:
#    <div id="WbjyFn"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "cond":["A","A","B","B","C","C"],
# "x":[2.0,3.0,2.0,3.0,2.0,3.0],
# "y":[1.0,1.5,2.0,1.0,1.6,1.8]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"line",
# "mapping":{
# "x":"x",
# "y":"y",
# "group":"cond",
# "linetype":"cond"
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y",
# "shape":"cond"
# },
# "data_meta":{
# },
# "size":4,
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("WbjyFn");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# The same but with hollow shapes
ggplot(df, aes(x='x', y='y', group='cond')) + \
    geom_line(aes(linetype='cond')) + \
    geom_point(aes(shape='cond'), size=4) + scale_shape(solid=False)
# Out:
#    <div id="HFDBc4"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "cond":["A","A","B","B","C","C"],
# "x":[2.0,3.0,2.0,3.0,2.0,3.0],
# "y":[1.0,1.5,2.0,1.0,1.6,1.8]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "group":"cond"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"shape",
# "solid":false
# }],
# "layers":[{
# "geom":"line",
# "mapping":{
# "linetype":"cond"
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "shape":"cond"
# },
# "data_meta":{
# },
# "size":4,
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("HFDBc4");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# Let's manually change the specific linetypes and shapes that are used
ggplot(df) + geom_line(aes(x='x', y='y', group='cond', linetype='cond')) + \
    geom_point(aes(x='x', y='y', shape='cond'), size=4) + \
    scale_linetype_manual(values=('dotdash', 'dotted', 'dashed')) + \
    scale_shape_manual(values=(6, 7, 8))
# Out:
#    <div id="5TFBCz"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "cond":["A","A","B","B","C","C"],
# "x":[2.0,3.0,2.0,3.0,2.0,3.0],
# "y":[1.0,1.5,2.0,1.0,1.6,1.8]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"linetype",
# "values":["dotdash","dotted","dashed"]
# },{
# "aesthetic":"shape",
# "values":[6,7,8]
# }],
# "layers":[{
# "geom":"line",
# "mapping":{
# "x":"x",
# "y":"y",
# "group":"cond",
# "linetype":"cond"
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y",
# "shape":"cond"
# },
# "data_meta":{
# },
# "size":4,
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("5TFBCz");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# Let's set gray lines and shapes with green fill
ggplot(df, aes(x='x', y='y', group='cond')) + \
    geom_line(aes(linetype='cond'), size=1.5, color='gray') + \
    geom_point(aes(shape='cond'), fill='dark_green', color='gray', size=6) + \
    scale_shape_manual(values=(21,22,24))  # Shapes: Filled circle, square, triangle
# Out:
#    <div id="8cqYOP"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "cond":["A","A","B","B","C","C"],
# "x":[2.0,3.0,2.0,3.0,2.0,3.0],
# "y":[1.0,1.5,2.0,1.0,1.6,1.8]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "group":"cond"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"shape",
# "values":[21,22,24]
# }],
# "layers":[{
# "geom":"line",
# "mapping":{
# "linetype":"cond"
# },
# "data_meta":{
# },
# "size":1.5,
# "color":"gray",
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "shape":"cond"
# },
# "data_meta":{
# },
# "fill":"dark_green",
# "color":"gray",
# "size":6,
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("8cqYOP");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# We can also add alpha channel(transparency)
ggplot(df, aes(x='x', y='y', group='cond')) + \
    geom_line(aes(linetype='cond'), size = 1.5, color='gray', alpha=.5) + \
    geom_point(aes(shape='cond'), fill='dark_green', color='gray', size=6, alpha=.7) + \
    scale_shape_manual(values=(21,22,24))
# Out:
#    <div id="YHzf3k"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "cond":["A","A","B","B","C","C"],
# "x":[2.0,3.0,2.0,3.0,2.0,3.0],
# "y":[1.0,1.5,2.0,1.0,1.6,1.8]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "group":"cond"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"shape",
# "values":[21,22,24]
# }],
# "layers":[{
# "geom":"line",
# "mapping":{
# "linetype":"cond"
# },
# "data_meta":{
# },
# "size":1.5,
# "color":"gray",
# "alpha":0.5,
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "shape":"cond"
# },
# "data_meta":{
# },
# "fill":"dark_green",
# "color":"gray",
# "size":6,
# "alpha":0.7,
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("YHzf3k");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
