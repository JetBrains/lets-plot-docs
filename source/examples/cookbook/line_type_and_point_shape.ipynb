# %%
import pandas as pd

from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="kUT8Mk"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("kUT8Mk").appendChild(div);
#                     };
#                     var e = document.getElementById("kUT8Mk");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
df = {'cond': ['A', 'A', 'B', 'B', 'C', 'C'], \
      'x': [2, 3, 2, 3, 2, 3], \
      'y': [1.0, 1.5, 2.0, 1.0, 1.6, 1.8]}

# %%
# Let's plot default lines and points
ggplot(df) + geom_line(aes(x='x', y='y', group='cond')) + \
    geom_point(aes(x='x', y='y'))
# Out:
#    <div id="onxbZn"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "cond":["A","A","B","B","C","C"],
# "x":[2.0,3.0,2.0,3.0,2.0,3.0],
# "y":[1.0,1.5,2.0,1.0,1.6,1.8]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"line",
# "mapping":{
# "x":"x",
# "y":"y",
# "group":"cond"
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("onxbZn");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# Let's set dotted thicker line and hollow large squares
ggplot(df) + geom_line(aes(x='x', y='y', group='cond'), linetype='dotted', size = 1.5) + \
    geom_point(aes(x='x', y='y'), shape = 0, size = 4)
# Out:
#    <div id="7x0PeX"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "cond":["A","A","B","B","C","C"],
# "x":[2.0,3.0,2.0,3.0,2.0,3.0],
# "y":[1.0,1.5,2.0,1.0,1.6,1.8]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"line",
# "mapping":{
# "x":"x",
# "y":"y",
# "group":"cond"
# },
# "data_meta":{
# },
# "linetype":"dotted",
# "size":1.5,
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "shape":0.0,
# "size":4.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("7x0PeX");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# We can make line type and shape of points depend on variable
ggplot(df) + geom_line(aes(x='x', y='y', group='cond', linetype='cond')) + \
    geom_point(aes(x='x', y='y', shape='cond'), size=4)
# Out:
#    <div id="XLVY4f"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "cond":["A","A","B","B","C","C"],
# "x":[2.0,3.0,2.0,3.0,2.0,3.0],
# "y":[1.0,1.5,2.0,1.0,1.6,1.8]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"line",
# "mapping":{
# "x":"x",
# "y":"y",
# "group":"cond",
# "linetype":"cond"
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y",
# "shape":"cond"
# },
# "data_meta":{
# },
# "size":4.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("XLVY4f");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# The same but with hollow shapes
ggplot(df, aes(x='x', y='y', group='cond')) + \
    geom_line(aes(linetype='cond')) + \
    geom_point(aes(shape='cond'), size=4) + scale_shape(solid=False)
# Out:
#    <div id="94r088"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "cond":["A","A","B","B","C","C"],
# "x":[2.0,3.0,2.0,3.0,2.0,3.0],
# "y":[1.0,1.5,2.0,1.0,1.6,1.8]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "group":"cond"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"shape",
# "solid":false
# }],
# "layers":[{
# "geom":"line",
# "mapping":{
# "linetype":"cond"
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "shape":"cond"
# },
# "data_meta":{
# },
# "size":4.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("94r088");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# Let's manually change the specific linetypes and shapes that are used
ggplot(df) + geom_line(aes(x='x', y='y', group='cond', linetype='cond')) + \
    geom_point(aes(x='x', y='y', shape='cond'), size=4) + \
    scale_linetype_manual(values=('dotdash', 'dotted', 'dashed')) + \
    scale_shape_manual(values=(6, 7, 8))
# Out:
#    <div id="JtMPLF"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "cond":["A","A","B","B","C","C"],
# "x":[2.0,3.0,2.0,3.0,2.0,3.0],
# "y":[1.0,1.5,2.0,1.0,1.6,1.8]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"linetype",
# "values":["dotdash","dotted","dashed"]
# },{
# "aesthetic":"shape",
# "values":[6.0,7.0,8.0]
# }],
# "layers":[{
# "geom":"line",
# "mapping":{
# "x":"x",
# "y":"y",
# "group":"cond",
# "linetype":"cond"
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y",
# "shape":"cond"
# },
# "data_meta":{
# },
# "size":4.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("JtMPLF");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# Let's set gray lines and shapes with green fill
ggplot(df, aes(x='x', y='y', group='cond')) + \
    geom_line(aes(linetype='cond'), size=1.5, color='gray') + \
    geom_point(aes(shape='cond'), fill='dark_green', color='gray', size=6) + \
    scale_shape_manual(values=(21,22,24))  # Shapes: Filled circle, square, triangle
# Out:
#    <div id="AFRzAK"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "cond":["A","A","B","B","C","C"],
# "x":[2.0,3.0,2.0,3.0,2.0,3.0],
# "y":[1.0,1.5,2.0,1.0,1.6,1.8]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "group":"cond"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"shape",
# "values":[21.0,22.0,24.0]
# }],
# "layers":[{
# "geom":"line",
# "mapping":{
# "linetype":"cond"
# },
# "data_meta":{
# },
# "size":1.5,
# "color":"gray",
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "shape":"cond"
# },
# "data_meta":{
# },
# "fill":"dark_green",
# "color":"gray",
# "size":6.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("AFRzAK");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# We can also add alpha channel(transparency)
ggplot(df, aes(x='x', y='y', group='cond')) + \
    geom_line(aes(linetype='cond'), size = 1.5, color='gray', alpha=.5) + \
    geom_point(aes(shape='cond'), fill='dark_green', color='gray', size=6, alpha=.7) + \
    scale_shape_manual(values=(21,22,24))
# Out:
#    <div id="jZkDqB"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "cond":["A","A","B","B","C","C"],
# "x":[2.0,3.0,2.0,3.0,2.0,3.0],
# "y":[1.0,1.5,2.0,1.0,1.6,1.8]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "group":"cond"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"shape",
# "values":[21.0,22.0,24.0]
# }],
# "layers":[{
# "geom":"line",
# "mapping":{
# "linetype":"cond"
# },
# "data_meta":{
# },
# "size":1.5,
# "color":"gray",
# "alpha":0.5,
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "shape":"cond"
# },
# "data_meta":{
# },
# "fill":"dark_green",
# "color":"gray",
# "size":6.0,
# "alpha":0.7,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("jZkDqB");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
