# %% [markdown]
# # Plot Margins
#
# `plot_margin` parameter in `theme()` allows to change the margin areas of a plot using the `margin()` function.

# %%
import numpy as np

from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="XoJSIl"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.1.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("XoJSIl").appendChild(div);
#                     };
#                     var e = document.getElementById("XoJSIl");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
np.random.seed(42)
data = {'x': np.random.randint(10, size=100)}

p = ggplot(data, aes(x='x')) + geom_bar() + ggtitle("Bar Сhart") + \
    theme(plot_background=element_rect(size = 6))

# %% [markdown]
# #### Plot without Margins

# %%
p
# Out:
#    <div id="DawRLg"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar Сhart"
# },
# "theme":{
# "plot_background":{
# "size":6.0,
# "blank":false
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..count..":[11.0,9.0,15.0,10.0,11.0,9.0,6.0,10.0,7.0,12.0],
# "x":[6.0,3.0,7.0,4.0,9.0,2.0,5.0,1.0,0.0,8.0]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("DawRLg");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Plot with Margins

# %%
p + theme(plot_margin=margin(t=20,  # Top
                             r=10,  # Right
                             b=10,  # Bottom
                             l=10)) # Left
# Out:
#    <div id="0qb8Fz"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Bar Сhart"
# },
# "theme":{
# "plot_background":{
# "size":6.0,
# "blank":false
# },
# "plot_margin":{
# "t":20.0,
# "r":10.0,
# "b":10.0,
# "l":10.0
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..count..":[11.0,9.0,15.0,10.0,11.0,9.0,6.0,10.0,7.0,12.0],
# "x":[6.0,3.0,7.0,4.0,9.0,2.0,5.0,1.0,0.0,8.0]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("0qb8Fz");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
