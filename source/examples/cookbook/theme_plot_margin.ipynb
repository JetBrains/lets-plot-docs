# %% [markdown]
# # Plot Margins
#
# `plot_margin` parameter in `theme()` allows to change the margin areas of a plot using the `margin()` function.

# %%
import numpy as np

from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="etPc62"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.1.0rc1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("etPc62").appendChild(div);
#                     };
#                     var e = document.getElementById("etPc62");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
np.random.seed(42)
data = {'x': np.random.randint(10, size=100)}

p = ggplot(data, aes(x='x')) + geom_bar() + theme(plot_background=element_rect(size = 1)) + ggtitle("Bar Сhart")
p
# Out:
#    <div id="4anYei"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# },
# "theme":{
# "plot_background":{
# "size":1.0,
# "blank":false
# }
# },
# "ggtitle":{
# "text":"Bar Сhart"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..count..":[11.0,9.0,15.0,10.0,11.0,9.0,6.0,10.0,7.0,12.0],
# "x":[6.0,3.0,7.0,4.0,9.0,2.0,5.0,1.0,0.0,8.0]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("4anYei");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
p + theme(plot_margin=margin(t=10,  # Top
                             r=20,  # Right
                             b=30,  # Bottom
                             l=40)) # Left
# Out:
#    <div id="Drb9RJ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# },
# "theme":{
# "plot_background":{
# "size":1.0,
# "blank":false
# },
# "plot_margin":{
# "t":10.0,
# "r":20.0,
# "b":30.0,
# "l":40.0
# }
# },
# "ggtitle":{
# "text":"Bar Сhart"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..count..":[11.0,9.0,15.0,10.0,11.0,9.0,6.0,10.0,7.0,12.0],
# "x":[6.0,3.0,7.0,4.0,9.0,2.0,5.0,1.0,0.0,8.0]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("Drb9RJ");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
