# %% [markdown]
# # Named System Colors
#
# The following named colors are available:
#
# * "pen" - access to the main drawing color of the current theme flavor
# * "paper" - access to the plot background of the current theme flavor
# * "brush" - default blue color
#
#
# These colors can be reassigned via parameter `geom` in `theme()`:
#
# `theme(geom=element_geom(pen=None, brush=None, paper=None)`
#
# where function `element_geom` allows to specify new values for the named colors.

# %%
from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="jh04xA"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("jh04xA").appendChild(div);
#                     };
#                     var e = document.getElementById("jh04xA");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
LetsPlot.set_theme(theme_grey())

# %%
df = {
  'name' : ['pen', 'brush', 'paper'],
  'slice': [1, 3, 3]
}

# %% [markdown]
# #### 1. Use Named System Colors

# %%
pie_chart = ggplot(df) + \
    geom_pie(aes(fill='name', slice='slice'),
             stat='identity',
             color='pen',
             tooltips='none', labels=layer_labels().line('@name')) + \
    scale_fill_manual(['pen', 'brush', 'paper'])
pie_chart
# Out:
#    <div id="HNv8Pl"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("HNv8Pl");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "name":["pen","brush","paper"],
# "slice":[1.0,3.0,3.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"slice"
# }]
# },
# "theme":{
# "name":"grey"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["pen","brush","paper"]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"slice"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "lines":["@name"]
# },
# "color":"pen",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### 2. With Theme Flavor

# %% [markdown]
# Let's check at the pie chart how the named colors look, including after applying different theme flavors.

# %%
gggrid([
    pie_chart + ggtitle("Default"),
    pie_chart + flavor_darcula() + ggtitle("darcula"),
    pie_chart + flavor_solarized_light() + ggtitle("solarized_light"),
    pie_chart + flavor_solarized_dark() + ggtitle("solarized_dark"),
    pie_chart + flavor_high_contrast_light() + ggtitle("high_contrast_light"),
    pie_chart + flavor_high_contrast_dark() + ggtitle("high_contrast_dark")
], ncol = 2)
# Out:
#    <div id="ihn8bj"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("ihn8bj");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "theme":{
# "name":"grey"
# },
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":3.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "name":["pen","brush","paper"],
# "slice":[1.0,3.0,3.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"slice"
# }]
# },
# "ggtitle":{
# "text":"Default"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["pen","brush","paper"]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"slice"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "lines":["@name"]
# },
# "color":"pen",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"2"
# },{
# "data":{
# "name":["pen","brush","paper"],
# "slice":[1.0,3.0,3.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"slice"
# }]
# },
# "theme":{
# "name":"grey",
# "flavor":"darcula"
# },
# "ggtitle":{
# "text":"darcula"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["pen","brush","paper"]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"slice"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "lines":["@name"]
# },
# "color":"pen",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"3"
# },{
# "data":{
# "name":["pen","brush","paper"],
# "slice":[1.0,3.0,3.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"slice"
# }]
# },
# "theme":{
# "name":"grey",
# "flavor":"solarized_light"
# },
# "ggtitle":{
# "text":"solarized_light"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["pen","brush","paper"]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"slice"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "lines":["@name"]
# },
# "color":"pen",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"4"
# },{
# "data":{
# "name":["pen","brush","paper"],
# "slice":[1.0,3.0,3.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"slice"
# }]
# },
# "theme":{
# "name":"grey",
# "flavor":"solarized_dark"
# },
# "ggtitle":{
# "text":"solarized_dark"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["pen","brush","paper"]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"slice"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "lines":["@name"]
# },
# "color":"pen",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"5"
# },{
# "data":{
# "name":["pen","brush","paper"],
# "slice":[1.0,3.0,3.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"slice"
# }]
# },
# "theme":{
# "name":"grey",
# "flavor":"high_contrast_light"
# },
# "ggtitle":{
# "text":"high_contrast_light"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["pen","brush","paper"]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"slice"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "lines":["@name"]
# },
# "color":"pen",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"6"
# },{
# "data":{
# "name":["pen","brush","paper"],
# "slice":[1.0,3.0,3.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"slice"
# }]
# },
# "theme":{
# "name":"grey",
# "flavor":"high_contrast_dark"
# },
# "ggtitle":{
# "text":"high_contrast_dark"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["pen","brush","paper"]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"slice"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "lines":["@name"]
# },
# "color":"pen",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"7"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# #### 3. `theme(geom = element_geom(pen, brush, paper))`

# %%
pie_chart + theme(geom=element_geom(pen='red', brush='green', paper='blue'))
# Out:
#    <div id="9Hsy1i"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("9Hsy1i");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "name":["pen","brush","paper"],
# "slice":[1.0,3.0,3.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"slice"
# }]
# },
# "theme":{
# "name":"grey",
# "geom":{
# "pen":"red",
# "brush":"green",
# "paper":"blue"
# }
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["pen","brush","paper"]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"slice"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "lines":["@name"]
# },
# "color":"pen",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"8"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ##### 3.1 `theme() + flavor()`

# %%
pie_chart + theme(geom=element_geom(pen='red', brush='green', paper='blue')) + flavor_solarized_light()
# Out:
#    <div id="U2bund"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("U2bund");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "name":["pen","brush","paper"],
# "slice":[1.0,3.0,3.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"slice"
# }]
# },
# "theme":{
# "name":"grey",
# "geom":{
# "pen":"red",
# "brush":"green",
# "paper":"blue"
# },
# "flavor":"solarized_light"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["pen","brush","paper"]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"slice"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "lines":["@name"]
# },
# "color":"pen",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"9"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ##### 3.2 `flavor() + theme()`

# %%
pie_chart + flavor_solarized_light() + theme(geom=element_geom(pen='red', brush='green', paper='blue'))
# Out:
#    <div id="5etyXl"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("5etyXl");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "name":["pen","brush","paper"],
# "slice":[1.0,3.0,3.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"slice"
# }]
# },
# "theme":{
# "name":"grey",
# "flavor":"solarized_light",
# "geom":{
# "pen":"red",
# "brush":"green",
# "paper":"blue"
# }
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["pen","brush","paper"]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"slice"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "lines":["@name"]
# },
# "color":"pen",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"10"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>
