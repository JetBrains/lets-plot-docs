# %% [markdown]
# # Named System Colors
#
# The following named colors are available:
#
# * "pen" - access to the main drawing color of the current theme flavor
# * "paper" - access to the plot background of the current theme flavor
# * "brush" - default blue color
#
#
# These colors can be reassigned via parameter `geom` in `theme()`:
#
# `theme(geom=element_geom(pen=None, brush=None, paper=None)`
#
# where function `element_geom` allows to specify new values for the named colors.

# %%
from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="rxhuID"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.4.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("rxhuID").appendChild(div);
#                     };
#                     var e = document.getElementById("rxhuID");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
LetsPlot.set_theme(theme_grey())

# %%
df = {
  'name' : ['pen', 'brush', 'paper'],
  'slice': [1, 3, 3]
}

# %% [markdown]
# #### 1. Use Named System Colors

# %%
pie_chart = ggplot(df) + \
    geom_pie(aes(fill='name', slice='slice'),
             stat='identity',
             color='pen',
             tooltips='none', labels=layer_labels().line('@name')) + \
    scale_fill_manual(['pen', 'brush', 'paper'])
pie_chart
# Out:
#    <div id="eIAYeC"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "name":["pen","brush","paper"],
# "slice":[1.0,3.0,3.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"slice"
# }]
# },
# "theme":{
# "name":"grey"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["pen","brush","paper"]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"slice"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "lines":["@name"]
# },
# "color":"pen",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("eIAYeC");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### 2. With Theme Flavor

# %% [markdown]
# Let's check at the pie chart how the named colors look, including after applying different theme flavors.

# %%
gggrid([
    pie_chart + ggtitle("Default"),
    pie_chart + flavor_darcula() + ggtitle("darcula"),
    pie_chart + flavor_solarized_light() + ggtitle("solarized_light"),
    pie_chart + flavor_solarized_dark() + ggtitle("solarized_dark"),
    pie_chart + flavor_high_contrast_light() + ggtitle("high_contrast_light"),
    pie_chart + flavor_high_contrast_dark() + ggtitle("high_contrast_dark")
], ncol = 2)
# Out:
#    <div id="zY4AFq"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "theme":{
# "name":"grey"
# },
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":3.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "name":["pen","brush","paper"],
# "slice":[1.0,3.0,3.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"slice"
# }]
# },
# "ggtitle":{
# "text":"Default"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["pen","brush","paper"]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"slice"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "lines":["@name"]
# },
# "color":"pen",
# "data":{
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# "name":["pen","brush","paper"],
# "slice":[1.0,3.0,3.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"slice"
# }]
# },
# "theme":{
# "name":"grey",
# "flavor":"darcula"
# },
# "ggtitle":{
# "text":"darcula"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["pen","brush","paper"]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"slice"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "lines":["@name"]
# },
# "color":"pen",
# "data":{
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# "name":["pen","brush","paper"],
# "slice":[1.0,3.0,3.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"slice"
# }]
# },
# "theme":{
# "name":"grey",
# "flavor":"solarized_light"
# },
# "ggtitle":{
# "text":"solarized_light"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["pen","brush","paper"]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"slice"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "lines":["@name"]
# },
# "color":"pen",
# "data":{
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# "name":["pen","brush","paper"],
# "slice":[1.0,3.0,3.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"slice"
# }]
# },
# "theme":{
# "name":"grey",
# "flavor":"solarized_dark"
# },
# "ggtitle":{
# "text":"solarized_dark"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["pen","brush","paper"]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"slice"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "lines":["@name"]
# },
# "color":"pen",
# "data":{
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# "name":["pen","brush","paper"],
# "slice":[1.0,3.0,3.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"slice"
# }]
# },
# "theme":{
# "name":"grey",
# "flavor":"high_contrast_light"
# },
# "ggtitle":{
# "text":"high_contrast_light"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["pen","brush","paper"]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"slice"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "lines":["@name"]
# },
# "color":"pen",
# "data":{
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# "name":["pen","brush","paper"],
# "slice":[1.0,3.0,3.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"slice"
# }]
# },
# "theme":{
# "name":"grey",
# "flavor":"high_contrast_dark"
# },
# "ggtitle":{
# "text":"high_contrast_dark"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["pen","brush","paper"]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"slice"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "lines":["@name"]
# },
# "color":"pen",
# "data":{
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("zY4AFq");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### 3. `theme(geom = element_geom(pen, brush, paper))`

# %%
pie_chart + theme(geom=element_geom(pen='red', brush='green', paper='blue'))
# Out:
#    <div id="3YTirN"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "name":["pen","brush","paper"],
# "slice":[1.0,3.0,3.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"slice"
# }]
# },
# "theme":{
# "name":"grey",
# "geom":{
# "pen":"red",
# "brush":"green",
# "paper":"blue"
# }
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["pen","brush","paper"]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"slice"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "lines":["@name"]
# },
# "color":"pen",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("3YTirN");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ##### 3.1 `theme() + flavor()`

# %%
pie_chart + theme(geom=element_geom(pen='red', brush='green', paper='blue')) + flavor_solarized_light()
# Out:
#    <div id="EDFz2n"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "name":["pen","brush","paper"],
# "slice":[1.0,3.0,3.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"slice"
# }]
# },
# "theme":{
# "name":"grey",
# "geom":{
# "pen":"red",
# "brush":"green",
# "paper":"blue"
# },
# "flavor":"solarized_light"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["pen","brush","paper"]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"slice"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "lines":["@name"]
# },
# "color":"pen",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("EDFz2n");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ##### 3.2 `flavor() + theme()`

# %%
pie_chart + flavor_solarized_light() + theme(geom=element_geom(pen='red', brush='green', paper='blue'))
# Out:
#    <div id="cWrpij"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "name":["pen","brush","paper"],
# "slice":[1.0,3.0,3.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"slice"
# }]
# },
# "theme":{
# "name":"grey",
# "flavor":"solarized_light",
# "geom":{
# "pen":"red",
# "brush":"green",
# "paper":"blue"
# }
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["pen","brush","paper"]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"slice"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "lines":["@name"]
# },
# "color":"pen",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("cWrpij");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
