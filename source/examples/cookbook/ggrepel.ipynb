# %% [markdown]
# # Dynamic Text Positioning with Repel Geometries
#
# - `geom_text_repel()`
# - `geom_label_repel()`
#
# These functions use a force-based layout algorithm to automatically reposition text labels and resolve overlaps.
#
# Labels repel each other and their associated data points while staying within the plot boundaries.

# %%
import random

import pandas as pd

from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="qBQD5j"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.7.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("qBQD5j").appendChild(div);
#                     };
#                     var e = document.getElementById("qBQD5j");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
df = pd.read_csv("https://gist.githubusercontent.com/seankross/a412dfbd88b3db70b74b/raw/5f23f993cd87c283ce766e7ac6b329ee7cc2e1d1/mtcars.csv")
print(df.shape)
df.head()
# Out:
# (32, 12)
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df1 = df[(2.0 < df["wt"])&(df["wt"] < 3.65)]
df2 = df[(2.0 < df["wt"])&(df["wt"] < 3)]
df2 = df2.assign(shape=df2["am"].map({0: 16, 1: 21}))

# %%
plot = ggplot(df1, aes("wt", "mpg", label="model")) + geom_point(color="red")
plot2 = ggplot(df2, aes("wt", "mpg", label="model")) + geom_point(color="red")

# %% [markdown]
# ### Comparison of geom_text() and geom_text_repel()

# %%
gggrid([
    plot2 + geom_text() + ggtitle("geom_text()"),
    plot2 + geom_text_repel() + ggtitle("geom_text_repel()"),
])
# Out:
#    <div id="HY0Tna"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("HY0Tna");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "ggtitle":{
# "text":"geom_text()"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# },{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "ggtitle":{
# "text":"geom_text_repel()"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"2"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ### geom_label_repel()
# All of the parameters discussed below apply equally to both `geom_text_repel()` and `geom_label_repel()`. For simplicity, we will use `geom_text_repel()` in the examples.

# %%
gggrid([
    plot2 + geom_label() + ggtitle("geom_label()"),
    plot2 + geom_label_repel() + ggtitle("geom_label_repel()"),
])
# Out:
#    <div id="Hc3S3P"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("Hc3S3P");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "ggtitle":{
# "text":"geom_label()"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"label",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"3"
# },{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "ggtitle":{
# "text":"geom_label_repel()"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"label_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"4"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ### `seed` parameter
#
# Controls the randomization to produce the same label layout each time the plot is generated.

# %%
gggrid([
    plot2 + geom_text_repel() + ggtitle("Without seed"),
    plot2 + geom_text_repel() + ggtitle("Without seed"),
    plot2 + geom_text_repel(seed=4) + ggtitle("With seed"),
    plot2 + geom_text_repel(seed=4) + ggtitle("With seed"),
], ncol=2)
# Out:
#    <div id="P72Xy3"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("P72Xy3");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "ggtitle":{
# "text":"Without seed"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"5"
# },{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "ggtitle":{
# "text":"Without seed"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"6"
# },{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "ggtitle":{
# "text":"With seed"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "seed":4.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"7"
# },{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "ggtitle":{
# "text":"With seed"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "seed":4.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"8"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# In some cases, it may be necessary to find a seed value that produces a more optimal label arrangement. A simple approach is to re-render the plot multiple times until you're satisfied with the result, then use the corresponding seed to reproduce it.

# %%
rand_int = random.randint(1, 1000)
print("seed = {0}".format(rand_int))
plot2 + geom_text_repel(seed=rand_int)
# Out:
# seed = 915
#    <div id="tbBHpq"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("tbBHpq");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "seed":915.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"9"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ### `max_iter` parameter
# Controls the maximum number of iterations used by the layout algorithm, helping to reduce notebook rendering time. More iterations generally lead to better label placement, but at the cost of increased computation time. For plots with a small number of labels, 200–300 iterations are often sufficient.
# The default value is 2000.

# %%
seed = 530
gggrid([
    plot2 + geom_text_repel(seed=seed, max_iter=2) + ggtitle("max_iter=2"),
    plot2 + geom_text_repel(seed=seed, max_iter=20) + ggtitle("max_iter=20"),
    plot2 + geom_text_repel(seed=seed, max_iter=200) + ggtitle("max_iter=200"),
])
# Out:
#    <div id="O3adCU"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("O3adCU");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "ggtitle":{
# "text":"max_iter=2"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "max_iter":2.0,
# "seed":530.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"10"
# },{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "ggtitle":{
# "text":"max_iter=20"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "max_iter":20.0,
# "seed":530.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"11"
# },{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "ggtitle":{
# "text":"max_iter=200"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "max_iter":200.0,
# "seed":530.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"12"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ### `max_time` parameter
# Another way to limit plot rendering time is by using the `max_time` parameter. This primarily serves as a safeguard against excessive computation when a large number of text labels are involved. Time is specified in seconds. The default value is `5` seconds, but you can disable the time limit by setting it to `-1` if needed.

# %%
gggrid([
    plot2 + geom_text_repel(seed=seed, max_time=0.001) + ggtitle("max_time=0.001"),
    plot2 + geom_text_repel(seed=seed, max_time=0.01) + ggtitle("max_time=0.01"),
    plot2 + geom_text_repel(seed=seed, max_time=-1) + ggtitle("max_time=-1"),
])
# Out:
#    <div id="XeAqat"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("XeAqat");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "ggtitle":{
# "text":"max_time=0.001"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "max_time":0.001,
# "seed":530.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"13"
# },{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "ggtitle":{
# "text":"max_time=0.01"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "max_time":0.01,
# "seed":530.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"14"
# },{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "ggtitle":{
# "text":"max_time=-1"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "max_time":-1.0,
# "seed":530.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"15"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ### `direction` parameter
# Restricts the movement of a text label relative to its anchor point to a specific direction. The default value is `both`.

# %%
gggrid([
    plot2 + geom_text_repel(seed=seed, direction="x") + ggtitle("direction = 'x'"),
    plot2 + geom_text_repel(seed=seed, direction="y") + ggtitle("direction = 'y'"),
    plot2 + geom_text_repel(seed=seed, direction="both") + ggtitle("direction = 'both'"),
])
# Out:
#    <div id="uax6Up"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("uax6Up");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "ggtitle":{
# "text":"direction = 'x'"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "seed":530.0,
# "direction":"x",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"16"
# },{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "ggtitle":{
# "text":"direction = 'y'"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "seed":530.0,
# "direction":"y",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"17"
# },{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "ggtitle":{
# "text":"direction = 'both'"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "seed":530.0,
# "direction":"both",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"18"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# As we can see, this option is of limited use for randomly scattered points, but in certain cases it can be extremely helpful:

# %%
plotX = ggplot(df2, aes(x="wt", label="model")) + \
    geom_point(y=1, color="red") + xlim(2, 3) + ylim(1, 1.3) + \
    geom_text_repel(
        y=1,
        nudge_y=0.05,
        direction="x",
        angle=90,
        hjust=0.0,
        seed=seed
    )

plotY = ggplot(df2, aes(y="mpg", label="model")) + \
    geom_point(x=1, color="red") + xlim(0.9, 1.3) + ylim(19, 35) + \
    geom_text_repel(
        x=1,
        nudge_x=0.05,
        direction="y",
        hjust=0.0,
        seed=seed
    )

gggrid([
    plotX + ggtitle("direction = x"),
    plotY + ggtitle("direction = y"),
])
# Out:
#    <div id="dthFyj"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("dthFyj");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "ggtitle":{
# "text":"direction = x"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "limits":[2.0,3.0]
# },{
# "aesthetic":"y",
# "limits":[1.0,1.3]
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "y":1.0,
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "nudge_y":0.05,
# "seed":530.0,
# "direction":"x",
# "y":1.0,
# "angle":90.0,
# "hjust":0.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"19"
# },{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4]
# },
# "mapping":{
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "ggtitle":{
# "text":"direction = y"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "limits":[0.9,1.3]
# },{
# "aesthetic":"y",
# "limits":[19.0,35.0]
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":1.0,
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "nudge_x":0.05,
# "seed":530.0,
# "direction":"y",
# "x":1.0,
# "hjust":0.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"20"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ### `point_padding` and `box_padding` parameters
# These parameters control the amount of spacing around text labels.
#
# - `point_padding` adds space between the label and all nearby points, but does not affect spacing between labels.
#
# - `box_padding` adds space between labels, but does not affect spacing between the label and the data point.

# %%
gggrid([
    plot2 + geom_text_repel(seed=seed, max_time=-1, point_padding=10) + ggtitle("point_padding"),
    plot2 + geom_text_repel(seed=seed, max_time=-1, box_padding=10) + ggtitle("box_padding"),
])
# Out:
#    <div id="olq1Ta"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("olq1Ta");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "ggtitle":{
# "text":"point_padding"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "max_time":-1.0,
# "seed":530.0,
# "point_padding":10.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"21"
# },{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "ggtitle":{
# "text":"box_padding"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "max_time":-1.0,
# "seed":530.0,
# "box_padding":10.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"22"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ### `max_overlaps` parameter
# Specifies the maximum allowed number of overlaps with other labels. Labels that exceed this threshold will be omitted from the plot. The default value is `10`. You can disable overlap filtering entirely by setting this parameter to `-1`.

# %%
gggrid([
    plot + geom_text_repel(seed=seed, max_time=-1, max_overlaps=5) + ggtitle("max_overlaps=5"),
    plot + geom_text_repel(seed=seed, max_time=-1, max_overlaps=-1) + ggtitle("max_overlaps=-1"),
])
# Out:
#    <div id="wxboyl"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("wxboyl");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Hornet 4 Drive","Hornet Sportabout","Valiant","Duster 360","Merc 240D","Merc 230","Merc 280","Merc 280C","Fiat 128","Toyota Corona","Dodge Challenger","AMC Javelin","Porsche 914-2","Ford Pantera L","Ferrari Dino","Maserati Bora","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,21.4,18.7,18.1,14.3,24.4,22.8,19.2,17.8,32.4,21.5,15.5,15.2,26.0,15.8,19.7,15.0,21.4],
# "wt":[2.62,2.875,2.32,3.215,3.44,3.46,3.57,3.19,3.15,3.44,3.44,2.2,2.465,3.52,3.435,2.14,3.17,2.77,3.57,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# }]
# },
# "ggtitle":{
# "text":"max_overlaps=5"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "max_time":-1.0,
# "seed":530.0,
# "max_overlaps":5.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"23"
# },{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Hornet 4 Drive","Hornet Sportabout","Valiant","Duster 360","Merc 240D","Merc 230","Merc 280","Merc 280C","Fiat 128","Toyota Corona","Dodge Challenger","AMC Javelin","Porsche 914-2","Ford Pantera L","Ferrari Dino","Maserati Bora","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,21.4,18.7,18.1,14.3,24.4,22.8,19.2,17.8,32.4,21.5,15.5,15.2,26.0,15.8,19.7,15.0,21.4],
# "wt":[2.62,2.875,2.32,3.215,3.44,3.46,3.57,3.19,3.15,3.44,3.44,2.2,2.465,3.52,3.435,2.14,3.17,2.77,3.57,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# }]
# },
# "ggtitle":{
# "text":"max_overlaps=-1"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "max_time":-1.0,
# "seed":530.0,
# "max_overlaps":-1.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"24"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ### `min_segment_length` parameter
# Sets the minimum length for the line connecting a label to its associated point. Lines shorter than this length will not be drawn. To display all lines, use the default value of `0`. To hide all lines, set the value to something very large.
# `min_segment_length` uses the same units as `point_size`, so be careful when using `min_segment_length` together with `size_unit` (see below).

# %%
gggrid([
    plot + geom_text_repel(seed=seed, max_time=-1, min_segment_length=0) + ggtitle("min_segment_length=0"),
    plot + geom_text_repel(seed=seed, max_time=-1, min_segment_length=9999) + ggtitle("min_segment_length=9999"),
])
# Out:
#    <div id="WiGiGG"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("WiGiGG");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Hornet 4 Drive","Hornet Sportabout","Valiant","Duster 360","Merc 240D","Merc 230","Merc 280","Merc 280C","Fiat 128","Toyota Corona","Dodge Challenger","AMC Javelin","Porsche 914-2","Ford Pantera L","Ferrari Dino","Maserati Bora","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,21.4,18.7,18.1,14.3,24.4,22.8,19.2,17.8,32.4,21.5,15.5,15.2,26.0,15.8,19.7,15.0,21.4],
# "wt":[2.62,2.875,2.32,3.215,3.44,3.46,3.57,3.19,3.15,3.44,3.44,2.2,2.465,3.52,3.435,2.14,3.17,2.77,3.57,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# }]
# },
# "ggtitle":{
# "text":"min_segment_length=0"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "max_time":-1.0,
# "seed":530.0,
# "min_segment_length":0.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"25"
# },{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Hornet 4 Drive","Hornet Sportabout","Valiant","Duster 360","Merc 240D","Merc 230","Merc 280","Merc 280C","Fiat 128","Toyota Corona","Dodge Challenger","AMC Javelin","Porsche 914-2","Ford Pantera L","Ferrari Dino","Maserati Bora","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,21.4,18.7,18.1,14.3,24.4,22.8,19.2,17.8,32.4,21.5,15.5,15.2,26.0,15.8,19.7,15.0,21.4],
# "wt":[2.62,2.875,2.32,3.215,3.44,3.46,3.57,3.19,3.15,3.44,3.44,2.2,2.465,3.52,3.435,2.14,3.17,2.77,3.57,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# }]
# },
# "ggtitle":{
# "text":"min_segment_length=9999"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "max_time":-1.0,
# "seed":530.0,
# "min_segment_length":9999.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"26"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ## Point settings
# geom_text_repel() does not draw points itself, but for it to work correctly, the values of parameters and aesthetics that control point size must match those used in the associated geom_point() layer.

# %%
ggplot(df2, aes("wt", "mpg", label="model")) + theme(legend_position="none") + \
    scale_size(range=[0.5,1], guide="none") + \
    scale_stroke(range=[1,4], guide="none") + \
    scale_shape_identity() + \
    geom_point(aes(size="gear", stroke="vs", shape="shape"), size_unit="y") + \
    geom_text_repel(aes(point_size="gear", point_stroke="vs", shape="shape"), size_unit="y")
# Out:
#    <div id="3HLggl"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("3HLggl");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78],
# "vs":[0.0,0.0,1.0,1.0,1.0,0.0,0.0,1.0],
# "gear":[4.0,4.0,4.0,4.0,3.0,5.0,5.0,4.0],
# "shape":[21.0,21.0,21.0,21.0,16.0,21.0,21.0,21.0]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "theme":{
# "legend_position":"none"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"size",
# "guide":"none",
# "range":[0.5,1.0]
# },{
# "aesthetic":"stroke",
# "guide":"none",
# "range":[1.0,4.0]
# },{
# "aesthetic":"shape",
# "guide":"none",
# "scale_mapper_kind":"identity",
# "discrete":true
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# "size":"gear",
# "stroke":"vs",
# "shape":"shape"
# },
# "data_meta":{
# },
# "size_unit":"y",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# "point_size":"gear",
# "point_stroke":"vs",
# "shape":"shape"
# },
# "data_meta":{
# },
# "size_unit":"y",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"27"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ### `point_size` aesthetic
# Allows you to pass to geom_text_repel() the data used to determine point sizes in a geom_point() layer. This helps accurately detect overlaps between labels and points when point sizes vary.

# %%
plot31 = ggplot(df2, aes("wt", "mpg", label="model")) + \
    geom_point(aes(size="gear"), color="red") + \
    theme(legend_position="none")

gggrid([
    plot31 + geom_text_repel(seed=seed, max_time=-1) + ggtitle("without point_size"),
    plot31 + geom_text_repel(aes(point_size="gear"), seed=seed, max_time=-1) + ggtitle("with point_size"),
])
# Out:
#    <div id="hfqLdH"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("hfqLdH");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78],
# "gear":[4.0,4.0,4.0,4.0,3.0,5.0,5.0,4.0]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "theme":{
# "legend_position":"none"
# },
# "ggtitle":{
# "text":"without point_size"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "size":"gear"
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "max_time":-1.0,
# "seed":530.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"28"
# },{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78],
# "gear":[4.0,4.0,4.0,4.0,3.0,5.0,5.0,4.0]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "theme":{
# "legend_position":"none"
# },
# "ggtitle":{
# "text":"with point_size"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "size":"gear"
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# "point_size":"gear"
# },
# "data_meta":{
# },
# "max_time":-1.0,
# "seed":530.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"29"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# You can also provide a constant value instead.

# %%
plot32 = ggplot(df2, aes("wt", "mpg", label="model")) + \
    geom_point(size=10, color="red") + \
    theme(legend_position="none")

gggrid([
    plot32 + geom_text_repel(seed=seed, max_time=-1) + ggtitle("without point_size"),
    plot32 + geom_text_repel(seed=seed, max_time=-1, point_size=10) + ggtitle("with point_size"),
])
# Out:
#    <div id="366rEn"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("366rEn");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "theme":{
# "legend_position":"none"
# },
# "ggtitle":{
# "text":"without point_size"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":10.0,
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "max_time":-1.0,
# "seed":530.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"30"
# },{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "theme":{
# "legend_position":"none"
# },
# "ggtitle":{
# "text":"with point_size"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":10.0,
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "max_time":-1.0,
# "seed":530.0,
# "point_size":10.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"31"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ### `point_stroke` and `shape` aesthetics
# Allow you to pass to geom_text_repel() the data used to determine point stroke width and shape in a geom_point() layer. This ensures accurate collision detection between labels and points.

# %%
plot33 = ggplot(df2, aes("wt", "mpg", label="model")) + \
    geom_point(aes(stroke="gear"), shape=21, size=10, color="red") + \
    theme(legend_position="none")

gggrid([
    plot33 + geom_text_repel(seed=seed, max_time=-1, point_size=10) + ggtitle("without point_stroke"),
    plot33 + geom_text_repel(aes(point_stroke="gear"), shape=21, point_size=10, seed=seed, max_time=-1) + ggtitle("with point_stroke"),
])
# Out:
#    <div id="ryxfz5"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("ryxfz5");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78],
# "gear":[4.0,4.0,4.0,4.0,3.0,5.0,5.0,4.0]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "theme":{
# "legend_position":"none"
# },
# "ggtitle":{
# "text":"without point_stroke"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "stroke":"gear"
# },
# "data_meta":{
# },
# "shape":21.0,
# "size":10.0,
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "max_time":-1.0,
# "seed":530.0,
# "point_size":10.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"32"
# },{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78],
# "gear":[4.0,4.0,4.0,4.0,3.0,5.0,5.0,4.0]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "theme":{
# "legend_position":"none"
# },
# "ggtitle":{
# "text":"with point_stroke"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "stroke":"gear"
# },
# "data_meta":{
# },
# "shape":21.0,
# "size":10.0,
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# "point_stroke":"gear"
# },
# "data_meta":{
# },
# "max_time":-1.0,
# "seed":530.0,
# "shape":21.0,
# "point_size":10.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"33"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ### `size_unit` parameter
# The `size_unit` parameter can be used in `geom_point()` to define the unit of measurement for the `size` aesthetic. In this case, it is recommended to also use `size_unit` in `geom_text_repel()` to ensure that point sizes are calculated correctly.

# %%
plot4 = ggplot(df2, aes("wt", "mpg", label="model")) + \
    geom_point(size=1, size_unit="y", color="red") + \
    theme(legend_position="none")

gggrid([
    plot4 + geom_text_repel(seed=seed, max_time=-1, point_size=1) + ggtitle("without size_unit"),
    plot4 + geom_text_repel(seed=seed, max_time=-1, point_size=1, size_unit="y") + ggtitle("with size_unit"),
]) + ggtb()
# Out:
#    <div id="KitDxV"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("KitDxV");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "ggtoolbar":{
# },
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "theme":{
# "legend_position":"none"
# },
# "ggtitle":{
# "text":"without size_unit"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size_unit":"y",
# "size":1.0,
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "max_time":-1.0,
# "seed":530.0,
# "point_size":1.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"34"
# },{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "theme":{
# "legend_position":"none"
# },
# "ggtitle":{
# "text":"with size_unit"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size_unit":"y",
# "size":1.0,
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "size_unit":"y",
# "max_time":-1.0,
# "seed":530.0,
# "point_size":1.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"35"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ##### `size_unit` applies to all size-related parameters: `point_size`, `min_segment_length`, `point_padding`, and `box_padding`.
# As an example, consider how it affects `min_segment_length`.
# As mentioned earlier, `min_segment_length` uses the same units as `point_size`. Therefore, in the following example, with the same `min_segment_length` value, some lines are not drawn in the second case because their length is less than one unit along the y-axis.

# %%
plot5 = ggplot(df2, aes("wt", "mpg", label="model")) + \
    theme(legend_position="none")

gggrid([
    plot5 + geom_point(size=10, color="red") + \
        geom_text_repel(seed=seed, max_time=-1, point_size=10, min_segment_length=1) + ggtitle("without size_unit"),
    plot5 + geom_point(size=1, size_unit="y", color="red") + \
        geom_text_repel(seed=seed, max_time=-1, point_size=1, min_segment_length=1, size_unit="y") + ggtitle("with size_unit"),
]) + ggtb()
# Out:
#    <div id="AZJZiT"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("AZJZiT");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "ggtoolbar":{
# },
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "theme":{
# "legend_position":"none"
# },
# "ggtitle":{
# "text":"without size_unit"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size":10.0,
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "max_time":-1.0,
# "seed":530.0,
# "min_segment_length":1.0,
# "point_size":10.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"36"
# },{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "theme":{
# "legend_position":"none"
# },
# "ggtitle":{
# "text":"with size_unit"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "size_unit":"y",
# "size":1.0,
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "size_unit":"y",
# "max_time":-1.0,
# "seed":530.0,
# "min_segment_length":1.0,
# "point_size":1.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"37"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ### `segment_color` aesthetic
# Allows you to specify the color of the line connecting the label to the point. By default, the line color matches the text color and follows the `color` aesthetic. In the example below, the `color` aesthetic is defined globally for all layers, so the colors of the points, text, and lines are the same.

# %%
ggplot(df2, aes("wt", "mpg", label="model", color="wt")) + geom_point() + geom_text_repel(seed=seed, max_time=-1)
# Out:
#    <div id="2DKzFY"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("2DKzFY");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model",
# "color":"wt"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "max_time":-1.0,
# "seed":530.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"38"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# By using the `color` and `segment_color` aesthetics together, you can assign different colors to the points, labels, and connecting lines.

# %%
plot6 = ggplot(df2, aes("wt", "mpg", label="model")) + theme(legend_position="none")

gggrid([
    plot6 + geom_point(aes(color="wt")) + \
        geom_text_repel(aes(segment_color="wt"), seed=seed, max_time=-1) + \
        ggtitle("Same color for points and lines"),
    plot6 + geom_point(color="red") + \
        geom_text_repel(aes(color="wt"), seed=seed, max_time=-1) + \
        ggtitle("Same color for text and line"),
    plot6 + geom_point(color="red") + \
        geom_text_repel(color="green", segment_color="blue", seed=seed, max_time=-1) + \
        ggtitle("Different colors"),
])
# Out:
#    <div id="knmVt1"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("knmVt1");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "theme":{
# "legend_position":"none"
# },
# "ggtitle":{
# "text":"Same color for points and lines"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "color":"wt"
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# "segment_color":"wt"
# },
# "data_meta":{
# },
# "max_time":-1.0,
# "seed":530.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"39"
# },{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "theme":{
# "legend_position":"none"
# },
# "ggtitle":{
# "text":"Same color for text and line"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# "color":"wt"
# },
# "data_meta":{
# },
# "max_time":-1.0,
# "seed":530.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"40"
# },{
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "theme":{
# "legend_position":"none"
# },
# "ggtitle":{
# "text":"Different colors"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "max_time":-1.0,
# "seed":530.0,
# "color":"green",
# "segment_color":"blue",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"41"
# }]
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ### `segment_alpha` aesthetic
#
# Specifies the transparency level of the connecting lines between labels and points. By default, the segment transparency inherits from the text and is governed by the `alpha` aesthetic.

# %%
ggplot(df2, aes("wt", "mpg", label="model")) + \
    geom_point(color="red") + \
    geom_text_repel(point_padding=20, color="red", segment_alpha=0.1, seed=seed, max_time=-1)
# Out:
#    <div id="yjgw0e"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("yjgw0e");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "max_time":-1.0,
# "seed":530.0,
# "point_padding":20.0,
# "color":"red",
# "segment_alpha":0.1,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"42"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ### `segment_size` aesthetic
# Specifies the width of the line connecting the label to the point.

# %%
plot2 + geom_text_repel(segment_size=2, seed=seed, max_time=-1)
# Out:
#    <div id="FdzUGT"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("FdzUGT");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "wt":[2.62,2.875,2.32,2.2,2.465,2.14,2.77,2.78]
# },
# "mapping":{
# "x":"wt",
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "max_time":-1.0,
# "seed":530.0,
# "segment_size":2.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"43"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ### `linetype` aesthetic

# %%
ggplot(df2, aes(y="mpg", label="model")) + geom_point(x=1, color="red") + xlim(0.9, 1.3) + ylim(19, 35) + \
    geom_text_repel(
        aes(linetype="disp"),
        x=1,
        nudge_x=0.2,
        direction="y",
        hjust=0.0,
        seed=seed
    )
# Out:
#    <div id="1cvYue"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("1cvYue");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4],
# "disp":[160.0,160.0,108.0,78.7,120.1,120.3,145.0,121.0]
# },
# "mapping":{
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "limits":[0.9,1.3]
# },{
# "aesthetic":"y",
# "limits":[19.0,35.0]
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":1.0,
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# "linetype":"disp"
# },
# "data_meta":{
# },
# "nudge_x":0.2,
# "seed":530.0,
# "direction":"y",
# "x":1.0,
# "hjust":0.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"44"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# ### `arrow` parameter

# %%
ggplot(df2, aes(y="mpg", label="model")) + geom_point(x=1, color="red") + xlim(0.9, 1.3) + ylim(19, 35) + \
    geom_text_repel(
        x=1,
        nudge_x=0.2,
        direction="y",
        hjust=0.0,
        arrow=arrow(type="closed", angle=10, ends="both"),
        seed=seed
    )
# Out:
#    <div id="ZmJNB3"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("ZmJNB3");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "model":["Mazda RX4","Mazda RX4 Wag","Datsun 710","Fiat 128","Toyota Corona","Porsche 914-2","Ferrari Dino","Volvo 142E"],
# "mpg":[21.0,21.0,22.8,32.4,21.5,26.0,19.7,21.4]
# },
# "mapping":{
# "y":"mpg",
# "label":"model"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"mpg"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"float",
# "column":"disp"
# },{
# "type":"int",
# "column":"hp"
# },{
# "type":"float",
# "column":"drat"
# },{
# "type":"float",
# "column":"wt"
# },{
# "type":"float",
# "column":"qsec"
# },{
# "type":"int",
# "column":"vs"
# },{
# "type":"int",
# "column":"am"
# },{
# "type":"int",
# "column":"gear"
# },{
# "type":"int",
# "column":"carb"
# },{
# "type":"int",
# "column":"shape"
# }]
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "limits":[0.9,1.3]
# },{
# "aesthetic":"y",
# "limits":[19.0,35.0]
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "x":1.0,
# "color":"red",
# "data":{
# }
# },{
# "geom":"text_repel",
# "mapping":{
# },
# "data_meta":{
# },
# "nudge_x":0.2,
# "seed":530.0,
# "direction":"y",
# "arrow":{
# "name":"arrow",
# "angle":10.0,
# "ends":"both",
# "type":"closed"
# },
# "x":1.0,
# "hjust":0.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"45"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>
