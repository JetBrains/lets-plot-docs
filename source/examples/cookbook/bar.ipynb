# %%
import pandas as pd

from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="OOpEDA"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.0.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("OOpEDA").appendChild(div);
#                     };
#                     var e = document.getElementById("OOpEDA");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
mpg_df=pd.read_csv('https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/mpg.csv')

# %%
ggplot(mpg_df, aes(x='class')) + \
    geom_bar(aes(fill='class'), alpha=.8) + \
    scale_fill_discrete()
# Out:
#    <div id="Dyzf5w"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"class"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "discrete":true
# }],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "fill":"class"
# },
# "data_meta":{
# },
# "alpha":0.8,
# "data":{
# "..count..":[47.0,41.0,62.0,5.0,11.0,33.0,35.0],
# "class":["compact","midsize","suv","2seater","minivan","pickup","subcompact"]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("Dyzf5w");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
ggplot(mpg_df) + \
    geom_bar(aes(x='cyl', fill='drv'), color='white', size=0.5)
# Out:
#    <div id="LpmM8e"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"cyl",
# "fill":"drv"
# },
# "data_meta":{
# },
# "color":"white",
# "size":0.5,
# "data":{
# "..count..":[58.0,43.0,1.0,4.0,23.0,32.0,48.0,21.0,4.0],
# "cyl":[4.0,6.0,8.0,5.0,4.0,6.0,8.0,8.0,6.0],
# "drv":["f","f","f","f","4","4","4","r","r"]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("LpmM8e");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
ggplot(mpg_df) + \
    geom_bar(aes(x='cyl', fill='drv'), position='dodge')
# Out:
#    <div id="2e7s98"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "x":"cyl",
# "fill":"drv"
# },
# "position":"dodge",
# "data_meta":{
# },
# "data":{
# "..count..":[58.0,43.0,1.0,4.0,23.0,32.0,48.0,21.0,4.0],
# "cyl":[4.0,6.0,8.0,5.0,4.0,6.0,8.0,8.0,6.0],
# "drv":["f","f","f","f","4","4","4","r","r"]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("2e7s98");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
results = {'rating': [5, 4, 3, 4, 3, 4, 5, 3, 5, 3, 4, 3]}

# %%
ggplot(results, aes(x='rating')) + geom_bar(aes(y='..count..',fill='..count..'), width=0.85) + \
    scale_fill_discrete()
# Out:
#    <div id="d0qDo2"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"rating"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "discrete":true
# }],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "y":"..count..",
# "fill":"..count.."
# },
# "data_meta":{
# },
# "width":0.85,
# "data":{
# "..count..":[3.0,4.0,5.0],
# "rating":[5.0,4.0,3.0]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("d0qDo2");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
