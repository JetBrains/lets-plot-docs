# %% [markdown]
# # Comparison of Charting Libraries Performance

# %%
import pandas as pd

from lets_plot import *
from lets_plot.mapping import as_discrete
LetsPlot.setup_html()
# Out:
#             <div id="bazLLQ"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.5.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("bazLLQ").appendChild(div);
#                     };
#                     var e = document.getElementById("bazLLQ");
#                     e.appendChild(script);
#                 })()
#             </script>

# %% [markdown]
# ### Preliminaries

# %%
def get_json_data(file_path):
    from requests import get

    r = get(file_path, stream=True)
    if r.status_code == 200:
        return r.json()
    else:
        return {}

def get_data(file_path):
    colors = {
        'LightningChart': '#e41a1c',
        'Plotly.js': '#4daf4a',
        'Canvas.js': '#ff7f00',
        'eCharts': '#ffff33',
        'Lets-Plot groups': '#377eb8',
        'Lets-Plot layers': '#984ea3',
    }
    data = {
        'test': [],
        'lib': [],
        'channels_count': [],
        'channel_data_points_per_second': [],
        'time_domain_interval': [],
        'loadup_speed_ms': [],
        'fps_avg': [],
        'fps_median': [],
        'frame_time_avg': [],
        'frame_time_median': [],
        'color': [],
    }
    for test, test_data in get_json_data(file_path).items():
        for lib, test_lib_data in test_data.items():
            data['test'].append(test)
            data['lib'].append(lib)
            data['channels_count'].append(test_lib_data['config']['channelsCount'])
            data['channel_data_points_per_second'].append(test_lib_data['config']['channelDataPointsPerSecond'])
            data['time_domain_interval'].append(test_lib_data['config']['timeDomainInterval'])
            data['loadup_speed_ms'].append(test_lib_data['loadupSpeedMs'])
            data['fps_avg'].append(test_lib_data['fps']['avg'])
            data['fps_median'].append(test_lib_data['fps']['median'])
            data['frame_time_avg'].append(test_lib_data['frameTime']['avg'])
            data['frame_time_median'].append(test_lib_data['frameTime']['median'])
            data['color'].append(colors[lib])
    return pd.DataFrame.from_dict(data)

# %%
df = get_data("https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/lib_comparison.json")
df['load'] = df['channels_count'] * df['time_domain_interval']
df.head(6)
# Out:
#   test               lib  channels_count  channel_data_points_per_second  \
# 0    A    LightningChart               1                            1000
# 1    A         Plotly.js               1                            1000
# 2    A         Canvas.js               1                            1000
# 3    A           eCharts               1                            1000
# 4    A  Lets-Plot groups               1                            1000
# 5    A  Lets-Plot layers               1                            1000
#
#    time_domain_interval  loadup_speed_ms    fps_avg  fps_median  \
# 0                  1000            101.7  58.412474   58.259538
# 1                  1000             92.7  40.252554   40.922497
# 2                  1000            101.5  23.045579   23.116954
# 3                  1000             48.0  59.155815   59.053692
# 4                  1000             68.1  49.928318   51.291719
# 5                  1000            104.9  57.002319   58.007307
#
#    frame_time_avg  frame_time_median    color  load
# 0       17.258501              16.90  #e41a1c  1000
# 1       30.025803              24.25  #4daf4a  1000
# 2       43.772100              43.10  #ff7f00  1000
# 3       16.941370              17.00  #ffff33  1000
# 4       19.021224              18.00  #377eb8  1000
# 5       17.057078              17.00  #984ea3  1000

# %% [markdown]
# Here "Lets-Plot groups" is a realization of the benchmark in which each data channel corresponds to a group in aesthetics. In "Lets-Plot layers" each data channel corresponds to a plot layer.

# %%
def comparison1(col):
    return ggplot(df) + \
        geom_line(aes('load', col, color='color'), size=2, \
                  tooltips=layer_tooltips().line('@lib').format(col, '.2f').line('{0}|@{0}'.format(col))) + \
        scale_x_log10() + scale_color_identity() + \
        ggtitle('Comparison of {0} through load increasing'.format(col))

def comparison2(col):
    return ggplot(df) + \
        geom_bar(aes(as_discrete('lib', order_by=col, order=1), col, fill='color'), stat='identity', \
                 tooltips=layer_tooltips().line('@lib').format(col, '.2f').line('{0}|@{0}'.format(col))) + \
        facet_grid(x='test') + \
        scale_fill_identity() + \
        coord_flip() + \
        ggtitle('Comparison of {0} through tests'.format(col)) + \
        theme_classic() + \
        theme(axis_line_y='blank', axis_ticks_y='blank', axis_text_y='blank', \
              strip_background='blank')

# %% [markdown]
# ### Comparison Charts

# %%
comparison1('loadup_speed_ms')
# Out:
#    <div id="1Botuo"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "lib":["LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers","LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers","LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers"],
# "loadup_speed_ms":[101.70000000298023,92.69999999925494,101.5,48.0,68.09999999776483,104.90000000223517,77.39999999850988,123.19999999925494,179.5,120.19999999925494,283.5,225.29999999701977,99.40000000223517,235.69999999925494,886.5999999977648,301.30000000074506,688.0,548.6999999992549],
# "color":["#e41a1c","#4daf4a","#ff7f00","#ffff33","#377eb8","#984ea3","#e41a1c","#4daf4a","#ff7f00","#ffff33","#377eb8","#984ea3","#e41a1c","#4daf4a","#ff7f00","#ffff33","#377eb8","#984ea3"],
# "load":[1000.0,1000.0,1000.0,1000.0,1000.0,1000.0,10000.0,10000.0,10000.0,10000.0,10000.0,10000.0,100000.0,100000.0,100000.0,100000.0,100000.0,100000.0]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Comparison of loadup_speed_ms through load increasing"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "trans":"log10"
# },{
# "aesthetic":"color",
# "guide":"none",
# "scale_mapper_kind":"identity"
# }],
# "layers":[{
# "geom":"line",
# "mapping":{
# "x":"load",
# "y":"loadup_speed_ms",
# "color":"color"
# },
# "tooltips":{
# "tooltip_formats":[{
# "field":"loadup_speed_ms",
# "format":".2f"
# }],
# "tooltip_lines":["@lib","loadup_speed_ms|@loadup_speed_ms"]
# },
# "data_meta":{
# },
# "size":2,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("1Botuo");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
comparison1('fps_avg')
# Out:
#    <div id="oTpeEj"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "lib":["LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers","LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers","LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers"],
# "fps_avg":[58.41247378739938,40.25255391220948,23.045579171890523,59.15581487332924,49.92831815567785,57.00231862477561,58.35075926529889,14.23815425768082,13.060580228003026,58.166643531097336,17.609254187195965,24.803138456444703,32.50563451904698,2.7291637199236027,2.7057610114803996,10.276482175570862,2.42716089923178,3.093920768933406],
# "color":["#e41a1c","#4daf4a","#ff7f00","#ffff33","#377eb8","#984ea3","#e41a1c","#4daf4a","#ff7f00","#ffff33","#377eb8","#984ea3","#e41a1c","#4daf4a","#ff7f00","#ffff33","#377eb8","#984ea3"],
# "load":[1000.0,1000.0,1000.0,1000.0,1000.0,1000.0,10000.0,10000.0,10000.0,10000.0,10000.0,10000.0,100000.0,100000.0,100000.0,100000.0,100000.0,100000.0]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Comparison of fps_avg through load increasing"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "trans":"log10"
# },{
# "aesthetic":"color",
# "guide":"none",
# "scale_mapper_kind":"identity"
# }],
# "layers":[{
# "geom":"line",
# "mapping":{
# "x":"load",
# "y":"fps_avg",
# "color":"color"
# },
# "tooltips":{
# "tooltip_formats":[{
# "field":"fps_avg",
# "format":".2f"
# }],
# "tooltip_lines":["@lib","fps_avg|@fps_avg"]
# },
# "data_meta":{
# },
# "size":2,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("oTpeEj");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
comparison1('frame_time_avg')
# Out:
#    <div id="28nauh"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "lib":["LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers","LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers","LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers"],
# "frame_time_avg":[17.258501440922192,30.0258032128544,43.77209985315822,16.94136955291581,19.0212237093695,17.057077625570777,17.24988479262501,149.27661691541178,72.18300970873425,16.94676503972716,54.28555758684274,39.01861074705502,30.621596724668112,1142.3730769230483,361.4139240506235,94.7701923076947,411.3942028985399,311.1720430107527],
# "color":["#e41a1c","#4daf4a","#ff7f00","#ffff33","#377eb8","#984ea3","#e41a1c","#4daf4a","#ff7f00","#ffff33","#377eb8","#984ea3","#e41a1c","#4daf4a","#ff7f00","#ffff33","#377eb8","#984ea3"],
# "load":[1000.0,1000.0,1000.0,1000.0,1000.0,1000.0,10000.0,10000.0,10000.0,10000.0,10000.0,10000.0,100000.0,100000.0,100000.0,100000.0,100000.0,100000.0]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Comparison of frame_time_avg through load increasing"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "trans":"log10"
# },{
# "aesthetic":"color",
# "guide":"none",
# "scale_mapper_kind":"identity"
# }],
# "layers":[{
# "geom":"line",
# "mapping":{
# "x":"load",
# "y":"frame_time_avg",
# "color":"color"
# },
# "tooltips":{
# "tooltip_formats":[{
# "field":"frame_time_avg",
# "format":".2f"
# }],
# "tooltip_lines":["@lib","frame_time_avg|@frame_time_avg"]
# },
# "data_meta":{
# },
# "size":2,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("28nauh");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
comparison2('loadup_speed_ms')
# Out:
#    <div id="0Jx4PM"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "test":["A","A","A","A","A","A","B","B","B","B","B","B","C","C","C","C","C","C"],
# "lib":["LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers","LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers","LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers"],
# "loadup_speed_ms":[101.70000000298023,92.69999999925494,101.5,48.0,68.09999999776483,104.90000000223517,77.39999999850988,123.19999999925494,179.5,120.19999999925494,283.5,225.29999999701977,99.40000000223517,235.69999999925494,886.5999999977648,301.30000000074506,688.0,548.6999999992549],
# "color":["#e41a1c","#4daf4a","#ff7f00","#ffff33","#377eb8","#984ea3","#e41a1c","#4daf4a","#ff7f00","#ffff33","#377eb8","#984ea3","#e41a1c","#4daf4a","#ff7f00","#ffff33","#377eb8","#984ea3"]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "facet":{
# "name":"grid",
# "x":"test",
# "x_order":1,
# "y_order":1
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "ggtitle":{
# "text":"Comparison of loadup_speed_ms through tests"
# },
# "theme":{
# "name":"classic",
# "axis_text_y":"blank",
# "axis_ticks_y":"blank",
# "axis_line_y":"blank",
# "strip_background":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "guide":"none",
# "scale_mapper_kind":"identity"
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# "x":"@as_discrete@lib",
# "y":"loadup_speed_ms",
# "fill":"color"
# },
# "tooltips":{
# "tooltip_formats":[{
# "field":"loadup_speed_ms",
# "format":".2f"
# }],
# "tooltip_lines":["@lib","loadup_speed_ms|@loadup_speed_ms"]
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"lib",
# "order_by":"loadup_speed_ms",
# "order":1
# }
# }]
# },
# "data":{
# "@as_discrete@lib":["LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers","LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers","LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers"]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("0Jx4PM");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
comparison2('fps_avg')
# Out:
#    <div id="um6QsZ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "test":["A","A","A","A","A","A","B","B","B","B","B","B","C","C","C","C","C","C"],
# "lib":["LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers","LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers","LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers"],
# "fps_avg":[58.41247378739938,40.25255391220948,23.045579171890523,59.15581487332924,49.92831815567785,57.00231862477561,58.35075926529889,14.23815425768082,13.060580228003026,58.166643531097336,17.609254187195965,24.803138456444703,32.50563451904698,2.7291637199236027,2.7057610114803996,10.276482175570862,2.42716089923178,3.093920768933406],
# "color":["#e41a1c","#4daf4a","#ff7f00","#ffff33","#377eb8","#984ea3","#e41a1c","#4daf4a","#ff7f00","#ffff33","#377eb8","#984ea3","#e41a1c","#4daf4a","#ff7f00","#ffff33","#377eb8","#984ea3"]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "facet":{
# "name":"grid",
# "x":"test",
# "x_order":1,
# "y_order":1
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "ggtitle":{
# "text":"Comparison of fps_avg through tests"
# },
# "theme":{
# "name":"classic",
# "axis_text_y":"blank",
# "axis_ticks_y":"blank",
# "axis_line_y":"blank",
# "strip_background":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "guide":"none",
# "scale_mapper_kind":"identity"
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# "x":"@as_discrete@lib",
# "y":"fps_avg",
# "fill":"color"
# },
# "tooltips":{
# "tooltip_formats":[{
# "field":"fps_avg",
# "format":".2f"
# }],
# "tooltip_lines":["@lib","fps_avg|@fps_avg"]
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"lib",
# "order_by":"fps_avg",
# "order":1
# }
# }]
# },
# "data":{
# "@as_discrete@lib":["LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers","LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers","LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers"]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("um6QsZ");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
comparison2('frame_time_avg')
# Out:
#    <div id="dypSCs"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "test":["A","A","A","A","A","A","B","B","B","B","B","B","C","C","C","C","C","C"],
# "lib":["LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers","LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers","LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers"],
# "frame_time_avg":[17.258501440922192,30.0258032128544,43.77209985315822,16.94136955291581,19.0212237093695,17.057077625570777,17.24988479262501,149.27661691541178,72.18300970873425,16.94676503972716,54.28555758684274,39.01861074705502,30.621596724668112,1142.3730769230483,361.4139240506235,94.7701923076947,411.3942028985399,311.1720430107527],
# "color":["#e41a1c","#4daf4a","#ff7f00","#ffff33","#377eb8","#984ea3","#e41a1c","#4daf4a","#ff7f00","#ffff33","#377eb8","#984ea3","#e41a1c","#4daf4a","#ff7f00","#ffff33","#377eb8","#984ea3"]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "facet":{
# "name":"grid",
# "x":"test",
# "x_order":1,
# "y_order":1
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "ggtitle":{
# "text":"Comparison of frame_time_avg through tests"
# },
# "theme":{
# "name":"classic",
# "axis_text_y":"blank",
# "axis_ticks_y":"blank",
# "axis_line_y":"blank",
# "strip_background":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "guide":"none",
# "scale_mapper_kind":"identity"
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# "x":"@as_discrete@lib",
# "y":"frame_time_avg",
# "fill":"color"
# },
# "tooltips":{
# "tooltip_formats":[{
# "field":"frame_time_avg",
# "format":".2f"
# }],
# "tooltip_lines":["@lib","frame_time_avg|@frame_time_avg"]
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"lib",
# "order_by":"frame_time_avg",
# "order":1
# }
# }]
# },
# "data":{
# "@as_discrete@lib":["LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers","LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers","LightningChart","Plotly.js","Canvas.js","eCharts","Lets-Plot groups","Lets-Plot layers"]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("dypSCs");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
