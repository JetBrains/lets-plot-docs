# %% [markdown]
# # Discrete Color Scales

# %%
import pandas as pd

from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="6Wkxju"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.4.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("6Wkxju").appendChild(div);
#                     };
#                     var e = document.getElementById("6Wkxju");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
df = pd.read_csv('https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/mpg.csv')

# %%
p = ggplot(df, aes(x='fl')) + geom_bar(aes(fill='fl'))
p1 = p + ggtitle("Default")
p2 = p + scale_fill_manual(values=["#7fc97f", "#beaed4", "#fdc086", "#ffff99", "#386cb0"]) + \
         ggtitle("Manual color scale")
p3 = p + scale_fill_hue() + \
         ggtitle("Hue color scale")
p4 = p + scale_fill_viridis() + \
         ggtitle("Viridis color scale")
p5 = p + scale_fill_brewer(type='qual', palette='Dark2') + \
         ggtitle("Brewer color scale")

gggrid([p1, p2, p3, p4, p5], ncol=3)
# Out:
#    <div id="B21pTd"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# "x":"fl"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "ggtitle":{
# "text":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "fill":"fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"fl"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "ggtitle":{
# "text":"Manual color scale"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["#7fc97f","#beaed4","#fdc086","#ffff99","#386cb0"]
# }],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "fill":"fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"fl"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "ggtitle":{
# "text":"Hue color scale"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "scale_mapper_kind":"color_hue"
# }],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "fill":"fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"fl"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "ggtitle":{
# "text":"Viridis color scale"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "scale_mapper_kind":"color_cmap"
# }],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "fill":"fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"fl"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "ggtitle":{
# "text":"Brewer color scale"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "type":"qual",
# "palette":"Dark2",
# "scale_mapper_kind":"color_brewer"
# }],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "fill":"fl"
# },
# "data_meta":{
# },
# "data":{
# "..count..":[52.0,168.0,8.0,5.0,1.0],
# "fl":["p","r","e","d","c"]
# }
# }],
# "metainfo_list":[]
# },"blank"]
# };
#            var plotContainer = document.getElementById("B21pTd");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
p = ggplot(df, aes(x='hwy')) + geom_histogram(aes(fill='hwy'), bins=7) + theme(legend_position='none')
p1 = p + ggtitle("Default")
p2 = p + scale_fill_discrete() + \
         ggtitle("Discrete color scale")

gggrid([p1, p2])
# Out:
#    <div id="ghAyIf"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# },
# "mapping":{
# "x":"hwy"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "theme":{
# "legend_position":"none"
# },
# "ggtitle":{
# "text":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"histogram",
# "mapping":{
# "fill":"hwy"
# },
# "data_meta":{
# },
# "bins":7.0,
# "data":{
# "..count..":[7.0,71.0,55.0,79.0,18.0,2.0,2.0],
# "hwy":[11.542857142857144,17.028571428571432,22.514285714285716,28.0,33.48571428571429,38.971428571428575,44.457142857142856]
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# },
# "mapping":{
# "x":"hwy"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"Unnamed: 0"
# },{
# "type":"str",
# "column":"manufacturer"
# },{
# "type":"str",
# "column":"model"
# },{
# "type":"float",
# "column":"displ"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"int",
# "column":"cyl"
# },{
# "type":"str",
# "column":"trans"
# },{
# "type":"str",
# "column":"drv"
# },{
# "type":"int",
# "column":"cty"
# },{
# "type":"int",
# "column":"hwy"
# },{
# "type":"str",
# "column":"fl"
# },{
# "type":"str",
# "column":"class"
# }]
# },
# "theme":{
# "legend_position":"none"
# },
# "ggtitle":{
# "text":"Discrete color scale"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "discrete":true
# }],
# "layers":[{
# "geom":"histogram",
# "mapping":{
# "fill":"hwy"
# },
# "data_meta":{
# },
# "bins":7.0,
# "data":{
# "..count..":[7.0,71.0,55.0,79.0,18.0,2.0,2.0],
# "hwy":[11.542857142857144,17.028571428571432,22.514285714285716,28.0,33.48571428571429,38.971428571428575,44.457142857142856]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("ghAyIf");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
