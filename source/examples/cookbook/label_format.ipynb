# %% [markdown]
# ### The `label_format` parameter in `geom_text()`
#
# The `label_format` parameter specifies template for transforming value of the `label` aesthetic to a string.

# %%
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="sXaKbJ"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.1.0rc1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("sXaKbJ").appendChild(div);
#                     };
#                     var e = document.getElementById("sXaKbJ");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
df = {
    'y': [y for y in range(5)],
    'z': [1.0/3, 12.5/7, -22.5/11, 2.5/7, 31.67/1.77 ],
    's': ['one', 'two', 'three', 'four', 'five']
}

# %%
# Floating point numbers without formatting.
ggplot(df) + geom_text(aes(y='y', label='z'))
# Out:
#    <div id="tPWXtw"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "y":[0.0,1.0,2.0,3.0,4.0],
# "z":[0.3333333333333333,1.7857142857142858,-2.0454545454545454,0.35714285714285715,17.89265536723164]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"text",
# "mapping":{
# "y":"y",
# "label":"z"
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("tPWXtw");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# Floating point numbers with formatting.
ggplot(df) + geom_text(aes(y='y', label='z'), label_format='.3f')
# Out:
#    <div id="DaFF8W"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "y":[0.0,1.0,2.0,3.0,4.0],
# "z":[0.3333333333333333,1.7857142857142858,-2.0454545454545454,0.35714285714285715,17.89265536723164]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"text",
# "mapping":{
# "y":"y",
# "label":"z"
# },
# "data_meta":{
# },
# "label_format":".3f",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("DaFF8W");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# Numbers formatted as percentile values.
ggplot(df) + geom_text(aes(y='y', label='z'), label_format='.2%')
# Out:
#    <div id="78Hgfz"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "y":[0.0,1.0,2.0,3.0,4.0],
# "z":[0.3333333333333333,1.7857142857142858,-2.0454545454545454,0.35714285714285715,17.89265536723164]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"text",
# "mapping":{
# "y":"y",
# "label":"z"
# },
# "data_meta":{
# },
# "label_format":".2%",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("78Hgfz");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# Number format as a part of a string pattern.
ggplot(df) + geom_text(aes(y='y', label='z'), label_format='Ttl: ${.2f} (B)')
# Out:
#    <div id="vA24OD"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "y":[0.0,1.0,2.0,3.0,4.0],
# "z":[0.3333333333333333,1.7857142857142858,-2.0454545454545454,0.35714285714285715,17.89265536723164]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"text",
# "mapping":{
# "y":"y",
# "label":"z"
# },
# "data_meta":{
# },
# "label_format":"Ttl: ${.2f} (B)",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("vA24OD");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# String pattern without value formatting.
ggplot(df) + geom_text(aes(y='y', label='s'), label_format='"{}"')
# Out:
#    <div id="M2SBpX"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "y":[0.0,1.0,2.0,3.0,4.0],
# "s":["one","two","three","four","five"]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"text",
# "mapping":{
# "y":"y",
# "label":"s"
# },
# "data_meta":{
# },
# "label_format":"\"{}\"",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("M2SBpX");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
