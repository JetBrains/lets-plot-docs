# %%
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="gwzEZB"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("gwzEZB").appendChild(div);
#                     };
#                     var e = document.getElementById("gwzEZB");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
# default theme
p = (
    ggplot({'x': list(range(5)), 'y': list(range(5))}, aes('x', 'y')) +
    geom_point(aes(size='y', fill="y"),tooltips=layer_tooltips().title("TITLE").line('label|value')) +
    labs(title='The plot title', 
         subtitle="The plot subtitle",
         caption="The plot caption",
         x='X axis title', 
         y='Y axis title', 
         fill='Fill legend title',
         size='Size legend title'
    )
)
p
# Out:
#    <div id="WcHp1l"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "x":[0.0,1.0,2.0,3.0,4.0],
# "y":[0.0,1.0,2.0,3.0,4.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"The plot title",
# "subtitle":"The plot subtitle"
# },
# "caption":{
# "text":"The plot caption"
# },
# "kind":"plot",
# "scales":[{
# "name":"X axis title",
# "aesthetic":"x"
# },{
# "name":"Y axis title",
# "aesthetic":"y"
# },{
# "name":"Fill legend title",
# "aesthetic":"fill"
# },{
# "name":"Size legend title",
# "aesthetic":"size"
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# "size":"y",
# "fill":"y"
# },
# "tooltips":{
# "formats":[],
# "lines":["label|value"],
# "title":"TITLE"
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("WcHp1l");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# Change font faces
p + theme(
        plot_subtitle=element_text(face='bold_italic'),
        plot_caption=element_text(face='italic'),
    
        legend_title=element_text(face='bold'),
        legend_text=element_text(face='italic'),
    
        axis_title=element_text(face='bold'),
        axis_text=element_text(face='bold_italic'),

        # tooltip_text will also applied to axes tooltips ('italic');
        # title and label in general tooltip are bold by default -> the result for them is 'bold_italic' 
        tooltip_text=element_text(face='italic'))
# Out:
#    <div id="9N4HdJ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "x":[0.0,1.0,2.0,3.0,4.0],
# "y":[0.0,1.0,2.0,3.0,4.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"The plot title",
# "subtitle":"The plot subtitle"
# },
# "caption":{
# "text":"The plot caption"
# },
# "theme":{
# "axis_title":{
# "face":"bold",
# "blank":false
# },
# "axis_text":{
# "face":"bold_italic",
# "blank":false
# },
# "legend_text":{
# "face":"italic",
# "blank":false
# },
# "legend_title":{
# "face":"bold",
# "blank":false
# },
# "plot_subtitle":{
# "face":"bold_italic",
# "blank":false
# },
# "plot_caption":{
# "face":"italic",
# "blank":false
# },
# "tooltip_text":{
# "face":"italic",
# "blank":false
# }
# },
# "kind":"plot",
# "scales":[{
# "name":"X axis title",
# "aesthetic":"x"
# },{
# "name":"Y axis title",
# "aesthetic":"y"
# },{
# "name":"Fill legend title",
# "aesthetic":"fill"
# },{
# "name":"Size legend title",
# "aesthetic":"size"
# }],
# "layers":[{
# "geom":"point",
# "mapping":{
# "size":"y",
# "fill":"y"
# },
# "tooltips":{
# "formats":[],
# "lines":["label|value"],
# "title":"TITLE"
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("9N4HdJ");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
