# %% [markdown]
# # The `panel_inset` Parameter in `theme()`

# %%
from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="poAVvM"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("poAVvM").appendChild(div);
#                     };
#                     var e = document.getElementById("poAVvM");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
hours = list(map(lambda v: '{:02d}:00'.format(v), range(12)))

p = ggplot() \
    + geom_point(aes(x=hours)) \
    + theme_grey() \
    + theme(axis_line=element_line(color='black'))

# %% [markdown]
# ## Polar Coordinate System
#
# In the polar coordinate system, it's common for tick labels to overlap.
#
# The `panel_inset` parameter assists in creating additional space to accommodate tick labels more effectively.

# %%
gggrid([
    p + coord_polar(),
    p + theme(panel_inset=[0, 35]) + coord_polar(),
    p + theme(panel_inset=[0, 35]) + coord_polar(transform_bkgr=False),
])
# Out:
#    <div id="ngUMfu"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "axis_line":{
# "color":"black",
# "blank":false
# }
# },
# "coord":{
# "name":"polar"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# },
# "data":{
# "x":["00:00","01:00","02:00","03:00","04:00","05:00","06:00","07:00","08:00","09:00","10:00","11:00"]
# }
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "axis_line":{
# "color":"black",
# "blank":false
# },
# "panel_inset":[0.0,35.0]
# },
# "coord":{
# "name":"polar"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# },
# "data":{
# "x":["00:00","01:00","02:00","03:00","04:00","05:00","06:00","07:00","08:00","09:00","10:00","11:00"]
# }
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "axis_line":{
# "color":"black",
# "blank":false
# },
# "panel_inset":[0.0,35.0]
# },
# "coord":{
# "name":"polar",
# "transform_bkgr":false
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# },
# "data":{
# "x":["00:00","01:00","02:00","03:00","04:00","05:00","06:00","07:00","08:00","09:00","10:00","11:00"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("ngUMfu");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Rectangular Coordinate System
# In rectangular coordinate systems, the `panel_inset` parameter functions as a margin, adjusting the panel boundaries within the plot:

# %%
gggrid([
    p,
    p + theme(panel_inset=15)
])
# Out:
#    <div id="Ejcx7g"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "axis_line":{
# "color":"black",
# "blank":false
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# },
# "data":{
# "x":["00:00","01:00","02:00","03:00","04:00","05:00","06:00","07:00","08:00","09:00","10:00","11:00"]
# }
# }],
# "metainfo_list":[]
# },{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "name":"grey",
# "axis_line":{
# "color":"black",
# "blank":false
# },
# "panel_inset":15.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x"
# },
# "data_meta":{
# },
# "data":{
# "x":["00:00","01:00","02:00","03:00","04:00","05:00","06:00","07:00","08:00","09:00","10:00","11:00"]
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("Ejcx7g");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
