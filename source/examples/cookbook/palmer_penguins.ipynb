# %% [markdown]
# # Palmer Penguins
#
# This notebook is inspired by an example [Radar chart with ggradar](https://r-graph-gallery.com/web-radar-chart-with-R.html).

# %%
import numpy as np
import pandas as pd

from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="wUrUJt"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.0rc2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("wUrUJt").appendChild(div);
#                     };
#                     var e = document.getElementById("wUrUJt");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
def rescale_in_group_df(df, value_col, group_col, rescaled_col=None):
    if rescaled_col is None:
        rescaled_col = "rescaled_{0}".format(value_col)
    def rescale_subdf(subdf):
        rescaler = lambda s: (s - s.min()) / (s.max() - s.min())
        return subdf.assign(**{rescaled_col: rescaler(subdf[value_col])})
    return pd.concat([rescale_subdf(df[df[group_col] == g]) for g in df[group_col].unique()])

def get_data():
    df = pd.read_csv("https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/penguins.csv")

    grouped_df = df.dropna().groupby("species")[["bill_length_mm", "bill_depth_mm", "flipper_length_mm", "body_mass_g"]].mean().reset_index()
    grouped_df.columns = ["species", "average bill length", "average bill depth", "average flipper length", "average body mass"]

    melted_df = pd.melt(grouped_df, id_vars="species")
    melted_df = melted_df.assign(units=np.where(melted_df["variable"] == "average body mass", "g", "mm"))

    rescaled_df = rescale_in_group_df(melted_df, "value", "variable")
    rescaled_df.loc[:, "rescaled_value_pct"] = (100 * rescaled_df["rescaled_value"]).astype(int)
    return rescaled_df.sort_values(by="species").reset_index(drop=True)

# %%
penguins_df = get_data()

# %%
font_family = "roboto"
axis_color = "lightgray"
axis_text_data = {"x": ["average bill length"]*3, \
                  "y": [0, 50, 100], \
                  "text": ["0%", "50%", "100%"]}

penguins_colors = {"Adelie": "#ff5a5f", "Chinstrap": "#ffb400", "Gentoo": "#007a87"}
penguins_tooltips = layer_tooltips().title("@species")\
                                    .line("@variable: @{value}@{units}").format("@value", ".2~f")
penguins_theme = theme(
    text=element_text(family=font_family, size=18),
    plot_title=element_text(size=28, hjust=.5, face='bold'),
    axis_title='blank', axis_text_y='blank', axis_line_x='blank', \
    axis_ticks=element_line(color=axis_color), \
    panel_grid=element_line(color=axis_color), \
    panel_inset=[0, 80, 0, 80], \
    legend_position=[1, 0], legend_justification=[1, 0],
    axis_tooltip='blank',
)

# %%
ggplot(penguins_df) + \
    geom_area(aes("variable", "rescaled_value_pct", paint_a="species"), position='identity', flat=True, \
              size=2.5, color_by='paint_a', fill_by='paint_a', alpha=.2) + \
    geom_point(aes("variable", "rescaled_value_pct", paint_a="species"), size=6, color_by='paint_a', tooltips=penguins_tooltips) + \
    geom_text(aes("x", "y", label="text"), data=axis_text_data, hjust=1, fontface='bold', family=font_family, size=10) + \
    scale_x_discrete() + \
    scale_manual('paint_a', name='', values=penguins_colors) + \
    coord_polar(ylim=[-15, 100]) + \
    ggsize(800, 600) + \
    ggtitle("Penguins species") + \
    penguins_theme + flavor_solarized_light()
# Out:
#    <div id="GvXXx6"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "species":["Adelie","Adelie","Adelie","Adelie","Chinstrap","Chinstrap","Chinstrap","Chinstrap","Gentoo","Gentoo","Gentoo","Gentoo"],
# "variable":["average bill length","average bill depth","average flipper length","average body mass","average bill length","average bill depth","average flipper length","average body mass","average bill length","average bill depth","average flipper length","average body mass"],
# "value":[38.82397260273973,18.3472602739726,190.1027397260274,3706.1643835616437,48.83382352941176,18.420588235294115,195.8235294117647,3733.0882352941176,47.56806722689076,14.996638655462185,217.23529411764707,5092.436974789916],
# "units":["mm","mm","mm","g","mm","mm","mm","g","mm","mm","mm","g"],
# "rescaled_value_pct":[0.0,97.0,0.0,0.0,100.0,100.0,21.0,1.0,87.0,0.0,100.0,100.0]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "coord":{
# "name":"polar",
# "ylim":[-15.0,100.0]
# },
# "ggsize":{
# "width":800.0,
# "height":600.0
# },
# "ggtitle":{
# "text":"Penguins species"
# },
# "theme":{
# "text":{
# "family":"roboto",
# "size":18.0,
# "blank":false
# },
# "axis_title":"blank",
# "axis_text_y":"blank",
# "axis_ticks":{
# "color":"lightgray",
# "blank":false
# },
# "axis_line_x":"blank",
# "legend_position":[1.0,0.0],
# "legend_justification":[1.0,0.0],
# "panel_grid":{
# "color":"lightgray",
# "blank":false
# },
# "panel_inset":[0.0,80.0,0.0,80.0],
# "plot_title":{
# "face":"bold",
# "size":28.0,
# "hjust":0.5,
# "blank":false
# },
# "axis_tooltip":"blank",
# "flavor":"solarized_light"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "discrete":true,
# "reverse":false
# },{
# "name":"",
# "aesthetic":"paint_a",
# "breaks":["Adelie","Chinstrap","Gentoo"],
# "values":["#ff5a5f","#ffb400","#007a87"]
# }],
# "layers":[{
# "geom":"area",
# "mapping":{
# "x":"variable",
# "y":"rescaled_value_pct",
# "paint_a":"species"
# },
# "position":"identity",
# "data_meta":{
# },
# "flat":true,
# "color_by":"paint_a",
# "fill_by":"paint_a",
# "size":2.5,
# "alpha":0.2,
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "x":"variable",
# "y":"rescaled_value_pct",
# "paint_a":"species"
# },
# "tooltips":{
# "formats":[{
# "field":"@value",
# "format":".2~f"
# }],
# "lines":["@variable: @{value}@{units}"],
# "title":"@species"
# },
# "data_meta":{
# },
# "color_by":"paint_a",
# "size":6.0,
# "data":{
# }
# },{
# "geom":"text",
# "data":{
# "x":["average bill length","average bill length","average bill length"],
# "y":[0.0,50.0,100.0],
# "text":["0%","50%","100%"]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"text"
# },
# "data_meta":{
# },
# "hjust":1.0,
# "fontface":"bold",
# "family":"roboto",
# "size":10.0
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("GvXXx6");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
