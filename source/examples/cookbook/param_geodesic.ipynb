# %% [markdown]
# # Param `geodesic` in `geom_segment()` and `geom_path()`
#
# With `geodesic=True` a segment will be transformed to a curve representing the shortest path between two points on the surface of Earth.
#
# Note that this parameter only works when functions `geom_path()` and `geom_segment()` are used in combination with `geom_livemap()`.

# %%
import pandas as pd

from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="LLqucq"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.0.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("LLqucq").appendChild(div);
#                     };
#                     var e = document.getElementById("LLqucq");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
LetsPlot.set(maptiles_lets_plot(theme='dark'))

# %% [markdown]
# #### By Default, a Segment on Map is a Straight Line

# %%
ggplot() + geom_livemap() + \
    geom_segment(x=-122.25165, y=37.464958, xend=139.4130, yend=35.4122, color='white', size=1)
# Out:
#    <div id="DdNLZu"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"dark",
# "attribution":"Map: <a href=\"https://github.com/JetBrains/lets-plot\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"segment",
# "mapping":{
# },
# "data_meta":{
# },
# "x":-122.25165,
# "y":37.464958,
# "xend":139.413,
# "yend":35.4122,
# "color":"white",
# "size":1.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("DdNLZu");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Segment with `geodesic=True`

# %% [markdown]
# With `geodesic=True` a segment on map becomes an arc.

# %%
ggplot() + geom_livemap() + \
    geom_segment(x=-122.25165, y=37.464958, xend=139.4130, yend=35.4122, geodesic=True, color='white', size=1)
# Out:
#    <div id="KzlEuv"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"dark",
# "attribution":"Map: <a href=\"https://github.com/JetBrains/lets-plot\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"segment",
# "mapping":{
# },
# "data_meta":{
# },
# "geodesic":true,
# "x":-122.25165,
# "y":37.464958,
# "xend":139.413,
# "yend":35.4122,
# "color":"white",
# "size":1.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("KzlEuv");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `geom_path()` with `geodesic=True`

# %%
data = {
    'city': ['New York', 'San-Francisco', 'Tokyo'],
    'lon': [-73.935242, -122.25165, 139.4130],
    'lat': [40.730610, 37.464958, 35.4122],
}
ggplot(data) + \
    geom_livemap() + \
    geom_path(aes(x='lon', y='lat'), color='white', size=1, linetype="dotted") + \
    geom_path(aes(x='lon', y='lat'), geodesic=True, color='white', size=1)
# Out:
#    <div id="hpJJsO"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "lon":[-73.935242,-122.25165,139.413],
# "lat":[40.73061,37.464958,35.4122]
# },
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"dark",
# "attribution":"Map: <a href=\"https://github.com/JetBrains/lets-plot\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"path",
# "mapping":{
# "x":"lon",
# "y":"lat"
# },
# "data_meta":{
# },
# "color":"white",
# "size":1.0,
# "linetype":"dotted",
# "data":{
# }
# },{
# "geom":"path",
# "mapping":{
# "x":"lon",
# "y":"lat"
# },
# "data_meta":{
# },
# "geodesic":true,
# "color":"white",
# "size":1.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("hpJJsO");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
