# %% [markdown]
# # Annotations for Bar Plot
#
#
# Annotations are configured using the `labels` parameter.

# %%
import pandas as pd

from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="nuYLmY"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.1.0rc1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("nuYLmY").appendChild(div);
#                     };
#                     var e = document.getElementById("nuYLmY");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
mpg_df = pd.read_csv ("https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/mpg.csv")
mpg_df.head(4)
# Out:
#    Unnamed: 0 manufacturer model  displ  year  cyl       trans drv  cty  hwy  \
# 0           1         audi    a4    1.8  1999    4    auto(l5)   f   18   29
# 1           2         audi    a4    1.8  1999    4  manual(m5)   f   21   29
# 2           3         audi    a4    2.0  2008    4  manual(m6)   f   20   31
# 3           4         audi    a4    2.0  2008    4    auto(av)   f   21   30
#
#   fl    class
# 0  p  compact
# 1  p  compact
# 2  p  compact
# 3  p  compact

# %% [markdown]
# #### `position='stack'`

# %%
ggplot(mpg_df, aes('class', fill='drv')) + \
    theme(legend_position='none') + \
    geom_bar(labels=layer_labels().line('@..proppct..').format('..proppct..', '{d}%'),
             tooltips='none')
# Out:
#    <div id="ovXUjB"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"class",
# "fill":"drv"
# },
# "data_meta":{
# },
# "theme":{
# "legend_position":"none"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[{
# "field":"..proppct..",
# "format":"{d}%"
# }],
# "lines":["@..proppct.."]
# },
# "data":{
# "..count..":[35.0,38.0,11.0,22.0,12.0,3.0,51.0,33.0,4.0,11.0,5.0,9.0],
# "class":["compact","midsize","minivan","subcompact","compact","midsize","suv","pickup","subcompact","suv","2seater","subcompact"],
# "drv":["f","f","f","f","4","4","4","4","4","r","r","r"],
# "..proppct..":[74.46808510638297,92.6829268292683,100.0,62.857142857142854,25.53191489361702,7.317073170731707,82.25806451612904,100.0,11.428571428571429,17.741935483870968,100.0,25.71428571428571]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("ovXUjB");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `position='dodge'`

# %%
ggplot(mpg_df, aes('class', fill='drv')) + \
    theme(legend_position='none') + \
    geom_bar(labels=layer_labels().line('@..proppct..').format('..proppct..', '{d}%'),
             tooltips='none', position='dodge')
# Out:
#    <div id="jobPNJ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"class",
# "fill":"drv"
# },
# "data_meta":{
# },
# "theme":{
# "legend_position":"none"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "position":"dodge",
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[{
# "field":"..proppct..",
# "format":"{d}%"
# }],
# "lines":["@..proppct.."]
# },
# "data":{
# "..count..":[35.0,38.0,11.0,22.0,12.0,3.0,51.0,33.0,4.0,11.0,5.0,9.0],
# "class":["compact","midsize","minivan","subcompact","compact","midsize","suv","pickup","subcompact","suv","2seater","subcompact"],
# "drv":["f","f","f","f","4","4","4","4","4","r","r","r"],
# "..proppct..":[74.46808510638297,92.6829268292683,100.0,62.857142857142854,25.53191489361702,7.317073170731707,82.25806451612904,100.0,11.428571428571429,17.741935483870968,100.0,25.71428571428571]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("jobPNJ");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### `position='fill'`

# %%
ggplot(mpg_df, aes('class', fill='drv')) + \
    coord_flip() + \
    theme(legend_position='none') + \
    geom_bar(labels=layer_labels().line('@..proppct..').format('..proppct..', '{d}%'), 
             tooltips='none', 
             position='fill')
# Out:
#    <div id="34kW0j"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"class",
# "fill":"drv"
# },
# "data_meta":{
# },
# "coord":{
# "name":"flip",
# "flip":true
# },
# "theme":{
# "legend_position":"none"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "position":"fill",
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[{
# "field":"..proppct..",
# "format":"{d}%"
# }],
# "lines":["@..proppct.."]
# },
# "data":{
# "..count..":[35.0,38.0,11.0,22.0,12.0,3.0,51.0,33.0,4.0,11.0,5.0,9.0],
# "class":["compact","midsize","minivan","subcompact","compact","midsize","suv","pickup","subcompact","suv","2seater","subcompact"],
# "drv":["f","f","f","f","4","4","4","4","4","r","r","r"],
# "..proppct..":[74.46808510638297,92.6829268292683,100.0,62.857142857142854,25.53191489361702,7.317073170731707,82.25806451612904,100.0,11.428571428571429,17.741935483870968,100.0,25.71428571428571]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("34kW0j");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
