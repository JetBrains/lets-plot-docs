# %%
from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="FicCXp"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.4.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("FicCXp").appendChild(div);
#                     };
#                     var e = document.getElementById("FicCXp");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
p = (
    ggplot({'x': [1.0], 'y': [1.0]}, aes('x', 'y')) +
    ggsize(400,300) +
    geom_point( tooltips=layer_tooltips().title("Tooltip title").line('label|value'))
)
p
# Out:
#    <div id="vzCAgi"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "x":[1.0],
# "y":[1.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggsize":{
# "width":400,
# "height":300
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "tooltips":{
# "tooltip_formats":[],
# "tooltip_lines":["label|value"],
# "tooltip_title":"Tooltip title"
# },
# "data_meta":{
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("vzCAgi");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# 'tooltip' - tooltip rectangle;
# 'tooltip_text' - text in general tooltip;
# 'tooltip_title_text' - tooltip title text;
# 'axis_tooltip_text_*' - axis tooltip text (inherits from 'tooltip_text')

p + theme(
    tooltip=element_rect(color='#225e32', fill='#238b45', size=2),
    tooltip_text=element_text(color='#bae4b3'),
    tooltip_title_text=element_text(color='#edf8e9'),
    axis_tooltip_text_x=element_text(color='green')
)
# Out:
#    <div id="3VGCuN"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "x":[1.0],
# "y":[1.0]
# },
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "ggsize":{
# "width":400,
# "height":300
# },
# "theme":{
# "axis_tooltip_text_x":{
# "color":"green",
# "blank":false
# },
# "tooltip":{
# "fill":"#238b45",
# "color":"#225e32",
# "size":2,
# "blank":false
# },
# "tooltip_text":{
# "color":"#bae4b3",
# "blank":false
# },
# "tooltip_title_text":{
# "color":"#edf8e9",
# "blank":false
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "tooltips":{
# "tooltip_formats":[],
# "tooltip_lines":["label|value"],
# "tooltip_title":"Tooltip title"
# },
# "data_meta":{
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("3VGCuN");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
