# %%
from lets_plot import *

LetsPlot.setup_html()
# Out:
#             <div id="HefsNw"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.2.0rc1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("HefsNw").appendChild(div);
#                     };
#                     var e = document.getElementById("HefsNw");
#                     e.appendChild(script);
#                 })()
#             </script>

# %% [markdown]
# ### Plotting means and error ranges.
#
# There are several ways to show error ranges on a plot. Among them are
# - *geom_errorbar*
# - *geom_crossbar*
# - *geom_linerange*
# - *geom_pointrange*

# %%
# This example was found at: www.cookbook-r.com/Graphs/Plotting_means_and_error_bars_(ggplot2)
data = dict(
    supp = ['OJ', 'OJ', 'OJ', 'VC', 'VC', 'VC'],
    dose = [0.5, 1.0, 2.0, 0.5, 1.0, 2.0],
    length = [13.23, 22.70, 26.06, 7.98, 16.77, 26.14],
    len_min = [11.83, 21.2, 24.50, 4.24, 15.26, 23.35],
    len_max = [15.63, 24.9, 27.11, 10.72, 19.28, 28.93]
)

# %%
p = ggplot(data, aes(x='dose', color='supp'))

# %% [markdown]
# ### Error-bars with lines and points.

# %%
p + geom_errorbar(aes(ymin='len_min', ymax='len_max'), width=.1) \
+ geom_line(aes(y='length')) \
+ geom_point(aes(y='length'))
# Out:
#    <div id="rHzd8C"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "supp":["OJ","OJ","OJ","VC","VC","VC"],
# "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
# "length":[13.23,22.7,26.06,7.98,16.77,26.14],
# "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
# "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
# },
# "mapping":{
# "x":"dose",
# "color":"supp"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"errorbar",
# "mapping":{
# "ymin":"len_min",
# "ymax":"len_max"
# },
# "data_meta":{
# },
# "width":0.1,
# "data":{
# }
# },{
# "geom":"line",
# "mapping":{
# "y":"length"
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "y":"length"
# },
# "data_meta":{
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("rHzd8C");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# The errorbars overlapped, so use position_dodge to move them horizontally
pd = position_dodge(0.1) # move them .05 to the left and right
p + geom_errorbar(aes(ymin='len_min', ymax='len_max'), width=.1, position=pd) \
+ geom_line(aes(y='length'), position=pd) \
+ geom_point(aes(y='length'), position=pd)
# Out:
#    <div id="2OUaEQ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "supp":["OJ","OJ","OJ","VC","VC","VC"],
# "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
# "length":[13.23,22.7,26.06,7.98,16.77,26.14],
# "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
# "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
# },
# "mapping":{
# "x":"dose",
# "color":"supp"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"errorbar",
# "mapping":{
# "ymin":"len_min",
# "ymax":"len_max"
# },
# "position":{
# "name":"dodge",
# "width":0.1
# },
# "data_meta":{
# },
# "width":0.1,
# "data":{
# }
# },{
# "geom":"line",
# "mapping":{
# "y":"length"
# },
# "position":{
# "name":"dodge",
# "width":0.1
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "y":"length"
# },
# "position":{
# "name":"dodge",
# "width":0.1
# },
# "data_meta":{
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("2OUaEQ");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# Black errorbars - notice the mapping of 'group=supp'
# Without it, the errorbars won't be dodged!
p + geom_errorbar(aes(ymin='len_min', ymax='len_max', group='supp'), color='black', width=.1, position=pd) \
+ geom_line(aes(y='length'), position=pd) \
+ geom_point(aes(y='length'), position=pd, size=5)
# Out:
#    <div id="6zAmWW"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "supp":["OJ","OJ","OJ","VC","VC","VC"],
# "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
# "length":[13.23,22.7,26.06,7.98,16.77,26.14],
# "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
# "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
# },
# "mapping":{
# "x":"dose",
# "color":"supp"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"errorbar",
# "mapping":{
# "ymin":"len_min",
# "ymax":"len_max",
# "group":"supp"
# },
# "position":{
# "name":"dodge",
# "width":0.1
# },
# "data_meta":{
# },
# "color":"black",
# "width":0.1,
# "data":{
# }
# },{
# "geom":"line",
# "mapping":{
# "y":"length"
# },
# "position":{
# "name":"dodge",
# "width":0.1
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "y":"length"
# },
# "position":{
# "name":"dodge",
# "width":0.1
# },
# "data_meta":{
# },
# "size":5,
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("6zAmWW");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# The finished graph:
# - fixed size
# - point shape # 21 is filled circle 
# - position legend in the bottom right
p1 = p \
+ xlab("Dose (mg)") \
+ ylab("Tooth length (mm)") \
+ scale_color_manual(['orange', 'dark_green'], na_value='gray') \
+ ggsize(700, 400)
p1 + geom_errorbar(aes(ymin='len_min', ymax='len_max', group='supp'), color='black', width=.1, position=pd) \
+ geom_line(aes(y='length'), position=pd) \
+ geom_point(aes(y='length'), position=pd, size=5, shape=21, fill="white") \
+ theme(legend_justification=[1,0], legend_position=[1,0]) \
+ ggtitle("The Effect of Vitamin C on Tooth Growth in Guinea Pigs")
# Out:
#    <div id="5TTQvc"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "supp":["OJ","OJ","OJ","VC","VC","VC"],
# "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
# "length":[13.23,22.7,26.06,7.98,16.77,26.14],
# "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
# "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
# },
# "mapping":{
# "x":"dose",
# "color":"supp"
# },
# "data_meta":{
# },
# "ggsize":{
# "width":700,
# "height":400
# },
# "theme":{
# "legend_position":[1,0],
# "legend_justification":[1,0]
# },
# "ggtitle":{
# "text":"The Effect of Vitamin C on Tooth Growth in Guinea Pigs"
# },
# "kind":"plot",
# "scales":[{
# "name":"Dose (mg)",
# "aesthetic":"x"
# },{
# "name":"Tooth length (mm)",
# "aesthetic":"y"
# },{
# "aesthetic":"color",
# "na_value":"gray",
# "values":["orange","dark_green"]
# }],
# "layers":[{
# "geom":"errorbar",
# "mapping":{
# "ymin":"len_min",
# "ymax":"len_max",
# "group":"supp"
# },
# "position":{
# "name":"dodge",
# "width":0.1
# },
# "data_meta":{
# },
# "color":"black",
# "width":0.1,
# "data":{
# }
# },{
# "geom":"line",
# "mapping":{
# "y":"length"
# },
# "position":{
# "name":"dodge",
# "width":0.1
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"point",
# "mapping":{
# "y":"length"
# },
# "position":{
# "name":"dodge",
# "width":0.1
# },
# "data_meta":{
# },
# "size":5,
# "shape":21,
# "fill":"white",
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("5TTQvc");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Error-bars on bar plot.

# %%
# Plot error ranges on Bar plot
p1 \
+ geom_bar(aes(y='length', fill='supp'), stat='identity', position='dodge', color='black') \
+ geom_errorbar(aes(ymin='len_min', ymax='len_max', group='supp'), color='black', width=.1, position=position_dodge(0.9)) \
+ theme(legend_justification=[0,1], legend_position=[0,1])
# Out:
#    <div id="vhFCZv"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "supp":["OJ","OJ","OJ","VC","VC","VC"],
# "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
# "length":[13.23,22.7,26.06,7.98,16.77,26.14],
# "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
# "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
# },
# "mapping":{
# "x":"dose",
# "color":"supp"
# },
# "data_meta":{
# },
# "ggsize":{
# "width":700,
# "height":400
# },
# "theme":{
# "legend_position":[0,1],
# "legend_justification":[0,1]
# },
# "kind":"plot",
# "scales":[{
# "name":"Dose (mg)",
# "aesthetic":"x"
# },{
# "name":"Tooth length (mm)",
# "aesthetic":"y"
# },{
# "aesthetic":"color",
# "na_value":"gray",
# "values":["orange","dark_green"]
# }],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# "y":"length",
# "fill":"supp"
# },
# "position":"dodge",
# "data_meta":{
# },
# "color":"black",
# "data":{
# }
# },{
# "geom":"errorbar",
# "mapping":{
# "ymin":"len_min",
# "ymax":"len_max",
# "group":"supp"
# },
# "position":{
# "name":"dodge",
# "width":0.9
# },
# "data_meta":{
# },
# "color":"black",
# "width":0.1,
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("vhFCZv");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Crossbars.

# %%
# Thickness of the horizontal mid-line can be adjusted using `fatten` parameter.
p1 + geom_crossbar(aes(ymin='len_min', ymax='len_max', middle='length', color='supp'), fatten=5)
# Out:
#    <div id="yYXf8F"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "supp":["OJ","OJ","OJ","VC","VC","VC"],
# "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
# "length":[13.23,22.7,26.06,7.98,16.77,26.14],
# "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
# "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
# },
# "mapping":{
# "x":"dose",
# "color":"supp"
# },
# "data_meta":{
# },
# "ggsize":{
# "width":700,
# "height":400
# },
# "kind":"plot",
# "scales":[{
# "name":"Dose (mg)",
# "aesthetic":"x"
# },{
# "name":"Tooth length (mm)",
# "aesthetic":"y"
# },{
# "aesthetic":"color",
# "na_value":"gray",
# "values":["orange","dark_green"]
# }],
# "layers":[{
# "geom":"crossbar",
# "mapping":{
# "ymin":"len_min",
# "ymax":"len_max",
# "middle":"length",
# "color":"supp"
# },
# "data_meta":{
# },
# "fatten":5,
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("yYXf8F");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Line-range.

# %%
p1 \
+ geom_linerange(aes(ymin='len_min', ymax='len_max', color='supp'), position=pd) \
+ geom_line(aes(y='length'), position=pd)
# Out:
#    <div id="qI63PW"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "supp":["OJ","OJ","OJ","VC","VC","VC"],
# "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
# "length":[13.23,22.7,26.06,7.98,16.77,26.14],
# "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
# "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
# },
# "mapping":{
# "x":"dose",
# "color":"supp"
# },
# "data_meta":{
# },
# "ggsize":{
# "width":700,
# "height":400
# },
# "kind":"plot",
# "scales":[{
# "name":"Dose (mg)",
# "aesthetic":"x"
# },{
# "name":"Tooth length (mm)",
# "aesthetic":"y"
# },{
# "aesthetic":"color",
# "na_value":"gray",
# "values":["orange","dark_green"]
# }],
# "layers":[{
# "geom":"linerange",
# "mapping":{
# "ymin":"len_min",
# "ymax":"len_max",
# "color":"supp"
# },
# "position":{
# "name":"dodge",
# "width":0.1
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"line",
# "mapping":{
# "y":"length"
# },
# "position":{
# "name":"dodge",
# "width":0.1
# },
# "data_meta":{
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("qI63PW");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Point-range

# %%
# Point-range is the same as line-range but with an added mid-point.
p1 \
+ geom_pointrange(aes(y='length', ymin='len_min', ymax='len_max', color='supp'), position=pd) \
+ geom_line(aes(y='length'), position=pd)
# Out:
#    <div id="YHJqpv"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "supp":["OJ","OJ","OJ","VC","VC","VC"],
# "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
# "length":[13.23,22.7,26.06,7.98,16.77,26.14],
# "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
# "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
# },
# "mapping":{
# "x":"dose",
# "color":"supp"
# },
# "data_meta":{
# },
# "ggsize":{
# "width":700,
# "height":400
# },
# "kind":"plot",
# "scales":[{
# "name":"Dose (mg)",
# "aesthetic":"x"
# },{
# "name":"Tooth length (mm)",
# "aesthetic":"y"
# },{
# "aesthetic":"color",
# "na_value":"gray",
# "values":["orange","dark_green"]
# }],
# "layers":[{
# "geom":"pointrange",
# "mapping":{
# "y":"length",
# "ymin":"len_min",
# "ymax":"len_max",
# "color":"supp"
# },
# "position":{
# "name":"dodge",
# "width":0.1
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"line",
# "mapping":{
# "y":"length"
# },
# "position":{
# "name":"dodge",
# "width":0.1
# },
# "data_meta":{
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("YHJqpv");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# Size of the mid-point can be adjuasted using `fatten` parameter - multiplication factor relative to the line size.
p1 \
+ geom_line(aes(y='length'), position=pd) \
+ geom_pointrange(aes(y='length', ymin='len_min', ymax='len_max', fill='supp'), position=pd, color='rgb(230, 230, 230)', size=5, shape=23, fatten=1) \
+ scale_fill_manual(['orange', 'dark_green'], na_value='gray')
# Out:
#    <div id="9mvIEX"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "supp":["OJ","OJ","OJ","VC","VC","VC"],
# "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
# "length":[13.23,22.7,26.06,7.98,16.77,26.14],
# "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
# "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
# },
# "mapping":{
# "x":"dose",
# "color":"supp"
# },
# "data_meta":{
# },
# "ggsize":{
# "width":700,
# "height":400
# },
# "kind":"plot",
# "scales":[{
# "name":"Dose (mg)",
# "aesthetic":"x"
# },{
# "name":"Tooth length (mm)",
# "aesthetic":"y"
# },{
# "aesthetic":"color",
# "na_value":"gray",
# "values":["orange","dark_green"]
# },{
# "aesthetic":"fill",
# "na_value":"gray",
# "values":["orange","dark_green"]
# }],
# "layers":[{
# "geom":"line",
# "mapping":{
# "y":"length"
# },
# "position":{
# "name":"dodge",
# "width":0.1
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"pointrange",
# "mapping":{
# "y":"length",
# "ymin":"len_min",
# "ymax":"len_max",
# "fill":"supp"
# },
# "position":{
# "name":"dodge",
# "width":0.1
# },
# "data_meta":{
# },
# "fatten":1,
# "color":"rgb(230, 230, 230)",
# "size":5,
# "shape":23,
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("9mvIEX");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
