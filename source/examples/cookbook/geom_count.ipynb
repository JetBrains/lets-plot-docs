# %% [markdown]
# # Handling an overplotting on a scatter plot: `geom_count()`/`stat_sum()`
#
# The `geom_count()` counts the number of observations at each location.
#
# Computed variables:
#
# - `..n..` - number of observations at location
# - `..prop..` - value in range 0..1 : share of observations at location
# - `..proppct..` - value in range 0..100 : % of observations at location

# %%
from lets_plot import *
from lets_plot.mapping import *
import pandas as pd

# %%
LetsPlot.setup_html()
# Out:
#             <div id="Q1JSIg"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("Q1JSIg").appendChild(div);
#                     };
#                     var e = document.getElementById("Q1JSIg");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
mpg_df = pd.read_csv ("https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/mpg.csv")
mpg_df.head()
# Out:
#    Unnamed: 0 manufacturer model  displ  year  cyl       trans drv  cty  hwy  \
# 0           1         audi    a4    1.8  1999    4    auto(l5)   f   18   29
# 1           2         audi    a4    1.8  1999    4  manual(m5)   f   21   29
# 2           3         audi    a4    2.0  2008    4  manual(m6)   f   20   31
# 3           4         audi    a4    2.0  2008    4    auto(av)   f   21   30
# 4           5         audi    a4    2.8  1999    6    auto(l5)   f   16   26
#
#   fl    class
# 0  p  compact
# 1  p  compact
# 2  p  compact
# 3  p  compact
# 4  p  compact

# %%
p = ggplot(mpg_df, aes(x=as_discrete('class', order=1), y=as_discrete('drv', order=1)))

# %% [markdown]
# #### 1. Plot an Observation Count by Location

# %%
p + geom_count()
# Out:
#    <div id="abHrPz"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"class",
# "y":"drv"
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"class",
# "order":1.0
# }
# },{
# "aes":"y",
# "annotation":"as_discrete",
# "parameters":{
# "label":"drv",
# "order":1.0
# }
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "stat":"sum",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..n..":[35.0,12.0,3.0,11.0,5.0,51.0,38.0,11.0,33.0,9.0,22.0,4.0],
# "class":["compact","compact","midsize","suv","2seater","suv","midsize","minivan","pickup","subcompact","subcompact","subcompact"],
# "drv":["f","4","4","r","r","4","f","f","4","r","f","4"]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("abHrPz");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
p + stat_sum()
# Out:
#    <div id="1Ijd0x"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"class",
# "y":"drv"
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"class",
# "order":1.0
# }
# },{
# "aes":"y",
# "annotation":"as_discrete",
# "parameters":{
# "label":"drv",
# "order":1.0
# }
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "stat":"sum",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..n..":[35.0,12.0,3.0,11.0,5.0,51.0,38.0,11.0,33.0,9.0,22.0,4.0],
# "class":["compact","compact","midsize","suv","2seater","suv","midsize","minivan","pickup","subcompact","subcompact","subcompact"],
# "drv":["f","4","4","r","r","4","f","f","4","r","f","4"]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("1Ijd0x");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### 2. Plot an Observations Share by Location

# %%
p + geom_count(aes(size='..prop..'))
# Out:
#    <div id="VDzVb1"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"class",
# "y":"drv"
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"class",
# "order":1.0
# }
# },{
# "aes":"y",
# "annotation":"as_discrete",
# "parameters":{
# "label":"drv",
# "order":1.0
# }
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "stat":"sum",
# "mapping":{
# "size":"..prop.."
# },
# "data_meta":{
# },
# "data":{
# "..prop..":[0.14957264957264957,0.05128205128205128,0.01282051282051282,0.04700854700854701,0.021367521367521368,0.21794871794871795,0.1623931623931624,0.04700854700854701,0.14102564102564102,0.038461538461538464,0.09401709401709402,0.017094017094017096],
# "class":["compact","compact","midsize","suv","2seater","suv","midsize","minivan","pickup","subcompact","subcompact","subcompact"],
# "drv":["f","4","4","r","r","4","f","f","4","r","f","4"]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("VDzVb1");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### 3. Plot an Observations Share by Drivetrain Type within each Vehicle "class"
#
# Note: group by "class".

# %%
p + geom_count(aes(size='..prop..', group='class'))
# Out:
#    <div id="m14tNq"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"class",
# "y":"drv"
# },
# "data_meta":{
# "mapping_annotations":[{
# "aes":"x",
# "annotation":"as_discrete",
# "parameters":{
# "label":"class",
# "order":1.0
# }
# },{
# "aes":"y",
# "annotation":"as_discrete",
# "parameters":{
# "label":"drv",
# "order":1.0
# }
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "stat":"sum",
# "mapping":{
# "size":"..prop..",
# "group":"class"
# },
# "data_meta":{
# },
# "data":{
# "..prop..":[1.0,0.07317073170731707,0.926829268292683,1.0,0.7446808510638298,0.2553191489361702,0.2571428571428571,0.6285714285714286,0.11428571428571428,1.0,0.1774193548387097,0.8225806451612904],
# "class":["pickup","midsize","midsize","minivan","compact","compact","subcompact","subcompact","subcompact","2seater","suv","suv"],
# "drv":["4","4","f","f","f","4","r","f","4","r","r","4"]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("m14tNq");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
