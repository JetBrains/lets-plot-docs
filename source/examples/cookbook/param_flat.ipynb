# %% [markdown]
# # Controlling lines curvnes on a livemap with `flat` parameter.
#
# Parameter `flat` is a replacement for the deprecated `geodesic` parameter of the livemap layer.
# Layers that support this parameter: `geom_segment()`, `geom_path()`:
# - `False` (by default) - allows a line to get geodesic;
# - `True` - keeps a line straight.

# %%
from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="UBPwja"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.0.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("UBPwja").appendChild(div);
#                     };
#                     var e = document.getElementById("UBPwja");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
data = {
    'lon': [-73.7997, -149.9002],
    'lat': [40.6408, 61.2180],
}

# %%
ggplot(data, aes(x='lon', y='lat')) + \
    geom_livemap() + \
    geom_path(flat=True, color='red')
# Out:
#    <div id="E36JE6"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "lon":[-73.7997,-149.9002],
# "lat":[40.6408,61.218]
# },
# "mapping":{
# "x":"lon",
# "y":"lat"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"Map: <a href=\"https://github.com/JetBrains/lets-plot\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"path",
# "mapping":{
# },
# "data_meta":{
# },
# "flat":true,
# "color":"red",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("E36JE6");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
ggplot(data, aes(x='lon', y='lat')) + \
    geom_livemap() + \
    geom_path(flat=True, color='red') + \
    geom_path(flat=False, color='blue')
# Out:
#    <div id="TSklD8"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "lon":[-73.7997,-149.9002],
# "lat":[40.6408,61.218]
# },
# "mapping":{
# "x":"lon",
# "y":"lat"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"Map: <a href=\"https://github.com/JetBrains/lets-plot\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"path",
# "mapping":{
# },
# "data_meta":{
# },
# "flat":true,
# "color":"red",
# "data":{
# }
# },{
# "geom":"path",
# "mapping":{
# },
# "data_meta":{
# },
# "flat":false,
# "color":"blue",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("TSklD8");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
