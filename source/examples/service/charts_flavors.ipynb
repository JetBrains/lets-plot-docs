# %%
from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="ZxT6JW"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.4.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
# ...

# %%
df = {
  'name': ['pen', 'brush', 'paper'],
  'slice': [1, 3, 3]
}

# %%
pie_chart = ggplot(df) + \
    geom_pie(aes(fill='name', slice='slice'),
             stat='identity',
             color='pen',
             size=0.5, size_unit="x",
             tooltips='none', labels=layer_labels().line('@name')) + \
    scale_fill_manual(['pen', 'brush', 'paper']) + \
    theme(legend_position='none', axis_title='blank')

# %%
gggrid([
    pie_chart + flavor_darcula(),
    pie_chart + flavor_solarized_light(),
    pie_chart + flavor_solarized_dark(),
    pie_chart + flavor_high_contrast_light(),
    pie_chart + flavor_high_contrast_dark(),
], ncol=2)
# Out:
#    <div id="mYa7cb"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":2.0,
# "nrow":3.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "name":["pen","brush","paper"],
# "slice":[1.0,3.0,3.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"slice"
# }]
# },
# "theme":{
# "axis_title":"blank",
# "legend_position":"none",
# "flavor":"darcula"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "values":["pen","brush","paper"]
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"slice"
# },
# "tooltips":"none",
# "data_meta":{
# },
# "labels":{
# "formats":[],
# "lines":["@name"]
# },
# "size_unit":"x",
# "color":"pen",
# "size":0.5,
# "data":{
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# "name":["pen","brush","paper"],
# ...
