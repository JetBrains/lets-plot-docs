# %% [markdown]
# # Correlation Plot
#
# The `corr_plot()` function creates a fluent builder object offering a set of methods for configuring of beautiful correlation plots.

# %%
import pandas as pd

from lets_plot import *
from lets_plot.bistro.corr import *
LetsPlot.setup_html()
# Out:
#             <div id="ThYJHN"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.2.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("ThYJHN").appendChild(div);
#                     };
#                     var e = document.getElementById("ThYJHN");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
df = pd.read_csv('https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/mpg.csv')

# %%
corr_plot(data=df.corr(numeric_only=True), threshold=.5).points().labels()\
    .palette_gradient(low='#d7191c', mid='#ffffbf', high='#1a9641')\
    .build() + ggsize(600, 400)
# Out:
#    <div id="OPf9aZ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "ggsize":{
# "width":600.0,
# "height":400.0
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"size",
# "scale_mapper_kind":"identity",
# "na_value":0,
# "guide":"none"
# },{
# "aesthetic":"x",
# "discrete":true,
# "breaks":["displ","cyl","cty","hwy"],
# "limits":["displ","cyl","cty","hwy"],
# "expand":[0.0,0.0]
# },{
# "aesthetic":"y",
# "discrete":true,
# "breaks":["displ","cyl","cty","hwy"],
# "limits":["hwy","cty","cyl","displ"],
# "expand":[0.0,0.0]
# },{
# "aesthetic":"color",
# "name":"",
# "breaks":[-1.0,-0.5,0.0,0.5,1.0],
# "limits":[-1.0,1.0],
# "na_value":"rgba(0,0,0,0)",
# "scale_mapper_kind":"color_gradient2",
# "low":"#d7191c",
# "mid":"#ffffbf",
# "high":"#1a9641"
# },{
# "aesthetic":"fill",
# "name":"",
# "breaks":[-1.0,-0.5,0.0,0.5,1.0],
# "limits":[-1.0,1.0],
# "na_value":"rgba(0,0,0,0)",
# "scale_mapper_kind":"color_gradient2",
# "low":"#d7191c",
# "mid":"#ffffbf",
# "high":"#1a9641"
# }],
# "layers":[{
# "na_text":"",
# "label_format":".2f",
# "show_legend":true,
# "tooltips":{
# "lines":["@corr"],
# "formats":[{
# "field":"@corr",
# "format":".2f"
# }]
# },
# "sampling":{
# "name":"none"
# },
# "geom":"point",
# "data":{
# "x":["cyl","cty","cty","hwy","hwy","hwy"],
# "y":["displ","displ","cyl","displ","cyl","cty"],
# "corr":[0.9302271024198506,-0.7985239689348548,-0.8057714082675277,-0.7660200208864677,-0.7619123538971949,0.955915913649572],
# "corr_abs":[0.9302271024198506,0.7985239689348548,0.8057714082675277,0.7660200208864677,0.7619123538971949,0.955915913649572]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "size":"corr_abs",
# "color":"corr"
# },
# "size_unit":"x"
# },{
# "na_text":"",
# "label_format":".2f",
# "show_legend":true,
# "tooltips":{
# "lines":["@corr"],
# "formats":[{
# "field":"@corr",
# "format":".2f"
# }]
# },
# "sampling":{
# "name":"none"
# },
# "geom":"text",
# "data":{
# "x":["displ","displ","displ","cyl","cyl","cty"],
# "y":["cyl","cty","hwy","cty","hwy","hwy"],
# "corr":[0.9302271024198506,-0.7985239689348548,-0.7660200208864677,-0.8057714082675277,-0.7619123538971949,0.955915913649572]
# },
# "mapping":{
# "x":"x",
# "y":"y",
# "label":"corr",
# "size":"corr_abs",
# "color":"corr"
# },
# "size_unit":"x",
# "size":1.0
# }],
# "metainfo_list":[],
# "coord":{
# "name":"fixed",
# "xlim":[-0.6,3.6],
# "ylim":[-0.6,3.6]
# },
# "theme":{
# "axis_title":{
# "blank":true
# },
# "axis_line":{
# "blank":true
# },
# "panel_grid":{
# "blank":true
# },
# "axis_ticks_x":{
# "blank":false
# },
# "axis_ticks_y":{
# "blank":false
# }
# },
# "mapping":{
# }
# };
#            var plotContainer = document.getElementById("OPf9aZ");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
