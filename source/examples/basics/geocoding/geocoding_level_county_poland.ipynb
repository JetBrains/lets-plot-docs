# %%
from lets_plot.geo_data import *
from lets_plot import *
LetsPlot.setup_html()
# Out:
# The geodata is provided by © OpenStreetMap contributors and is made available here under the Open Database License (ODbL).
#             <div id="WHW6ep"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.2.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
# ...

# %%
country = 'Poland'
gdf = geocode_counties().scope(country).inc_res(4).get_boundaries()

ggplot() + \
    geom_map(data=gdf, color='white', fill='#18bc9c', \
             tooltips=layer_tooltips().line('@{found name}')) + \
    theme(axis_title='blank', axis_text='blank', axis_ticks='blank', axis_line='blank') + \
    ggsize(800, 600) + ggtitle('{0} Counties'.format(country)) + \
    theme(panel_grid='blank')
# Out:
#    <div id="nXSzP2"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank",
# "panel_grid":"blank"
# },
# "ggsize":{
# "width":800.0,
# "height":600.0
# },
# "ggtitle":{
# "text":"Poland Counties"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"map",
# "data":{
# ...
