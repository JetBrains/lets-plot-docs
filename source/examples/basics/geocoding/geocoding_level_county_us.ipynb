# %%
from lets_plot.geo_data import *
from lets_plot import *
LetsPlot.setup_html()
# Out:
# The geodata is provided by © OpenStreetMap contributors and is made available here under the Open Database License (ODbL).
#             <script type="text/javascript" data-lets-plot-script="library">
#                 window.letsPlotCall = function(f) {f();};
#                 console.log('Embedding: lets-plot-latest.min.js');
#                 (()=>{var __webpack_modules__={73:function(t,e,n){var i,r,o;r=[e,n(421)],void 0===(o="function"==typeof(i=function(t,e){"use strict";e.defineInlineFunction,e.wrapFunction;var n=e.Kind.INTERFACE,i=e.Kind.OBJECT,r=e.toString,o=e.equals,a=e.kotlin.Exception,s=e.kotlin.js.get_js_1yb8b7$,l=e.kotlin.Enum,u=e.Kind.CLASS,c=e.throwISE,p=e.kotlin.Unit,h=e.getCallableRef;function _(){}function d(){f=this}I.prototype=Object.create(l.prototype),I.prototype.constructor=I,_.$metadata$={kind:n,simpleName:"Appender",interfaces:[]},d.prototype.trace_s8jyv4$=function(t){console.log(t)},d.prototype.debug_s8jyv4$=function(t){console.log(t)},d.prototype.info_s8jyv4$=function(t){console.info(t)},d.prototype.warn_s8jyv4$=function(t){console.warn(t)},d.prototype.error_s8jyv4$=function(t){console.error(t)},d.$metadata$={kind:i,simpleName:"ConsoleOutputAppender",interfaces:[_]};var f=null;function m(){return null===f&&new d,f}function $(){y=this}$.prototype.formatMessage_pijeg6$=function(t,n,i){var o,s=t.name+": ["+n+"] ";try{o=r(i())}catch(t){if(!e.isType(t,a))throw t;o=K.ErrorMessageProducer.getErrorLog_3lhtaa$(t)}return s+o},$.prototype.formatMessage_hqgb2y$=function(t,n,i,o){var s,l=t.name+": ["+n+"] ";try{s=r(o())}catch(t){if(!e.isType(t,a))throw t;s=K.ErrorMessageProducer.getErrorLog_3lhtaa$(t)}return l+s+this.throwableToString_0(i)},$.prototype.formatMessage_i9qi47$=function(t,n,i,o){var s,l=t.name+": ["+n+"] "+r(null!=i?i.getName():null)+" ";try{s=r(o())}catch(t){if(!e.isType(t,a))throw t;s=K.ErrorMessageProducer.getErrorLog_3lhtaa$(t)}return l+s},$.prototype.formatMessage_fud0c7$=function(t,n,i,o,s){var l,u=t.name+": ["+n+"] "+r(null!=i?i.getName():null)+" ";try{l=r(s())}catch(t){if(!e.isType(t,a))throw t;l=K.ErrorMessageProducer.getErrorLog_3lhtaa$(t)}return u+l+this.throwableToString_0(o)},$.prototype.throwableToString_0=function(t){if(null==t)return"";for(var e="",n=t;null!=n&&!o(n.cause,n);)e+=", Caused by: '"+r(n.message)+"'",n=n.cause;return e},$.$metadata$={kind:i,simpleName:"DefaultMessageFormatter",interfaces:[v]};var y=null;function g(){return null===y&&new $,y}function v(){}function b(){}function x(){w=this}v.$metadata$={kind:n,simpleName:"Formatter",interfaces:[]},b.$metadata$={kind:n,simpleName:"KLogger",interfaces:[]},x.prototype.logger_o14v8n$=function(t){return new U(s(e.getKClassFromExpression(t)).name)},x.prototype.logger_61zpoe$=function(t){return new U(t)},x.$metadata$={kind:i,simpleName:"KotlinLogging",interfaces:[]};var w=null;function C(){N=this,this.LOG_LEVEL=L(),this.APPENDER=m(),this.FORMATTER=g()}C.$metadata$={kind:i,simpleName:"KotlinLoggingConfiguration",interfaces:[]};var k,E,S,T,O,N=null;function P(){return null===N&&new C,N}function I(t,e){l.call(this),this.name$=t,this.ordinal$=e}function A(){A=function(){},k=new I("TRACE",0),E=new I("DEBUG",1),S=new I("INFO",2),T=new I("WARN",3),O=new I("ERROR",4)}function R(){return A(),k}function j(){return A(),E}function L(){return A(),S}function z(){return A(),T}function D(){return A(),O}function M(t){return t.ordinal>=P().LOG_LEVEL.ordinal}function F(){B=this}I.$metadata$={kind:u,simpleName:"KotlinLoggingLevel",interfaces:[l]},I.values=function(){return[R(),j(),L(),z(),D()]},I.valueOf_61zpoe$=function(t){switch(t){case"TRACE":return R();case"DEBUG":return j();case"INFO":return L();case"WARN":return z();case"ERROR":return D();default:c("No enum constant mu.KotlinLoggingLevel."+t)}},F.prototype.getErrorLog_3lhtaa$=function(t){return"Log message invocation failed: "+t},F.$metadata$={kind:i,simpleName:"ErrorMessageProducer",interfaces:[]};var B=null;function U(t){this.loggerName_0=t}function q(){return"exit()"}U.prototype.trace_nq59yw$=function(t){this.logIfEnabled_0(R(),t,h("trace",function(t,e){return t.trace_s8jyv4$(e),p}.bind(null,P().APPENDER)))},U.prototype.debug_nq59yw$=function(t){this.logIfEnabled_0(j(),t,h("debug",function(t,e){return t.debug_s8jyv4$(e),p}.bind(null,P().APPENDER)))},U.prototype.info_nq59yw$=function(t){this.logIfEnabled_0(L(),t,h("inf ...

# %%
gdf = geocode_counties().scope('US-48').inc_res().get_boundaries()

ggplot() + \
    geom_map(data=gdf, color='white', fill='#18bc9c', \
             tooltips=layer_tooltips().line('@{found name}')) + \
    theme(axis_title='blank', axis_text='blank', axis_ticks='blank', axis_line='blank') + \
    ggsize(800, 600) + ggtitle('US Counties') + \
    theme(panel_grid='blank')
# Out:
#    <div id="fFytii"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank",
# "panel_grid":"blank"
# },
# "ggsize":{
# "width":800,
# "height":600
# },
# "ggtitle":{
# "text":"US Counties"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"map",
# "data":{
# "found name":["Bennington County","Windham County","Windsor County","Rutland County","Berkshire County","Grand Isle County","Franklin County","Chittenden County","Addison County","Washington County","Lamoille County","Orleans County","Caledonia County","Orange County","Strafford County","Orleans County","Rockingham County","Erie County","Niagara County","Clinton County","Essex County","Franklin County","Saint Lawrence County","Hamilton County","Warren County","Essex County","Hays County","Comal County","Blanco County","Travis County","Caldwell County","Guadalupe County","Bexar County","Kendall County","Warren County","Clermont County","Clinton County","Greene County","Montgomery County","Butler County","Hamilton County","Essex County","Genesee County","Cattaraugus County","Cook County","Fayette County","Baltimore City","Deer Lodge County","Brown County","Douglas County","Lyon County","Washoe County","Eureka County","Humboldt County","Pershing County","Carson City","Mineral County","Elko County","Lincoln County","Churchill County","Nye County","Lander County","White Pine County","Clark County","Esmeralda County","Storey County","Franklin County","Madison County","Union County","Delaware County","Licking County","Fairfield County","Pickaway County","Clark County","Champaign County","Logan County","Marion County","Morrow County","Knox County","Suffolk","Petersburg","Manassas Park","Alexandria","Virginia Beach","Chesapeake","Norfolk","Portsmouth","Williamsburg","Harrisonburg","Manassas","Fairfax","Emporia","Dearborn County","Coshocton County","Muskingum County","Perry County","Hocking County","Ross County","Fayette County","Waukesha County","Milwaukee County","Washington County","Sheboygan County","Fond du Lac County","Green Lake County","Dodge County","Winnebago County","Waushara County","Outagamie County","Calumet County","Marathon County","Waupaca County","Portage County","Shawano County","Wood County","Adams County","Clark County","Taylor County","Lincoln County","Oneida County","Vilas County","Forest County","Brown County","Manitowoc County","Kewaunee County","Door County","Price County","Iron County","Ashland County","Sawyer County","Bayfield County","Chippewa County","Rusk County","Juneau County","Monroe County","Jackson County","Dubuque County","Highland County","New Haven County","Fremont County","Natrona County","Washakie County","Hot Springs County","Park County","Carbon County","Johnson County","Converse County","Campbell County","Sheridan County","Big Horn County","Teton County","Sublette County","Lincoln County","Platte County","Goshen County","Niobrara County","Weston County","Crook County","Big Horn County","Uinta County","Hillsborough County","Merrimack County","Lorain County","Erie County","Lake County","Ottawa County","Cuyahoga County","Ashtabula County","Lucas County","Oakland County","Macomb County","Lapeer County","Genesee County","Livingston County","Washtenaw County","Wayne County","Boone County","Kenton County","Campbell County","Belknap County","Kings County","Queens County","Polk County","Le Flore County","Orange County","Seminole County","Osceola County","Brevard County","Volusia County","Lake County","Kent County","Humboldt County","Tulare County","Sacramento County","Marin County","Contra Costa County","Napa County","Nevada County","Mariposa County","Orange County","San Joaquin County","Sonoma County","Lassen County","Calaveras County","Tuolumne County","Mono County","Sierra County","Yuba County","Colusa County","Plumas County","Sutter County","Los Angeles County","Kings County","El Dorado County","San Diego County","Siskiyou County","Trinity County","Monterey County","Tehama County","San Francisco City and County","Madera County","Mendocino County","Amador County","Inyo County","Fresno County","Glenn County","Kern County","Riverside County","San Luis Obispo County","Alpine County","San Mateo County","Alameda County","San Benito County","Santa Clara County","Lake County","Del Norte County","Merced Cou ...
