# %% [markdown]
# # Identity Scales
#
# Use data values **as** visual values.

# %%
import pandas as pd

from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="T93TDC"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.0.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("T93TDC").appendChild(div);
#                     };
#                     var e = document.getElementById("T93TDC");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
df = pd.read_csv('https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/mpg.csv')

# %%
p = ggplot(df, aes(x='cyl')) + \
    geom_bar(aes(size='cyl'), color='#54278f', fill='#f2f0f7', show_legend=False)
p1 = p + ggtitle('Default')
p2 = p + scale_size_identity() + ggtitle('With Scale')

w, h = 400, 300
bunch = GGBunch()
bunch.add_plot(p1, 0, 0, w, h)
bunch.add_plot(p2, w, 0, w, h)
bunch.show()
# Out:
#    <div id="xusXPz"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0.0,
# "y":0.0,
# "width":400.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# "x":"cyl"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "size":"cyl"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"#54278f",
# "fill":"#f2f0f7",
# "data":{
# "..count..":[81.0,79.0,70.0,4.0],
# "cyl":[4.0,6.0,8.0,5.0]
# }
# }],
# "metainfo_list":[]
# }
# },{
# "x":400.0,
# "y":0.0,
# "width":400.0,
# "height":300.0,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# "x":"cyl"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"With Scale"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"size",
# "guide":"none",
# "scale_mapper_kind":"identity"
# }],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "size":"cyl"
# },
# "show_legend":false,
# "data_meta":{
# },
# "color":"#54278f",
# "fill":"#f2f0f7",
# "data":{
# "..count..":[81.0,79.0,70.0,4.0],
# "cyl":[4.0,6.0,8.0,5.0]
# }
# }],
# "metainfo_list":[]
# }
# }]
# };
#            var plotContainer = document.getElementById("xusXPz");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
