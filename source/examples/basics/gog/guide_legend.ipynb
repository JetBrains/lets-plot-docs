# %% [markdown]
# # guide_legend()

# %%
import pandas as pd

from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="G9AfQ4"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v3.2.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("G9AfQ4").appendChild(div);
#                     };
#                     var e = document.getElementById("G9AfQ4");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
df = pd.read_csv('https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/mpg.csv')

# %%
ggplot(df, aes(x='fl')) + \
    geom_bar(aes(fill='manufacturer'), tooltips=layer_tooltips().line('@manufacturer')\
                                                                .line('fuel type|@fl')\
                                                                .line('count|@..count..')) + \
    scale_fill_discrete(guide=guide_legend(nrow=3)) + \
    ggsize(700, 400) + \
    theme(legend_position='bottom')
# Out:
#    <div id="L2de8q"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"fl"
# },
# "data_meta":{
# },
# "ggsize":{
# "width":700.0,
# "height":400.0
# },
# "theme":{
# "legend_position":"bottom"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"fill",
# "guide":{
# "name":"legend",
# "nrow":3.0
# },
# "discrete":true
# }],
# "layers":[{
# "geom":"bar",
# "mapping":{
# "fill":"manufacturer"
# },
# "tooltips":{
# "formats":[],
# "lines":["@manufacturer","fuel type|@fl","count|@..count.."]
# },
# "data_meta":{
# },
# "data":{
# "..count..":[18.0,11.0,2.0,5.0,1.0,32.0,5.0,24.0,1.0,6.0,2.0,1.0,14.0,1.0,5.0,1.0,1.0,2.0,2.0,2.0,1.0,4.0,8.0,5.0,3.0,2.0,10.0,4.0,34.0,13.0,11.0,3.0],
# "fl":["p","r","e","p","d","r","e","r","p","r","p","c","r","d","r","e","p","p","r","r","p","r","r","p","r","p","r","p","r","r","p","d"],
# "manufacturer":["audi","chevrolet","chevrolet","chevrolet","chevrolet","dodge","dodge","ford","ford","honda","honda","honda","hyundai","jeep","jeep","jeep","jeep","land rover","land rover","lincoln","lincoln","mercury","nissan","nissan","pontiac","pontiac","subaru","subaru","toyota","volkswagen","volkswagen","volkswagen"]
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("L2de8q");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
