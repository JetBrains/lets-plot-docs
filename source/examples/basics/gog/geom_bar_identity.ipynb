# %% [markdown]
# # geom_bar(stat='identity')

# %%
import pandas as pd

from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="iII8hz"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.2.1/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("iII8hz").appendChild(div);
#                     };
#                     var e = document.getElementById("iII8hz");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
df = pd.read_csv('https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/mpg.csv')
df = df.sort_values(by='class')

# %%
count_df = df.groupby('class').count().iloc[:, 0].to_frame('count').reset_index()

ggplot(count_df, aes('class', 'count')) + geom_bar(stat='identity')
# Out:
#    <div id="qePLwd"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "class":["2seater","compact","midsize","minivan","pickup","subcompact","suv"],
# "count":[5.0,47.0,41.0,11.0,33.0,35.0,62.0]
# },
# "mapping":{
# "x":"class",
# "y":"count"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("qePLwd");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
ggplot(df, aes('class')) + geom_bar()
# Out:
#    <div id="UJO8mP"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# },
# "mapping":{
# "x":"class"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "..count..":[5.0,47.0,41.0,11.0,33.0,35.0,62.0],
# "class":["2seater","compact","midsize","minivan","pickup","subcompact","suv"]
# }
# }]
# };
#            var plotContainer = document.getElementById("UJO8mP");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
