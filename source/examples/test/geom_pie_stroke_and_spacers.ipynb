# %%
from lets_plot import *

LetsPlot.setup_html()
# Out:
#             <div id="g0BY8U"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.4.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("g0BY8U").appendChild(div);
#                     };
#                     var e = document.getElementById("g0BY8U");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
data = {
    'Fruit': ['Apple', 'Banana', 'Orange', 'Grapes', 'Mango'],
    'Quantity': [20, 15, 10, 12, 18],
    'Price': [80, 50, 70, 70, 100],
    'Origin': ['J&K', 'BH', 'MP', 'WB', 'BH'] 
}

# %%
blank_theme = theme(line=element_blank(), axis=element_blank())

# %% [markdown]
# ### Default

# %%
ggplot(data) + blank_theme + \
    geom_pie(aes(fill='Fruit', slice='Quantity'), stat='identity', size=20)
# Out:
#    <div id="Qp3419"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "Fruit":["Apple","Banana","Orange","Grapes","Mango"],
# "Quantity":[20.0,15.0,10.0,12.0,18.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Fruit"
# },{
# "type":"int",
# "column":"Quantity"
# },{
# "type":"int",
# "column":"Price"
# },{
# "type":"str",
# "column":"Origin"
# }]
# },
# "theme":{
# "line":{
# "blank":true
# },
# "axis":{
# "blank":true
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"Fruit",
# "slice":"Quantity"
# },
# "data_meta":{
# },
# "size":20.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("Qp3419");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Specify `color`

# %%
ggplot(data) + blank_theme + \
    geom_pie(aes(fill='Fruit', slice='Quantity'),
             stat='identity', size=20,
             color='#990000')
# Out:
#    <div id="AfSyEp"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "Fruit":["Apple","Banana","Orange","Grapes","Mango"],
# "Quantity":[20.0,15.0,10.0,12.0,18.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Fruit"
# },{
# "type":"int",
# "column":"Quantity"
# },{
# "type":"int",
# "column":"Price"
# },{
# "type":"str",
# "column":"Origin"
# }]
# },
# "theme":{
# "line":{
# "blank":true
# },
# "axis":{
# "blank":true
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"Fruit",
# "slice":"Quantity"
# },
# "data_meta":{
# },
# "size":20.0,
# "color":"#990000",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("AfSyEp");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Specify `stroke`

# %%
ggplot(data) + blank_theme + \
    geom_pie(aes(fill='Fruit', slice='Quantity'),
             stat='identity', size=20,
             color='#990000', stroke=15)
# Out:
#    <div id="cFbiCN"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "Fruit":["Apple","Banana","Orange","Grapes","Mango"],
# "Quantity":[20.0,15.0,10.0,12.0,18.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Fruit"
# },{
# "type":"int",
# "column":"Quantity"
# },{
# "type":"int",
# "column":"Price"
# },{
# "type":"str",
# "column":"Origin"
# }]
# },
# "theme":{
# "line":{
# "blank":true
# },
# "axis":{
# "blank":true
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"Fruit",
# "slice":"Quantity"
# },
# "data_meta":{
# },
# "size":20.0,
# "color":"#990000",
# "stroke":15.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("cFbiCN");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Specify `stroke_side`
#
# Note: for a pie chart without a hole, if you specify to draw an inner arc (stroke_side = 'both' or 'inner'), a hole will be added.

# %%
def pie_with_stroke(side, hole):
    return ggplot(data) + blank_theme + \
        ggtitle("stroke_side='{0}', hole={1}".format(side, hole)) + \
        geom_pie(aes(fill='Fruit', slice='Quantity', color='Fruit'),
                 stat='identity', 
                 size=15,
                 stroke=10,
                 hole=hole,
                 stroke_side=side) + \
        scale_color_brewer(palette='Dark2') + \
        theme(legend_position='none')

gggrid([
    pie_with_stroke("both", hole=0),
    pie_with_stroke("outer", hole=0),
    pie_with_stroke("inner", hole=0),
    
    pie_with_stroke("both", hole=0.3),
    pie_with_stroke("outer", hole=0.3),
    pie_with_stroke("inner", hole=0.3)
], ncol=3)
# Out:
#    <div id="IJx7gY"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":2.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "Fruit":["Apple","Banana","Orange","Grapes","Mango"],
# "Quantity":[20.0,15.0,10.0,12.0,18.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Fruit"
# },{
# "type":"int",
# "column":"Quantity"
# },{
# "type":"int",
# "column":"Price"
# },{
# "type":"str",
# "column":"Origin"
# }]
# },
# "theme":{
# "line":{
# "blank":true
# },
# "axis":{
# "blank":true
# },
# "legend_position":"none"
# },
# "ggtitle":{
# "text":"stroke_side='both', hole=0"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"color",
# "palette":"Dark2",
# "scale_mapper_kind":"color_brewer"
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"Fruit",
# "slice":"Quantity",
# "color":"Fruit"
# },
# "data_meta":{
# },
# "hole":0.0,
# "stroke_side":"both",
# "size":15.0,
# "stroke":10.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# "Fruit":["Apple","Banana","Orange","Grapes","Mango"],
# "Quantity":[20.0,15.0,10.0,12.0,18.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Fruit"
# },{
# "type":"int",
# "column":"Quantity"
# },{
# "type":"int",
# "column":"Price"
# },{
# "type":"str",
# "column":"Origin"
# }]
# },
# "theme":{
# "line":{
# "blank":true
# },
# "axis":{
# "blank":true
# },
# "legend_position":"none"
# },
# "ggtitle":{
# "text":"stroke_side='outer', hole=0"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"color",
# "palette":"Dark2",
# "scale_mapper_kind":"color_brewer"
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"Fruit",
# "slice":"Quantity",
# "color":"Fruit"
# },
# "data_meta":{
# },
# "hole":0.0,
# "stroke_side":"outer",
# "size":15.0,
# "stroke":10.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# "Fruit":["Apple","Banana","Orange","Grapes","Mango"],
# "Quantity":[20.0,15.0,10.0,12.0,18.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Fruit"
# },{
# "type":"int",
# "column":"Quantity"
# },{
# "type":"int",
# "column":"Price"
# },{
# "type":"str",
# "column":"Origin"
# }]
# },
# "theme":{
# "line":{
# "blank":true
# },
# "axis":{
# "blank":true
# },
# "legend_position":"none"
# },
# "ggtitle":{
# "text":"stroke_side='inner', hole=0"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"color",
# "palette":"Dark2",
# "scale_mapper_kind":"color_brewer"
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"Fruit",
# "slice":"Quantity",
# "color":"Fruit"
# },
# "data_meta":{
# },
# "hole":0.0,
# "stroke_side":"inner",
# "size":15.0,
# "stroke":10.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# "Fruit":["Apple","Banana","Orange","Grapes","Mango"],
# "Quantity":[20.0,15.0,10.0,12.0,18.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Fruit"
# },{
# "type":"int",
# "column":"Quantity"
# },{
# "type":"int",
# "column":"Price"
# },{
# "type":"str",
# "column":"Origin"
# }]
# },
# "theme":{
# "line":{
# "blank":true
# },
# "axis":{
# "blank":true
# },
# "legend_position":"none"
# },
# "ggtitle":{
# "text":"stroke_side='both', hole=0.3"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"color",
# "palette":"Dark2",
# "scale_mapper_kind":"color_brewer"
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"Fruit",
# "slice":"Quantity",
# "color":"Fruit"
# },
# "data_meta":{
# },
# "hole":0.3,
# "stroke_side":"both",
# "size":15.0,
# "stroke":10.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# "Fruit":["Apple","Banana","Orange","Grapes","Mango"],
# "Quantity":[20.0,15.0,10.0,12.0,18.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Fruit"
# },{
# "type":"int",
# "column":"Quantity"
# },{
# "type":"int",
# "column":"Price"
# },{
# "type":"str",
# "column":"Origin"
# }]
# },
# "theme":{
# "line":{
# "blank":true
# },
# "axis":{
# "blank":true
# },
# "legend_position":"none"
# },
# "ggtitle":{
# "text":"stroke_side='outer', hole=0.3"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"color",
# "palette":"Dark2",
# "scale_mapper_kind":"color_brewer"
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"Fruit",
# "slice":"Quantity",
# "color":"Fruit"
# },
# "data_meta":{
# },
# "hole":0.3,
# "stroke_side":"outer",
# "size":15.0,
# "stroke":10.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# "Fruit":["Apple","Banana","Orange","Grapes","Mango"],
# "Quantity":[20.0,15.0,10.0,12.0,18.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Fruit"
# },{
# "type":"int",
# "column":"Quantity"
# },{
# "type":"int",
# "column":"Price"
# },{
# "type":"str",
# "column":"Origin"
# }]
# },
# "theme":{
# "line":{
# "blank":true
# },
# "axis":{
# "blank":true
# },
# "legend_position":"none"
# },
# "ggtitle":{
# "text":"stroke_side='inner', hole=0.3"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"color",
# "palette":"Dark2",
# "scale_mapper_kind":"color_brewer"
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"Fruit",
# "slice":"Quantity",
# "color":"Fruit"
# },
# "data_meta":{
# },
# "hole":0.3,
# "stroke_side":"inner",
# "size":15.0,
# "stroke":10.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("IJx7gY");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Mapping (check legend)

# %%
# 'fill', 'color', 'stroke' - to variable 'Fruit'

ggplot(data) + blank_theme + \
    geom_pie(aes(fill='Fruit', slice='Quantity', color='Fruit', stroke='Fruit'),
             stat='identity', size=20, 
             hole=0.3) + \
    scale_color_brewer(palette='Dark2')
# Out:
#    <div id="YBw7HY"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "Fruit":["Apple","Banana","Orange","Grapes","Mango"],
# "Quantity":[20.0,15.0,10.0,12.0,18.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Fruit"
# },{
# "type":"int",
# "column":"Quantity"
# },{
# "type":"int",
# "column":"Price"
# },{
# "type":"str",
# "column":"Origin"
# }]
# },
# "theme":{
# "line":{
# "blank":true
# },
# "axis":{
# "blank":true
# }
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"color",
# "palette":"Dark2",
# "scale_mapper_kind":"color_brewer"
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"Fruit",
# "slice":"Quantity",
# "color":"Fruit",
# "stroke":"Fruit"
# },
# "data_meta":{
# },
# "hole":0.3,
# "size":20.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("YBw7HY");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# color = 'Fruit', stroke = 'Quantity'

ggplot(data) + blank_theme + \
    geom_pie(aes(fill='Fruit', slice='Quantity', color='Fruit', stroke='Quantity'),
             stat='identity', size=20, 
             hole=0.3) + \
    scale_color_brewer(palette='Dark2')
# Out:
#    <div id="MY3sgJ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "Fruit":["Apple","Banana","Orange","Grapes","Mango"],
# "Quantity":[20.0,15.0,10.0,12.0,18.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Fruit"
# },{
# "type":"int",
# "column":"Quantity"
# },{
# "type":"int",
# "column":"Price"
# },{
# "type":"str",
# "column":"Origin"
# }]
# },
# "theme":{
# "line":{
# "blank":true
# },
# "axis":{
# "blank":true
# }
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"color",
# "palette":"Dark2",
# "scale_mapper_kind":"color_brewer"
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"Fruit",
# "slice":"Quantity",
# "color":"Fruit",
# "stroke":"Quantity"
# },
# "data_meta":{
# },
# "hole":0.3,
# "size":20.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("MY3sgJ");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# All to different variables

ggplot(data) + blank_theme + \
    geom_pie(aes(fill='Fruit', slice='Quantity', color='Origin', stroke='Price'),
             stat='identity', size=20, 
             hole=0.3) + \
    scale_color_brewer(palette='Set1', guide=guide_legend(nrow=1))
# Out:
#    <div id="bNddqR"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "Fruit":["Apple","Banana","Orange","Grapes","Mango"],
# "Quantity":[20.0,15.0,10.0,12.0,18.0],
# "Price":[80.0,50.0,70.0,70.0,100.0],
# "Origin":["J&K","BH","MP","WB","BH"]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Fruit"
# },{
# "type":"int",
# "column":"Quantity"
# },{
# "type":"int",
# "column":"Price"
# },{
# "type":"str",
# "column":"Origin"
# }]
# },
# "theme":{
# "line":{
# "blank":true
# },
# "axis":{
# "blank":true
# }
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"color",
# "guide":{
# "name":"legend",
# "nrow":1.0
# },
# "palette":"Set1",
# "scale_mapper_kind":"color_brewer"
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"Fruit",
# "slice":"Quantity",
# "color":"Origin",
# "stroke":"Price"
# },
# "data_meta":{
# },
# "hole":0.3,
# "size":20.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("bNddqR");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### `spacer_width` parameter

# %%
ggplot(data) + blank_theme + \
    geom_pie(aes(fill='Fruit', slice='Quantity', color='Fruit'),
             stat='identity', size=20, 
             hole=0.3,
             stroke=15,
             spacer_width=5) + \
    scale_color_brewer(palette='Dark2')
# Out:
#    <div id="uWxEGh"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "Fruit":["Apple","Banana","Orange","Grapes","Mango"],
# "Quantity":[20.0,15.0,10.0,12.0,18.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Fruit"
# },{
# "type":"int",
# "column":"Quantity"
# },{
# "type":"int",
# "column":"Price"
# },{
# "type":"str",
# "column":"Origin"
# }]
# },
# "theme":{
# "line":{
# "blank":true
# },
# "axis":{
# "blank":true
# }
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"color",
# "palette":"Dark2",
# "scale_mapper_kind":"color_brewer"
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"Fruit",
# "slice":"Quantity",
# "color":"Fruit"
# },
# "data_meta":{
# },
# "hole":0.3,
# "spacer_width":5.0,
# "size":20.0,
# "stroke":15.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("uWxEGh");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### With flavor

# %%
ggplot(data) + blank_theme + \
    geom_pie(aes(fill='Fruit', slice='Quantity', color='Fruit'),
             stat='identity', size=20, 
             hole=0.3,
             stroke=15,
             spacer_width=5) + \
    scale_color_brewer(palette='Dark2') + \
    flavor_solarized_dark()
# Out:
#    <div id="vEaKmv"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "Fruit":["Apple","Banana","Orange","Grapes","Mango"],
# "Quantity":[20.0,15.0,10.0,12.0,18.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Fruit"
# },{
# "type":"int",
# "column":"Quantity"
# },{
# "type":"int",
# "column":"Price"
# },{
# "type":"str",
# "column":"Origin"
# }]
# },
# "theme":{
# "line":{
# "blank":true
# },
# "axis":{
# "blank":true
# },
# "flavor":"solarized_dark"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"color",
# "palette":"Dark2",
# "scale_mapper_kind":"color_brewer"
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"Fruit",
# "slice":"Quantity",
# "color":"Fruit"
# },
# "data_meta":{
# },
# "hole":0.3,
# "spacer_width":5.0,
# "size":20.0,
# "stroke":15.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("vEaKmv");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### `spacer_color` parameter

# %%
ggplot(data) + blank_theme + \
    geom_pie(aes(fill='Fruit', slice='Quantity', color='Fruit'),
             stat='identity', size=20, 
             hole=0.3,
             stroke=15,
             spacer_width=5,
             spacer_color='white') + \
    scale_color_brewer(palette='Dark2') + \
    flavor_solarized_dark()
# Out:
#    <div id="iDxoxN"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "Fruit":["Apple","Banana","Orange","Grapes","Mango"],
# "Quantity":[20.0,15.0,10.0,12.0,18.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"Fruit"
# },{
# "type":"int",
# "column":"Quantity"
# },{
# "type":"int",
# "column":"Price"
# },{
# "type":"str",
# "column":"Origin"
# }]
# },
# "theme":{
# "line":{
# "blank":true
# },
# "axis":{
# "blank":true
# },
# "flavor":"solarized_dark"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"color",
# "palette":"Dark2",
# "scale_mapper_kind":"color_brewer"
# }],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"Fruit",
# "slice":"Quantity",
# "color":"Fruit"
# },
# "data_meta":{
# },
# "hole":0.3,
# "spacer_width":5.0,
# "spacer_color":"white",
# "size":20.0,
# "stroke":15.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("iDxoxN");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### With `explode`
#
# Do not draw spacer lines for exploded sectors and their neighbors

# %%
length = {
  'name' : ['20-50 km', '50-75 km', '10-20 km', '75-100 km', '3-5 km', '7-10 km', '5-7 km', '>100 km', '2-3 km'],
  'count': [1109, 696, 353, 192, 168, 86, 74, 65, 53],
  'explode': [0, 0, 0, 0.1, 0.1, 0.2, 0.3, 0.4, 0.6]
}


p = ggplot(length) + blank_theme + theme(legend_position='none') + flavor_solarized_light()
gggrid([
    p + geom_pie(aes(fill='name', slice='count', explode='explode'), stat='identity', 
                 size=20) + ggtitle("Default"),
    p + geom_pie(aes(fill='name', slice='count', explode='explode'), stat='identity', size=20,
                 color='black', spacer_color='black') + ggtitle("Add 'spacer_color'"),
    p + geom_pie(aes(fill='name', slice='count', explode='explode'), stat='identity', size=20, 
                 color='black', spacer_color='black',
                 hole=0.2, stroke_side='both') + ggtitle("Add hole and stroke_side='both'"),
])
# Out:
#    <div id="x4YRUo"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":1.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "name":["20-50 km","50-75 km","10-20 km","75-100 km","3-5 km","7-10 km","5-7 km",">100 km","2-3 km"],
# "count":[1109.0,696.0,353.0,192.0,168.0,86.0,74.0,65.0,53.0],
# "explode":[0.0,0.0,0.0,0.1,0.1,0.2,0.3,0.4,0.6]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"count"
# },{
# "type":"unknown(mixed types)",
# "column":"explode"
# }]
# },
# "theme":{
# "line":{
# "blank":true
# },
# "axis":{
# "blank":true
# },
# "legend_position":"none",
# "flavor":"solarized_light"
# },
# "ggtitle":{
# "text":"Default"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"count",
# "explode":"explode"
# },
# "data_meta":{
# },
# "size":20.0,
# "data":{
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# "name":["20-50 km","50-75 km","10-20 km","75-100 km","3-5 km","7-10 km","5-7 km",">100 km","2-3 km"],
# "count":[1109.0,696.0,353.0,192.0,168.0,86.0,74.0,65.0,53.0],
# "explode":[0.0,0.0,0.0,0.1,0.1,0.2,0.3,0.4,0.6]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"count"
# },{
# "type":"unknown(mixed types)",
# "column":"explode"
# }]
# },
# "theme":{
# "line":{
# "blank":true
# },
# "axis":{
# "blank":true
# },
# "legend_position":"none",
# "flavor":"solarized_light"
# },
# "ggtitle":{
# "text":"Add 'spacer_color'"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"count",
# "explode":"explode"
# },
# "data_meta":{
# },
# "spacer_color":"black",
# "size":20.0,
# "color":"black",
# "data":{
# }
# }],
# "metainfo_list":[]
# },{
# "data":{
# "name":["20-50 km","50-75 km","10-20 km","75-100 km","3-5 km","7-10 km","5-7 km",">100 km","2-3 km"],
# "count":[1109.0,696.0,353.0,192.0,168.0,86.0,74.0,65.0,53.0],
# "explode":[0.0,0.0,0.0,0.1,0.1,0.2,0.3,0.4,0.6]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"count"
# },{
# "type":"unknown(mixed types)",
# "column":"explode"
# }]
# },
# "theme":{
# "line":{
# "blank":true
# },
# "axis":{
# "blank":true
# },
# "legend_position":"none",
# "flavor":"solarized_light"
# },
# "ggtitle":{
# "text":"Add hole and stroke_side='both'"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"pie",
# "stat":"identity",
# "mapping":{
# "fill":"name",
# "slice":"count",
# "explode":"explode"
# },
# "data_meta":{
# },
# "hole":0.2,
# "stroke_side":"both",
# "spacer_color":"black",
# "size":20.0,
# "color":"black",
# "data":{
# }
# }],
# "metainfo_list":[]
# }]
# };
#            var plotContainer = document.getElementById("x4YRUo");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ### Pie-chart on Map

# %%
from lets_plot.geo_data import *

p_data = {"city": ["New York", "New York", "Philadelphia", "Philadelphia"], \
        "est_pop_2020": [4_381_593, 3_997_959, 832_685, 748_846], \
        "sex": ["female", "male", "female", "male"]}

centroids = geocode_cities(p_data["city"]).get_centroids()
# Out:
# The geodata is provided by © OpenStreetMap contributors and is made available here under the Open Database License (ODbL).

# %%
# Default 

ggplot() + geom_livemap() + \
    geom_pie(aes(slice='est_pop_2020', fill='sex', size='est_pop_2020'),
             stat='identity', data=p_data, map=centroids, map_join='city') + \
    scale_size(range=[5,10], guide='none')
# Out:
#    <div id="dkPh3g"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"size",
# "guide":"none",
# "range":[5.0,10.0]
# }],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"pie",
# "stat":"identity",
# "data":{
# "city":["New York","New York","Philadelphia","Philadelphia"],
# "est_pop_2020":[4381593.0,3997959.0,832685.0,748846.0],
# "sex":["female","male","female","male"]
# },
# "mapping":{
# "slice":"est_pop_2020",
# "fill":"sex",
# "size":"est_pop_2020"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"city"
# },{
# "type":"int",
# "column":"est_pop_2020"
# },{
# "type":"str",
# "column":"sex"
# }]
# },
# "map":{
# "city":["New York","New York","Philadelphia","Philadelphia"],
# "found name":["New York","New York","Philadelphia","Philadelphia"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-73.8673749469137, 40.6847005337477]}","{\"type\": \"Point\", \"coordinates\": [-73.8673749469137, 40.6847005337477]}","{\"type\": \"Point\", \"coordinates\": [-75.1393639560221, 40.0024095922709]}","{\"type\": \"Point\", \"coordinates\": [-75.1393639560221, 40.0024095922709]}"]
# },
# "map_join":[["city"],["city"]],
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("dkPh3g");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %%
# New parameters

ggplot() + geom_livemap() + \
    geom_pie(aes(slice='est_pop_2020', fill='sex', size='est_pop_2020'),
             stat='identity', data=p_data, map=centroids, map_join='city',
             color='black', stroke=2, stroke_side='both',
             spacer_color='black', spacer_width=2, 
             alpha=0.6) + \
    scale_size(range=[5,10], guide='none')
# Out:
#    <div id="0gmsSr"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "mapping":{
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"size",
# "guide":"none",
# "range":[5.0,10.0]
# }],
# "layers":[{
# "geom":"livemap",
# "mapping":{
# },
# "data_meta":{
# },
# "tiles":{
# "kind":"vector_lets_plot",
# "url":"wss://tiles.datalore.jetbrains.com",
# "theme":"color",
# "attribution":"<a href=\"https://lets-plot.org\">© Lets-Plot</a>, map data: <a href=\"https://www.openstreetmap.org/copyright\">© OpenStreetMap contributors</a>."
# },
# "geocoding":{
# "url":"https://geo2.datalore.jetbrains.com/map_data/geocoding"
# },
# "data":{
# }
# },{
# "geom":"pie",
# "stat":"identity",
# "data":{
# "city":["New York","New York","Philadelphia","Philadelphia"],
# "est_pop_2020":[4381593.0,3997959.0,832685.0,748846.0],
# "sex":["female","male","female","male"]
# },
# "mapping":{
# "slice":"est_pop_2020",
# "fill":"sex",
# "size":"est_pop_2020"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"city"
# },{
# "type":"int",
# "column":"est_pop_2020"
# },{
# "type":"str",
# "column":"sex"
# }]
# },
# "map":{
# "city":["New York","New York","Philadelphia","Philadelphia"],
# "found name":["New York","New York","Philadelphia","Philadelphia"],
# "geometry":["{\"type\": \"Point\", \"coordinates\": [-73.8673749469137, 40.6847005337477]}","{\"type\": \"Point\", \"coordinates\": [-73.8673749469137, 40.6847005337477]}","{\"type\": \"Point\", \"coordinates\": [-75.1393639560221, 40.0024095922709]}","{\"type\": \"Point\", \"coordinates\": [-75.1393639560221, 40.0024095922709]}"]
# },
# "map_join":[["city"],["city"]],
# "stroke_side":"both",
# "spacer_width":2.0,
# "spacer_color":"black",
# "color":"black",
# "stroke":2.0,
# "alpha":0.6,
# "map_data_meta":{
# "geodataframe":{
# "geometry":"geometry"
# }
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("0gmsSr");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
