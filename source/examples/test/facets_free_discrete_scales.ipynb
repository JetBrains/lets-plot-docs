# %%
import pandas as pd
from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="WDh9rg"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.3/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("WDh9rg").appendChild(div);
#                     };
#                     var e = document.getElementById("WDh9rg");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
plot_data = pd.DataFrame.from_records([
    ("pet", "cat", 5, "carnivore"),
    ("pet", "dog", 10, "carnivore"),
    ("pet", "rabbit", 2, "herbivore"),
    ("pet", "hamster", 1, "herbivore"),

    ("farm_animal", "cow", 500, "herbivore"),
    ("farm_animal", "pig", 100, "carnivore"),
    ("farm_animal", "horse", 700, "herbivore"),
])
plot_data.columns = ("animal_type", "animal", "weight", "diet")

# %%
plot = (
    ggplot(plot_data, aes(x="animal", y="weight"))
    + geom_bar(stat="identity")
    + theme_bw()
    + theme(
        panel_grid_minor=element_blank()
    )
)
plot
# Out:
#    <div id="dWBkO5"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("dWBkO5");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Two facets, grid, free scales

# %%
plot + facet_grid(x = "animal_type", scales="free")
# Out:
#    <div id="9OU2PJ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "x":"animal_type",
# "scales":"free",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("9OU2PJ");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Two facets, wrap, free scales

# %%
plot + facet_wrap(facets="animal_type", ncol=2, scales="free")
# Out:
#    <div id="GVVcym"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":"animal_type",
# "ncol":2.0,
# "scales":"free",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("GVVcym");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, grid, free x

# %%
plot + facet_grid(x="animal_type", y="diet", scales="free_x")
# Out:
#    <div id="TMeWcd"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "x":"animal_type",
# "y":"diet",
# "scales":"free_x",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("TMeWcd");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, wrap, free x

# %%
plot + facet_wrap(facets=["animal_type", "diet"], ncol=2, scales="free_x")
# Out:
#    <div id="lyiQcn"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":["animal_type","diet"],
# "ncol":2.0,
# "scales":"free_x",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("lyiQcn");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, grid, free y

# %%
plot + facet_grid(x="animal_type", y="diet", scales="free_y")
# Out:
#    <div id="jYXEC6"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "x":"animal_type",
# "y":"diet",
# "scales":"free_y",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("jYXEC6");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, wrap, free y

# %%
plot + facet_wrap(facets=["animal_type", "diet"], ncol=2, scales="free_y")
# Out:
#    <div id="ZmoIi0"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":["animal_type","diet"],
# "ncol":2.0,
# "scales":"free_y",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("ZmoIi0");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, grid, free scales

# %%
plot + facet_grid(x="animal_type", y="diet", scales="free")
# Out:
#    <div id="Y6LXzP"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "x":"animal_type",
# "y":"diet",
# "scales":"free",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("Y6LXzP");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, wrap, free scales

# %%
plot + facet_wrap(facets=["animal_type", "diet"], ncol=2, scales="free")
# Out:
#    <div id="3uY2gN"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":["animal_type","diet"],
# "ncol":2.0,
# "scales":"free",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("3uY2gN");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Y-orientation

# %%
plot_y = (
    ggplot(plot_data, aes(x="weight", y="animal"))
    + geom_bar(stat="identity", orientation="y")
    + theme_bw()
    + theme(
        panel_grid_minor=element_blank()
    )
)
plot_y
# Out:
#    <div id="YBKddX"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("YBKddX");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Two facets, grid, free scales

# %%
plot_y + facet_grid(y = "animal_type", scales="free_y")
# Out:
#    <div id="ba4QJb"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "y":"animal_type",
# "scales":"free_y",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("ba4QJb");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Two facets, wrap, free scales

# %%
plot_y + facet_wrap(facets="animal_type", ncol=2, scales="free")
# Out:
#    <div id="GqBFQg"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":"animal_type",
# "ncol":2.0,
# "scales":"free",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("GqBFQg");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, grid, free x

# %%
plot_y + facet_grid(y="animal_type", x="diet", scales="free_x")
# Out:
#    <div id="GsUrvU"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "x":"diet",
# "y":"animal_type",
# "scales":"free_x",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("GsUrvU");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, wrap, free x

# %%
plot_y + facet_wrap(facets=["animal_type", "diet"], ncol=2, scales="free_x")
# Out:
#    <div id="GG7HqT"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":["animal_type","diet"],
# "ncol":2.0,
# "scales":"free_x",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("GG7HqT");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, grid, free y

# %%
plot_y + facet_grid(y="animal_type", x="diet", scales="free_y")
# Out:
#    <div id="z2L35F"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "x":"diet",
# "y":"animal_type",
# "scales":"free_y",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("z2L35F");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, wrap, free y

# %%
plot_y + facet_wrap(facets=["animal_type", "diet"], ncol=2, scales="free_y")
# Out:
#    <div id="ji0w3n"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":["animal_type","diet"],
# "ncol":2.0,
# "scales":"free_y",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("ji0w3n");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, grid, free scales

# %%
plot_y + facet_grid(y="animal_type", x="diet", scales="free")
# Out:
#    <div id="5ZMohe"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "x":"diet",
# "y":"animal_type",
# "scales":"free",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("5ZMohe");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, wrap, free scales

# %%
plot_y + facet_wrap(facets=["animal_type", "diet"], ncol=2, scales="free")
# Out:
#    <div id="jAgWuN"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":["animal_type","diet"],
# "ncol":2.0,
# "scales":"free",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("jAgWuN");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
