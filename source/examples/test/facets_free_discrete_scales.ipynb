# %%
import pandas as pd
from lets_plot import *

# %%
LetsPlot.setup_html()
# Out:
#             <div id="zi9jKD"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.4.0/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("zi9jKD").appendChild(div);
#                     };
#                     var e = document.getElementById("zi9jKD");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
plot_data = pd.DataFrame.from_records([
    ("pet", "cat", 5, "carnivore"),
    ("pet", "dog", 10, "carnivore"),
    ("pet", "rabbit", 2, "herbivore"),
    ("pet", "hamster", 1, "herbivore"),

    ("farm_animal", "cow", 500, "herbivore"),
    ("farm_animal", "pig", 100, "carnivore"),
    ("farm_animal", "horse", 700, "herbivore"),
])
plot_data.columns = ("animal_type", "animal", "weight", "diet")

# %%
plot = (
    ggplot(plot_data, aes(x="animal", y="weight"))
    + geom_bar(stat="identity")
    + theme_bw()
    + theme(
        panel_grid_minor=element_blank()
    )
)
plot
# Out:
#    <div id="3FI83X"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("3FI83X");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Two facets, grid, free scales

# %%
plot + facet_grid(x = "animal_type", scales="free")
# Out:
#    <div id="EbAH1n"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "x":"animal_type",
# "scales":"free",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("EbAH1n");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Two facets, wrap, free scales

# %%
plot + facet_wrap(facets="animal_type", ncol=2, scales="free")
# Out:
#    <div id="IyPFCM"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":"animal_type",
# "ncol":2.0,
# "scales":"free",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("IyPFCM");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, grid, free x

# %%
plot + facet_grid(x="animal_type", y="diet", scales="free_x")
# Out:
#    <div id="VA2mIh"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "x":"animal_type",
# "y":"diet",
# "scales":"free_x",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("VA2mIh");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, wrap, free x

# %%
plot + facet_wrap(facets=["animal_type", "diet"], ncol=2, scales="free_x")
# Out:
#    <div id="7io8nM"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":["animal_type","diet"],
# "ncol":2.0,
# "scales":"free_x",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("7io8nM");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, grid, free y

# %%
plot + facet_grid(x="animal_type", y="diet", scales="free_y")
# Out:
#    <div id="cpm9gv"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "x":"animal_type",
# "y":"diet",
# "scales":"free_y",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("cpm9gv");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, wrap, free y

# %%
plot + facet_wrap(facets=["animal_type", "diet"], ncol=2, scales="free_y")
# Out:
#    <div id="w7PeMD"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":["animal_type","diet"],
# "ncol":2.0,
# "scales":"free_y",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("w7PeMD");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, grid, free scales

# %%
plot + facet_grid(x="animal_type", y="diet", scales="free")
# Out:
#    <div id="mNMMkZ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "x":"animal_type",
# "y":"diet",
# "scales":"free",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("mNMMkZ");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, wrap, free scales

# %%
plot + facet_wrap(facets=["animal_type", "diet"], ncol=2, scales="free")
# Out:
#    <div id="m6Jm9P"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"animal",
# "y":"weight"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":["animal_type","diet"],
# "ncol":2.0,
# "scales":"free",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("m6Jm9P");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# ## Y-orientation

# %%
plot_y = (
    ggplot(plot_data, aes(x="weight", y="animal"))
    + geom_bar(stat="identity", orientation="y")
    + theme_bw()
    + theme(
        panel_grid_minor=element_blank()
    )
)
plot_y
# Out:
#    <div id="Z5HIzz"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("Z5HIzz");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Two facets, grid, free scales

# %%
plot_y + facet_grid(y = "animal_type", scales="free_y")
# Out:
#    <div id="iWKUWp"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "y":"animal_type",
# "scales":"free_y",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("iWKUWp");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Two facets, wrap, free scales

# %%
plot_y + facet_wrap(facets="animal_type", ncol=2, scales="free")
# Out:
#    <div id="UZxour"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":"animal_type",
# "ncol":2.0,
# "scales":"free",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("UZxour");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, grid, free x

# %%
plot_y + facet_grid(y="animal_type", x="diet", scales="free_x")
# Out:
#    <div id="aAvYJM"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "x":"diet",
# "y":"animal_type",
# "scales":"free_x",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("aAvYJM");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, wrap, free x

# %%
plot_y + facet_wrap(facets=["animal_type", "diet"], ncol=2, scales="free_x")
# Out:
#    <div id="bB56VU"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":["animal_type","diet"],
# "ncol":2.0,
# "scales":"free_x",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("bB56VU");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, grid, free y

# %%
plot_y + facet_grid(y="animal_type", x="diet", scales="free_y")
# Out:
#    <div id="CtHc7A"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "x":"diet",
# "y":"animal_type",
# "scales":"free_y",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("CtHc7A");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, wrap, free y

# %%
plot_y + facet_wrap(facets=["animal_type", "diet"], ncol=2, scales="free_y")
# Out:
#    <div id="4s7jQb"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":["animal_type","diet"],
# "ncol":2.0,
# "scales":"free_y",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("4s7jQb");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, grid, free scales

# %%
plot_y + facet_grid(y="animal_type", x="diet", scales="free")
# Out:
#    <div id="E0u4eJ"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"grid",
# "x":"diet",
# "y":"animal_type",
# "scales":"free",
# "x_order":1.0,
# "y_order":1.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("E0u4eJ");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>

# %% [markdown]
# #### Four facets, wrap, free scales

# %%
plot_y + facet_wrap(facets=["animal_type", "diet"], ncol=2, scales="free")
# Out:
#    <div id="JkzfPG"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "animal_type":["pet","pet","pet","pet","farm_animal","farm_animal","farm_animal"],
# "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
# "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
# "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"]
# },
# "mapping":{
# "x":"weight",
# "y":"animal"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"animal_type"
# },{
# "type":"str",
# "column":"animal"
# },{
# "type":"int",
# "column":"weight"
# },{
# "type":"str",
# "column":"diet"
# }]
# },
# "theme":{
# "name":"bw",
# "panel_grid_minor":{
# "blank":true
# }
# },
# "facet":{
# "name":"wrap",
# "facets":["animal_type","diet"],
# "ncol":2.0,
# "scales":"free",
# "order":1.0,
# "dir":"h"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "orientation":"y",
# "data":{
# }
# }],
# "metainfo_list":[]
# };
#            var plotContainer = document.getElementById("JkzfPG");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
