// %%
%useLatestDescriptors
%use lets-plot
// Out:
//    <div id="KSdCpE"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.4.1/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("KSdCpE").appendChild(div);
//            };
//            var e = document.getElementById("KSdCpE");
//            e.appendChild(script);
//        })();
//    </script>

// %% [markdown]
// ### Plotting means and error ranges.
//
// There are several ways to show error ranges on a plot. Among them are
// - `geomErrorBar()`
// - `geomCrossbar()`
// - `geomLineRange()`
// - `geomPointRange()`

// %%
// This example was found at: www.cookbook-r.com/Graphs/Plotting_means_and_error_bars_(ggplot2)
val data = mapOf(
    "supp" to listOf("OJ", "OJ", "OJ", "VC", "VC", "VC"),
    "dose" to listOf(0.5, 1.0, 2.0, 0.5, 1.0, 2.0),
    "length" to listOf(13.23, 22.70, 26.06, 7.98, 16.77, 26.14),
    "len_min" to listOf(11.83, 21.2, 24.50, 4.24, 15.26, 23.35),
    "len_max" to listOf(15.63, 24.9, 27.11, 10.72, 19.28, 28.93)
)

// %%
val p = letsPlot(data) {x="dose"; color="supp"}

// %% [markdown]
// ### Error-bars with lines and points.

// %%
p + geomErrorBar(width = .1) {ymin = "len_min"; ymax = "len_max"} +
    geomLine {y = "length"} +
    geomPoint {y = "length"}
// Out:
//    <div id="NiGIMi"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// "x":"dose",
// "color":"supp"
// },
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14],
// "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
// "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "ymin":"len_min",
// "ymax":"len_max"
// },
// "stat":"identity",
// "width":0.1,
// "position":"identity",
// "geom":"errorbar",
// "data":{
// }
// },{
// "mapping":{
// "y":"length"
// },
// "stat":"identity",
// "position":"identity",
// "geom":"line",
// "data":{
// }
// },{
// "mapping":{
// "y":"length"
// },
// "stat":"identity",
// "position":"identity",
// "geom":"point",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"supp"
// },{
// "type":"float",
// "column":"dose"
// },{
// "type":"float",
// "column":"length"
// },{
// "type":"float",
// "column":"len_min"
// },{
// "type":"float",
// "column":"len_max"
// }]
// }
// };
//            var plotContainer = document.getElementById("NiGIMi");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %%
// The errorbars overlapped, so use position_dodge to move them horizontally
val pd = positionDodge(0.1) // move them .05 to the left and right
p + geomErrorBar(width=.1, position=pd) {ymin="len_min"; ymax="len_max"} +
    geomLine(position=pd) {y="length"} +
    geomPoint(position=pd) {y="length"}
// Out:
//    <div id="kbO7xw"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// "x":"dose",
// "color":"supp"
// },
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14],
// "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
// "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "ymin":"len_min",
// "ymax":"len_max"
// },
// "stat":"identity",
// "width":0.1,
// "position":{
// "name":"dodge",
// "width":0.1
// },
// "geom":"errorbar",
// "data":{
// }
// },{
// "mapping":{
// "y":"length"
// },
// "stat":"identity",
// "position":{
// "name":"dodge",
// "width":0.1
// },
// "geom":"line",
// "data":{
// }
// },{
// "mapping":{
// "y":"length"
// },
// "stat":"identity",
// "position":{
// "name":"dodge",
// "width":0.1
// },
// "geom":"point",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"supp"
// },{
// "type":"float",
// "column":"dose"
// },{
// "type":"float",
// "column":"length"
// },{
// "type":"float",
// "column":"len_min"
// },{
// "type":"float",
// "column":"len_max"
// }]
// }
// };
//            var plotContainer = document.getElementById("kbO7xw");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %%
// Black errorbars - notice the mapping of 'group=supp'
// Without it, the errorbars won't be dodged!
p + geomErrorBar(
    color = "pen", 
    width = .1, 
    position = pd) {ymin = "len_min"; ymax = "len_max"; group = "supp"} +
    geomLine(position = pd) {y = "length"} +
    geomPoint(position = pd, size = 5) {y = "length"}
// Out:
//    <div id="Dh6amW"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// "x":"dose",
// "color":"supp"
// },
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14],
// "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
// "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "ymin":"len_min",
// "ymax":"len_max",
// "group":"supp"
// },
// "stat":"identity",
// "color":"pen",
// "width":0.1,
// "position":{
// "name":"dodge",
// "width":0.1
// },
// "geom":"errorbar",
// "data":{
// }
// },{
// "mapping":{
// "y":"length"
// },
// "stat":"identity",
// "position":{
// "name":"dodge",
// "width":0.1
// },
// "geom":"line",
// "data":{
// }
// },{
// "mapping":{
// "y":"length"
// },
// "stat":"identity",
// "size":5.0,
// "position":{
// "name":"dodge",
// "width":0.1
// },
// "geom":"point",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"supp"
// },{
// "type":"float",
// "column":"dose"
// },{
// "type":"float",
// "column":"length"
// },{
// "type":"float",
// "column":"len_min"
// },{
// "type":"float",
// "column":"len_max"
// }]
// }
// };
//            var plotContainer = document.getElementById("Dh6amW");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %%
// Finished graph
// - fixed size
// - point shape # 21 is filled circle 
// - position legend in bottom right
val p1 = p +
    xlab("Dose (mg)") +
    ylab("Tooth length (mm)") +
    scaleColorManual(listOf("orange", "dark_green"), naValue = "gray") +
    ggsize(700, 400)
p1 + geomErrorBar(color = "pen", 
                  width = .1, 
                  position = pd) {ymin = "len_min"; ymax = "len_max"; group = "supp"} +
    geomLine(position = pd) {y = "length"} +
    geomPoint(position = pd, size = 5, shape = 21) {y = "length"} +
    theme().legendJustification(1,0).legendPosition(1,0) +
    ggtitle("The Effect of Vitamin C on Tooth Growth in Guinea Pigs")
// Out:
//    <div id="aCJgXj"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "ggtitle":{
// "text":"The Effect of Vitamin C on Tooth Growth in Guinea Pigs"
// },
// "mapping":{
// "x":"dose",
// "color":"supp"
// },
// "guides":{
// "x":{
// "title":"Dose (mg)"
// },
// "y":{
// "title":"Tooth length (mm)"
// }
// },
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14],
// "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
// "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
// },
// "ggsize":{
// "width":700.0,
// "height":400.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"color",
// "na_value":"gray",
// "values":["orange","dark_green"]
// }],
// "layers":[{
// "mapping":{
// "ymin":"len_min",
// "ymax":"len_max",
// "group":"supp"
// },
// "stat":"identity",
// "color":"pen",
// "width":0.1,
// "position":{
// "name":"dodge",
// "width":0.1
// },
// "geom":"errorbar",
// "data":{
// }
// },{
// "mapping":{
// "y":"length"
// },
// "stat":"identity",
// "position":{
// "name":"dodge",
// "width":0.1
// },
// "geom":"line",
// "data":{
// }
// },{
// "mapping":{
// "y":"length"
// },
// "stat":"identity",
// "shape":21.0,
// "size":5.0,
// "position":{
// "name":"dodge",
// "width":0.1
// },
// "geom":"point",
// "data":{
// }
// }],
// "theme":{
// "legend_justification":[1.0,0.0],
// "legend_position":[1.0,0.0]
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"supp"
// },{
// "type":"float",
// "column":"dose"
// },{
// "type":"float",
// "column":"length"
// },{
// "type":"float",
// "column":"len_min"
// },{
// "type":"float",
// "column":"len_max"
// }]
// }
// };
//            var plotContainer = document.getElementById("aCJgXj");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %% [markdown]
// ### Error-bars on bar plot.

// %%
// Plot error ranges on Bar plot
p1 + 
    geomBar(stat = Stat.identity, 
            position = positionDodge(), 
            color = "pen") {y = "length"; fill = "supp"} +
    geomErrorBar(width = .1, 
                 position = positionDodge(0.9),
                 color = "pen") {
        ymin = "len_min"
        ymax = "len_max" 
        group = "supp"} +
    theme().legendJustification(0,1).legendPosition(0,1)
// Out:
//    <div id="bmjYr7"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// "x":"dose",
// "color":"supp"
// },
// "guides":{
// "x":{
// "title":"Dose (mg)"
// },
// "y":{
// "title":"Tooth length (mm)"
// }
// },
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14],
// "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
// "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
// },
// "ggsize":{
// "width":700.0,
// "height":400.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"color",
// "na_value":"gray",
// "values":["orange","dark_green"]
// }],
// "layers":[{
// "mapping":{
// "y":"length",
// "fill":"supp"
// },
// "stat":"identity",
// "color":"pen",
// "position":"dodge",
// "geom":"bar",
// "data":{
// }
// },{
// "mapping":{
// "ymin":"len_min",
// "ymax":"len_max",
// "group":"supp"
// },
// "stat":"identity",
// "color":"pen",
// "width":0.1,
// "position":{
// "name":"dodge",
// "width":0.9
// },
// "geom":"errorbar",
// "data":{
// }
// }],
// "theme":{
// "legend_justification":[0.0,1.0],
// "legend_position":[0.0,1.0]
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"supp"
// },{
// "type":"float",
// "column":"dose"
// },{
// "type":"float",
// "column":"length"
// },{
// "type":"float",
// "column":"len_min"
// },{
// "type":"float",
// "column":"len_max"
// }]
// }
// };
//            var plotContainer = document.getElementById("bmjYr7");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %% [markdown]
// ### Crossbars.

// %%
// Thickness of the horizontal mid-line can be adjusted using `fatten` parameter.
p1 + geomCrossbar(fatten = 5.0) {
    ymin="len_min"
    ymax="len_max"
    y="length"
    color="supp"
}
// Out:
//    <div id="Jq0hhG"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// "x":"dose",
// "color":"supp"
// },
// "guides":{
// "x":{
// "title":"Dose (mg)"
// },
// "y":{
// "title":"Tooth length (mm)"
// }
// },
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14],
// "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
// "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
// },
// "ggsize":{
// "width":700.0,
// "height":400.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"color",
// "na_value":"gray",
// "values":["orange","dark_green"]
// }],
// "layers":[{
// "mapping":{
// "ymin":"len_min",
// "ymax":"len_max",
// "y":"length",
// "color":"supp"
// },
// "stat":"identity",
// "position":"dodge",
// "geom":"crossbar",
// "fatten":5.0,
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"supp"
// },{
// "type":"float",
// "column":"dose"
// },{
// "type":"float",
// "column":"length"
// },{
// "type":"float",
// "column":"len_min"
// },{
// "type":"float",
// "column":"len_max"
// }]
// }
// };
//            var plotContainer = document.getElementById("Jq0hhG");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %% [markdown]
// ### Line-range.

// %%
p1 + geomLineRange(position=pd) {ymin="len_min"; ymax="len_max"; color="supp"} +
     geomLine(position=pd) {y="length"}
// Out:
//    <div id="6990gK"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// "x":"dose",
// "color":"supp"
// },
// "guides":{
// "x":{
// "title":"Dose (mg)"
// },
// "y":{
// "title":"Tooth length (mm)"
// }
// },
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14],
// "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
// "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
// },
// "ggsize":{
// "width":700.0,
// "height":400.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"color",
// "na_value":"gray",
// "values":["orange","dark_green"]
// }],
// "layers":[{
// "mapping":{
// "ymin":"len_min",
// "ymax":"len_max",
// "color":"supp"
// },
// "stat":"identity",
// "position":{
// "name":"dodge",
// "width":0.1
// },
// "geom":"linerange",
// "data":{
// }
// },{
// "mapping":{
// "y":"length"
// },
// "stat":"identity",
// "position":{
// "name":"dodge",
// "width":0.1
// },
// "geom":"line",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"supp"
// },{
// "type":"float",
// "column":"dose"
// },{
// "type":"float",
// "column":"length"
// },{
// "type":"float",
// "column":"len_min"
// },{
// "type":"float",
// "column":"len_max"
// }]
// }
// };
//            var plotContainer = document.getElementById("6990gK");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %% [markdown]
// ### Point-range.

// %%
// Point-range is the same as line-range but with an added mid-point.
p1 + geomPointRange(position=pd) {y="length"; ymin="len_min"; ymax="len_max"; color="supp"} +
     geomLine(position=pd) {y="length"}
// Out:
//    <div id="QRIZbP"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// "x":"dose",
// "color":"supp"
// },
// "guides":{
// "x":{
// "title":"Dose (mg)"
// },
// "y":{
// "title":"Tooth length (mm)"
// }
// },
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14],
// "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
// "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
// },
// "ggsize":{
// "width":700.0,
// "height":400.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"color",
// "na_value":"gray",
// "values":["orange","dark_green"]
// }],
// "layers":[{
// "mapping":{
// "y":"length",
// "ymin":"len_min",
// "ymax":"len_max",
// "color":"supp"
// },
// "stat":"identity",
// "position":{
// "name":"dodge",
// "width":0.1
// },
// "geom":"pointrange",
// "data":{
// }
// },{
// "mapping":{
// "y":"length"
// },
// "stat":"identity",
// "position":{
// "name":"dodge",
// "width":0.1
// },
// "geom":"line",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"supp"
// },{
// "type":"float",
// "column":"dose"
// },{
// "type":"float",
// "column":"length"
// },{
// "type":"float",
// "column":"len_min"
// },{
// "type":"float",
// "column":"len_max"
// }]
// }
// };
//            var plotContainer = document.getElementById("QRIZbP");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %%
// Size of the mid-point can be adjuasted using `fatten` parameter - multiplication factor relative to the line size.
p1 + geomLine(position = pd) {y = "length"} +
     geomPointRange(position = pd, 
                    color = "rgb(230, 230, 230)", 
                    size = 5, 
                    linewidth = 5, 
                    shape = 23, fatten = 1.0) {
         y = "length"
         ymin = "len_min"
         ymax = "len_max"
         fill = "supp"
     } +
     scaleFillManual(listOf("orange", "dark_green"), naValue="gray")
// Out:
//    <div id="hegtM3"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// "x":"dose",
// "color":"supp"
// },
// "guides":{
// "x":{
// "title":"Dose (mg)"
// },
// "y":{
// "title":"Tooth length (mm)"
// }
// },
// "data":{
// "dose":[0.5,1.0,2.0,0.5,1.0,2.0],
// "supp":["OJ","OJ","OJ","VC","VC","VC"],
// "length":[13.23,22.7,26.06,7.98,16.77,26.14],
// "len_min":[11.83,21.2,24.5,4.24,15.26,23.35],
// "len_max":[15.63,24.9,27.11,10.72,19.28,28.93]
// },
// "ggsize":{
// "width":700.0,
// "height":400.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"color",
// "na_value":"gray",
// "values":["orange","dark_green"]
// },{
// "aesthetic":"fill",
// "na_value":"gray",
// "values":["orange","dark_green"]
// }],
// "layers":[{
// "mapping":{
// "y":"length"
// },
// "stat":"identity",
// "position":{
// "name":"dodge",
// "width":0.1
// },
// "geom":"line",
// "data":{
// }
// },{
// "mapping":{
// "y":"length",
// "ymin":"len_min",
// "ymax":"len_max",
// "fill":"supp"
// },
// "stat":"identity",
// "color":"rgb(230, 230, 230)",
// "shape":23.0,
// "size":5.0,
// "position":{
// "name":"dodge",
// "width":0.1
// },
// "geom":"pointrange",
// "linewidth":5.0,
// "fatten":1.0,
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"supp"
// },{
// "type":"float",
// "column":"dose"
// },{
// "type":"float",
// "column":"length"
// },{
// "type":"float",
// "column":"len_min"
// },{
// "type":"float",
// "column":"len_max"
// }]
// }
// };
//            var plotContainer = document.getElementById("hegtM3");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
