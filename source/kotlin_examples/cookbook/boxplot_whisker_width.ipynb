// %%
%useLatestDescriptors
%use lets-plot
// Out:
//    <div id="eNu9yN"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.4.1/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("eNu9yN").appendChild(div);
//            };
//            var e = document.getElementById("eNu9yN");
//            e.appendChild(script);
//        })();
//    </script>

// %%
LetsPlot.getInfo()
// Out:
// Lets-Plot Kotlin API v.4.8.0. Frontend: Notebook with dynamically loaded JS. Lets-Plot JS v.4.4.1.

// %%
val n = 100
val rand = java.util.Random(37)
val data = mapOf<String, Any>(
    "x" to List(n) { listOf("a", "b", "c").random() },
    "y" to List(n) { rand.nextGaussian() }
)

letsPlot(data) { x = "x"; y = "y" }  + geomBoxplot(whiskerWidth = 0.2)
// Out:
//    <div id="U6fvhJ"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"boxplot",
// "whisker_width":0.2,
// "position":"dodge",
// "geom":"boxplot",
// "data":{
// "..middle..":[-0.01523713036011583,0.40713450838998066,-0.07418640466593203],
// "..upper..":[0.6847231553643796,0.847533133411047,0.3604467650550379],
// "..ymax..":[2.439598419520245,2.2972205355496347,1.052027068066767],
// "x":["a","c","b"],
// "..lower..":[-0.5866192318690705,-0.4758885921794891,-0.6089511563103002],
// "..ymin..":[-1.5229462883897182,-2.20104878328904,-1.577245894169239]
// }
// },{
// "mapping":{
// },
// "stat":"boxplot_outlier",
// "show_legend":false,
// "position":"dodge",
// "geom":"point",
// "data":{
// "..middle..":[-0.01523713036011583,0.40713450838998066,-0.07418640466593203],
// "..upper..":[0.6847231553643796,0.847533133411047,0.3604467650550379],
// "..ymax..":[2.439598419520245,2.2972205355496347,1.052027068066767],
// "x":["a","c","b"],
// "..lower..":[-0.5866192318690705,-0.4758885921794891,-0.6089511563103002],
// "y":[NaN,NaN,NaN],
// "..ymin..":[-1.5229462883897182,-2.20104878328904,-1.577245894169239]
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"x"
// },{
// "type":"float",
// "column":"y"
// }]
// }
// };
//            var plotContainer = document.getElementById("U6fvhJ");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
