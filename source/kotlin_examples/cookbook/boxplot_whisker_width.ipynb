// %%
%useLatestDescriptors
%use lets-plot
// Out:
//    <div id="vU3miK"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.3/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("vU3miK").appendChild(div);
//            };
//            var e = document.getElementById("vU3miK");
//            e.appendChild(script);
//        })();
//    </script>

// %%
LetsPlot.getInfo()
// Out:
// Lets-Plot Kotlin API v.4.7.3. Frontend: Notebook with dynamically loaded JS. Lets-Plot JS v.4.3.3.

// %%
val n = 100
val rand = java.util.Random(37)
val data = mapOf<String, Any>(
    "x" to List(n) { listOf("a", "b", "c").random() },
    "y" to List(n) { rand.nextGaussian() }
)

letsPlot(data) { x = "x"; y = "y" }  + geomBoxplot(whiskerWidth = 0.2)
// Out:
//    <div id="WkbIB1"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"boxplot",
// "whisker_width":0.2,
// "position":"dodge",
// "geom":"boxplot",
// "data":{
// "..middle..":[0.010174247519462422,0.0665446750836876,0.24510646157522875],
// "..upper..":[0.6343128459133454,0.6304769581004004,0.6746110774564892],
// "..ymax..":[2.429780509168998,1.9695418127098692,2.162580230059769],
// "..lower..":[-0.6321596518906987,-0.32337790360524765,-0.49382129817276393],
// "x":["b","c","a"],
// "..ymin..":[-1.577245894169239,-1.3941301234610528,-1.5229462883897182]
// }
// },{
// "mapping":{
// },
// "stat":"boxplot_outlier",
// "show_legend":false,
// "position":"dodge",
// "geom":"point",
// "data":{
// "..middle..":[0.010174247519462422,0.0665446750836876,0.24510646157522875],
// "..upper..":[0.6343128459133454,0.6304769581004004,0.6746110774564892],
// "..ymax..":[2.429780509168998,1.9695418127098692,2.162580230059769],
// "..lower..":[-0.6321596518906987,-0.32337790360524765,-0.49382129817276393],
// "x":["b","c","a"],
// "..ymin..":[-1.577245894169239,-1.3941301234610528,-1.5229462883897182],
// "y":[NaN,-2.20104878328904,2.439598419520245]
// }
// }]
// };
//            var plotContainer = document.getElementById("WkbIB1");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
