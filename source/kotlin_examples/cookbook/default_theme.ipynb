// %%
%useLatestDescriptors
%use lets-plot
// Out:
//    <div id="zhKjD1"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.3/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("zhKjD1").appendChild(div);
//            };
//            var e = document.getElementById("zhKjD1");
//            e.appendChild(script);
//        })();
//    </script>

// %%
// Set the 'grey' theme as a default plot theme.
LetsPlot.theme = themeGrey()

// %%
val dat = mapOf("x" to listOf(1, 2, 3), "y" to listOf(1, 2, 3))
letsPlot(dat) {x = "x"; y = "y"} + geomPoint(size = 5)
// Out:
//    <div id="gEpD7U"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "data":{
// "x":[1.0,2.0,3.0],
// "y":[1.0,2.0,3.0]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "size":5.0,
// "position":"identity",
// "geom":"point",
// "data":{
// }
// }],
// "theme":{
// "name":"grey"
// }
// };
//            var plotContainer = document.getElementById("gEpD7U");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
