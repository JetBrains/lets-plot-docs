// %% [markdown]
// ## Using parameters `norm`, `vmain`, `vmax`  in `geomImshow()`
//
// You can use parameters `norm`, `vmain`, `vmax` when rendering grayscale images.
//
// A grayscale image is specified by 2D array where each element's value
// represents the luminance of corresponding pixel in the image.

// %%
%useLatestDescriptors
%use lets-plot
// Out:
//    <div id="BCtq6c"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.2/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("BCtq6c").appendChild(div);
//            };
//            var e = document.getElementById("BCtq6c");
//            e.appendChild(script);
//        })();
//    </script>

// %%
// Generate 2D arrays. 
// First two arrays both contain float numbers but have different range of values.
// The 3rd array contains int-s.
fun linspace(start: Double, end: Double, count: Int): List<Number> {
    val step = (end - start) / (count - 1)
    return mutableListOf<Double>() + 
        start + (1 .. (count - 2)).map { i -> start + i * step } + end
}

val arr_f0 = RasterData.create(listOf(linspace(0.3, 0.7, 30)))
val arr_f1 = RasterData.create(listOf(linspace(30.0, 170.0, 30)))
val arr_i = RasterData.create(listOf(linspace(30.0, 170.0, 30).map { it.toInt() }))

// %%
// Setup suitable plot options for the demo.
val p = (letsPlot() + ggsize(450, 60) + geomRect(xmin=-0.5, ymin=-0.5, xmax=29.5, ymax=0.5, color="black", alpha=0) + 
coordCartesian() + themeClassic() + theme(axis="blank"))

// %% [markdown]
// #### Image normalization
//
// By default, `geomImshow()` applies a linear scaling to transform data values to range [0-255].

// %%
(p + geomImshow(arr_f0)).show()
(p + geomImshow(arr_f1)).show()
(p + geomImshow(arr_i)).show()
// Out:
//    <div id="PYivsy"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"paint_c",
// "scale_mapper_kind":"color_grey",
// "name":"",
// "start":0.0,
// "end":1.0
// }],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// "paint_c":"paint_c"
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color_by":"paint_c",
// "href":"...",
// "geom":"image",
// "data":{
// "paint_c":[0.30000001192092896,0.699999988079071]
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("PYivsy");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
//    <div id="w65ekb"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"paint_c",
// "scale_mapper_kind":"color_grey",
// "name":"",
// "start":0.0,
// "end":1.0
// }],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// "paint_c":"paint_c"
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color_by":"paint_c",
// "href":"...",
// "geom":"image",
// "data":{
// "paint_c":[30.0,170.0]
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("w65ekb");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
//    <div id="dfRo9N"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"paint_c",
// "scale_mapper_kind":"color_grey",
// "name":"",
// "start":0.0,
// "end":1.0
// }],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// "paint_c":"paint_c"
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color_by":"paint_c",
// "href":"...",
// "geom":"image",
// "data":{
// "paint_c":[30.0,170.0]
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("dfRo9N");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %% [markdown]
// ##
//
// You can disable image normalization using the `norm` parameter.

// %%
(p + geomImshow(arr_f0, norm=false)).show()
(p + geomImshow(arr_f1, norm=false)).show()
(p + geomImshow(arr_i, norm=false)).show()
// Out:
//    <div id="bqsiZ2"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"paint_c",
// "scale_mapper_kind":"color_grey",
// "name":"",
// "start":0.0011764706349840352,
// "end":0.002745097992466945
// }],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// "paint_c":"paint_c"
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color_by":"paint_c",
// "href":"...",
// "geom":"image",
// "data":{
// "paint_c":[0.30000001192092896,0.699999988079071]
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("bqsiZ2");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
//    <div id="ILh863"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"paint_c",
// "scale_mapper_kind":"color_grey",
// "name":"",
// "start":0.11764705882352941,
// "end":0.6666666666666666
// }],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// "paint_c":"paint_c"
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color_by":"paint_c",
// "href":"...",
// "geom":"image",
// "data":{
// "paint_c":[30.0,170.0]
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("ILh863");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
//    <div id="8t0RZJ"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"paint_c",
// "scale_mapper_kind":"color_grey",
// "name":"",
// "start":0.11764705882352941,
// "end":0.6666666666666666
// }],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// "paint_c":"paint_c"
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color_by":"paint_c",
// "href":"...",
// "geom":"image",
// "data":{
// "paint_c":[30.0,170.0]
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("8t0RZJ");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %% [markdown]
// #### Define normalization range using `vmin, vmax` parameters

// %%
// Set upper limit less than the data max value.
(p + geomImshow(arr_f0, vmax=.5)).show()
(p + geomImshow(arr_f1, vmax=100)).show()
(p + geomImshow(arr_i, vmax=100)).show()
// Out:
//    <div id="L0H9zv"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"paint_c",
// "scale_mapper_kind":"color_grey",
// "name":"",
// "start":0.0,
// "end":1.0
// }],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// "paint_c":"paint_c"
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color_by":"paint_c",
// "href":"...",
// "geom":"image",
// "data":{
// "paint_c":[0.30000001192092896,0.5]
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("L0H9zv");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
//    <div id="QPhRdT"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"paint_c",
// "scale_mapper_kind":"color_grey",
// "name":"",
// "start":0.0,
// "end":1.0
// }],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// "paint_c":"paint_c"
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color_by":"paint_c",
// "href":"...",
// "geom":"image",
// "data":{
// "paint_c":[30.0,100.0]
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("QPhRdT");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
//    <div id="N39xVk"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"paint_c",
// "scale_mapper_kind":"color_grey",
// "name":"",
// "start":0.0,
// "end":1.0
// }],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// "paint_c":"paint_c"
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color_by":"paint_c",
// "href":"...",
// "geom":"image",
// "data":{
// "paint_c":[30.0,100.0]
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("N39xVk");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %%
// Set limits wider than the data entire range.
(p + geomImshow(arr_f0, vmin=.4, vmax=.6)).show()
(p + geomImshow(arr_f1, vmin=70, vmax=120)).show()
(p + geomImshow(arr_i, vmin=50, vmax=150)).show()
// Out:
//    <div id="ouzVgK"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"paint_c",
// "scale_mapper_kind":"color_grey",
// "name":"",
// "start":0.0,
// "end":1.0
// }],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// "paint_c":"paint_c"
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color_by":"paint_c",
// "href":"...",
// "geom":"image",
// "data":{
// "paint_c":[0.4000000059604645,0.6000000238418579]
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("ouzVgK");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
//    <div id="kK9fxX"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"paint_c",
// "scale_mapper_kind":"color_grey",
// "name":"",
// "start":0.0,
// "end":1.0
// }],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// "paint_c":"paint_c"
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color_by":"paint_c",
// "href":"...",
// "geom":"image",
// "data":{
// "paint_c":[70.0,120.0]
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("kK9fxX");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
//    <div id="ntAtqw"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "coord":{
// "name":"cartesian",
// "flip":false
// },
// "ggsize":{
// "width":450.0,
// "height":60.0
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"paint_c",
// "scale_mapper_kind":"color_grey",
// "name":"",
// "start":0.0,
// "end":1.0
// }],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color":"black",
// "alpha":0.0,
// "position":"identity",
// "geom":"rect",
// "data":{
// }
// },{
// "ymin":-0.5,
// "mapping":{
// "paint_c":"paint_c"
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":0.5,
// "xmax":29.5,
// "color_by":"paint_c",
// "href":"...",
// "geom":"image",
// "data":{
// "paint_c":[50.0,150.0]
// }
// }],
// "theme":{
// "name":"classic",
// "axis":"blank"
// }
// };
//            var plotContainer = document.getElementById("ntAtqw");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
