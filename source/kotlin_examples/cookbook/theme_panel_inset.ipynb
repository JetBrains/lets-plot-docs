// %% [markdown]
// # The `panelInset` Parameter in `theme()`

// %%
%useLatestDescriptors
%use lets-plot
// Out:
//    <div id="H12ZC4"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.3/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("H12ZC4").appendChild(div);
//            };
//            var e = document.getElementById("H12ZC4");
//            e.appendChild(script);
//        })();
//    </script>

// %%
LetsPlot.getInfo()
// Out:
// Lets-Plot Kotlin API v.4.7.3. Frontend: Notebook with dynamically loaded JS. Lets-Plot JS v.4.3.3.

// %%
val hours = (0 until 12).map { String.format("%02d:00", it) }

val p = letsPlot() +
    geomPoint() { x = hours } +
    themeGrey() +
    theme(axisLine = elementLine(color = "black"))

// %% [markdown]
// ## Polar Coordinate System
//
// In the polar coordinate system, it's common for tick labels to overlap.
//
// The `panelInset` parameter assists in creating additional space to accommodate tick labels more effectively.

// %%
gggrid(
    listOf(
        p + coordPolar(),
        p + theme(panelInset = listOf(0, 35)) + coordPolar(),
        p + theme(panelInset = listOf(0, 35)) + coordPolar(transformBkgr = false),
    )
)
// Out:
//    <div id="YbAh0D"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "layout":{
// "name":"grid",
// "ncol":3,
// "nrow":1,
// "fit":true,
// "align":false
// },
// "figures":[{
// "mapping":{
// },
// "coord":{
// "name":"polar"
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"x"
// },
// "stat":"identity",
// "position":"identity",
// "geom":"point",
// "data":{
// "x":["00:00","01:00","02:00","03:00","04:00","05:00","06:00","07:00","08:00","09:00","10:00","11:00"]
// }
// }],
// "theme":{
// "name":"grey",
// "axis_line":{
// "color":"black",
// "blank":false
// }
// }
// },{
// "mapping":{
// },
// "coord":{
// "name":"polar"
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"x"
// },
// "stat":"identity",
// "position":"identity",
// "geom":"point",
// "data":{
// "x":["00:00","01:00","02:00","03:00","04:00","05:00","06:00","07:00","08:00","09:00","10:00","11:00"]
// }
// }],
// "theme":{
// "name":"grey",
// "axis_line":{
// "color":"black",
// "blank":false
// },
// "panel_inset":[0.0,35.0]
// }
// },{
// "mapping":{
// },
// "coord":{
// "name":"polar",
// "transform_bkgr":false
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"x"
// },
// "stat":"identity",
// "position":"identity",
// "geom":"point",
// "data":{
// "x":["00:00","01:00","02:00","03:00","04:00","05:00","06:00","07:00","08:00","09:00","10:00","11:00"]
// }
// }],
// "theme":{
// "name":"grey",
// "axis_line":{
// "color":"black",
// "blank":false
// },
// "panel_inset":[0.0,35.0]
// }
// }],
// "kind":"subplots"
// };
//            var plotContainer = document.getElementById("YbAh0D");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %% [markdown]
// ## Rectangular Coordinate System
// In rectangular coordinate systems, the `panelInset` parameter functions as a margin, adjusting the panel boundaries within the plot:

// %%
gggrid(
    listOf(
        p,
        p + theme(panelInset = 15)
    )
)
// Out:
//    <div id="JTMRIC"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "layout":{
// "name":"grid",
// "ncol":2,
// "nrow":1,
// "fit":true,
// "align":false
// },
// "figures":[{
// "layers":[{
// "mapping":{
// "x":"x"
// },
// "stat":"identity",
// "position":"identity",
// "geom":"point",
// "data":{
// "x":["00:00","01:00","02:00","03:00","04:00","05:00","06:00","07:00","08:00","09:00","10:00","11:00"]
// }
// }],
// "mapping":{
// },
// "theme":{
// "name":"grey",
// "axis_line":{
// "color":"black",
// "blank":false
// }
// },
// "kind":"plot",
// "scales":[]
// },{
// "layers":[{
// "mapping":{
// "x":"x"
// },
// "stat":"identity",
// "position":"identity",
// "geom":"point",
// "data":{
// "x":["00:00","01:00","02:00","03:00","04:00","05:00","06:00","07:00","08:00","09:00","10:00","11:00"]
// }
// }],
// "mapping":{
// },
// "theme":{
// "name":"grey",
// "axis_line":{
// "color":"black",
// "blank":false
// },
// "panel_inset":15.0
// },
// "kind":"plot",
// "scales":[]
// }],
// "kind":"subplots"
// };
//            var plotContainer = document.getElementById("JTMRIC");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
