// %% [markdown]
// ## geomImshow()
//
// `geomImshow()` displays an image specified by 2D or 3D array.
//
// Whether the image is grayscale or color depends on the shape of the image array:
// - (M, N) - grey-scale image
// - (M, N, 3) - color RGB image
// - (M, N, 4) - color RGB image with alpha channel
//
// By default, all values in the image array will be transformed to the range [0-255] using a linear scaler.

// %%
%useLatestDescriptors
%use lets-plot
// Out:
//    <div id="QD4AA7"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.2/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("QD4AA7").appendChild(div);
//            };
//            var e = document.getElementById("QD4AA7");
//            e.appendChild(script);
//        })();
//    </script>
//             <div id="kotlin_out_0"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["letsPlotJs"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["letsPlotJs"] = resQueue;
//                 window["call_letsPlotJs"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.2/js-package/distr/lets-plot.min.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_letsPlotJs"] = function(f) {f();};
//                         window.kotlinQueues["letsPlotJs"].forEach(function(f) {f();});
//                         window.kotlinQueues["letsPlotJs"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_letsPlotJs"] = function(f) {};
//                         window.kotlinQueues["letsPlotJs"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource letsPlotJs';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>

// %% [markdown]
// ### Grayscale image

// %%
val A2x3 = RasterData.create(
    listOf(
        listOf(50, 150 ,200),
        listOf(200,100,50)
    )
)

ggplot() + geomImshow(A2x3)
// Out:
//    <div id="uuMGXr"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.2/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("uuMGXr").appendChild(div);
//            };
//            var e = document.getElementById("uuMGXr");
//            e.appendChild(script);
//        })();
//    </script>
//    <div id="whTeOK"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("whTeOK");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"paint_c",
// "scale_mapper_kind":"color_grey",
// "name":"",
// "start":0.0,
// "end":1.0
// }],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// "paint_c":"paint_c"
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":1.5,
// "xmax":2.5,
// "color_by":"paint_c",
// "inherit_aes":false,
// "href":"...",
// "geom":"image",
// "data":{
// "paint_c":[50.0,200.0]
// }
// }],
// "spec_id":"1"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=434dca69-c5a6-4b20-878b-c5ed17e36606 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pDVU7UW .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pDVU7UW .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pDVU7UW .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pDVU7UW .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pDVU7UW .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pDVU7UW .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pDVU7UW .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pDVU7UW .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dkCX3qU .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pDVU7UW .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pDVU7UW .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dkCX3qU .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pDVU7UW .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pDVU7UW .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dkCX3qU .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dkCX3qU .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dkCX3qU .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pDVU7UW">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 16.14914192329607 L0.0 383.85085807670396 L600.0 383.85085807670396 L600.0 16.14914192329607 Z">
//     </path>
//     <g transform="translate(29.5 22.64914192329607 ) ">
//       <g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="21.047844283186905" y1="0.0" x2="21.047844283186905" y2="308.70171615340786" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="91.20732522714323" y1="0.0" x2="91.20732522714323" y2="308.70171615340786" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="161.36680617109954" y1="0.0" x2="161.36680617109954" y2="308.70171615340786" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="231.52628711505588" y1="0.0" x2="231.52628711505588" y2="308.70171615340786" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="301.68576805901216" y1="0.0" x2="301.68576805901216" y2="308.70171615340786" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="371.84524900296856" y1="0.0" x2="371.84524900296856" y2="308.70171615340786" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="442.00472994692484" y1="0.0" x2="442.00472994692484" y2="308.70171615340786" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="294.6698199646166" x2="463.0525742301117" y2="294.6698199646166" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="224.51033902066027" x2="463.0525742301117" y2="224.51033902066027" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="154.35085807670396" x2="463.0525742301117" y2="154.35085807670396" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="84.19137713274762" x2="463.0525742301117" y2="84.19137713274762" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="14.031896188791308" x2="463.0525742301117" y2="14.031896188791308" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cTQJJ7Z)" clip-bounds-jfx="[rect (35.01530667574961, 0.0), (463.0525742301117, 308.70171615340786)]">
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <g>
//               <image preserveAspectRatio="none" x="21.047844283186905" y="14.031896188791308" width="420.9568856637379" height="280.63792377582524" xlink:href="..." styl

// %% [markdown]
// #### Grayscale image without normalization

// %%
ggplot() + geomImshow(A2x3, norm=false)
// Out:
//    <div id="tXw8wE"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("tXw8wE");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"paint_c",
// "scale_mapper_kind":"color_grey",
// "name":"",
// "start":0.19607843137254902,
// "end":0.7843137254901961
// }],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// "paint_c":"paint_c"
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":1.5,
// "xmax":2.5,
// "color_by":"paint_c",
// "inherit_aes":false,
// "href":"...",
// "geom":"image",
// "data":{
// "paint_c":[50.0,200.0]
// }
// }],
// "spec_id":"3"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=4c3a245a-c4f7-4341-95eb-f5d4a2a1da20 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pYNJYBH .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pYNJYBH .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pYNJYBH .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pYNJYBH .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pYNJYBH .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pYNJYBH .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pYNJYBH .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pYNJYBH .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #djs7XlQ .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pYNJYBH .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pYNJYBH .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #djs7XlQ .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pYNJYBH .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pYNJYBH .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #djs7XlQ .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #djs7XlQ .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #djs7XlQ .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pYNJYBH">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 16.14914192329607 L0.0 383.85085807670396 L600.0 383.85085807670396 L600.0 16.14914192329607 Z">
//     </path>
//     <g transform="translate(29.5 22.64914192329607 ) ">
//       <g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="21.047844283186905" y1="0.0" x2="21.047844283186905" y2="308.70171615340786" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="91.20732522714323" y1="0.0" x2="91.20732522714323" y2="308.70171615340786" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="161.36680617109954" y1="0.0" x2="161.36680617109954" y2="308.70171615340786" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="231.52628711505588" y1="0.0" x2="231.52628711505588" y2="308.70171615340786" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="301.68576805901216" y1="0.0" x2="301.68576805901216" y2="308.70171615340786" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="371.84524900296856" y1="0.0" x2="371.84524900296856" y2="308.70171615340786" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="442.00472994692484" y1="0.0" x2="442.00472994692484" y2="308.70171615340786" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="294.6698199646166" x2="463.0525742301117" y2="294.6698199646166" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="224.51033902066027" x2="463.0525742301117" y2="224.51033902066027" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="154.35085807670396" x2="463.0525742301117" y2="154.35085807670396" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="84.19137713274762" x2="463.0525742301117" y2="84.19137713274762" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="14.031896188791308" x2="463.0525742301117" y2="14.031896188791308" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#caLkzRd)" clip-bounds-jfx="[rect (35.01530667574961, 0.0), (463.0525742301117, 308.70171615340786)]">
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <g>
//               <image preserveAspectRatio="none" x="21.047844283186905" y="14.031896188791308" width="420.9568856637379" height="280.637923

// %% [markdown]
// ### RGB image
//
// M x N x 3 array

// %%
val A2x3x3 = RasterData.create(
    listOf(
        listOf(listOf(255, 0, 0), listOf(0, 255, 0), listOf(0, 0, 255)),
        listOf(listOf(0, 255, 0), listOf(0, 0, 255), listOf(255, 0, 0))
    )
)

ggplot() + geomImshow(A2x3x3)
// Out:
//    <div id="0PKUeS"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("0PKUeS");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":1.5,
// "xmax":2.5,
// "color_by":"paint_c",
// "inherit_aes":false,
// "href":"...",
// "geom":"image",
// "data":{
// }
// }],
// "spec_id":"5"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=049c895b-636f-4e73-aa2e-e5e9a15090ce width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #p3I33WS .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #p3I33WS .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #p3I33WS .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #p3I33WS .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #p3I33WS .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #p3I33WS .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #p3I33WS .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #p3I33WS .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dnLqJMb .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #p3I33WS .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #p3I33WS .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dnLqJMb .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #p3I33WS .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #p3I33WS .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dnLqJMb .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dnLqJMb .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dnLqJMb .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="p3I33WS">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M8.742346662125215 0.0 L8.742346662125215 400.0 L591.2576533378748 400.0 L591.2576533378748 0.0 Z">
//     </path>
//     <g transform="translate(38.242346662125215 6.5 ) ">
//       <g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="23.25" y1="0.0" x2="23.25" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="100.75" y1="0.0" x2="100.75" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="178.25" y1="0.0" x2="178.25" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="255.75" y1="0.0" x2="255.75" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="333.25" y1="0.0" x2="333.25" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="410.75" y1="0.0" x2="410.75" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="488.25" y1="0.0" x2="488.25" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="325.5" x2="511.49999999999994" y2="325.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="248.0" x2="511.49999999999994" y2="248.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="170.5" x2="511.49999999999994" y2="170.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="93.0" x2="511.49999999999994" y2="93.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="15.5" x2="511.49999999999994" y2="15.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cTeShlZ)" clip-bounds-jfx="[rect (35.01530667574961, 0.0), (511.49999999999994, 341.0)]">
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <g>
//               <image preserveAspectRatio="none" x="23.25" y="15.5" width="465.0" height="310.0" xlink:href="..." style="image-rendering: optimizeSpeed; image-rendering: pixelated">
//
//             </g>
//           </g>
//         </g>
//         <defs>
//           <clipPath id="cTeShlZ">
//             <rect x="35.01530667574961" y="0.0" width="511.49999999999994" height="341.0">
//             </rect>
//           </clipPath>
//         </defs>
//       </g>
//       <g>
//         <g transform="translate(35.01530667574961 341.0 ) ">
//           <g transform="translate(23.25 0.0 ) ">
//             <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//             </line>
//             <g

// %% [markdown]
// ### RGB image with alpha channel
//
// M x N x 4 array

// %%
val A2x3x4 = RasterData.create(
    listOf(
        listOf(
            listOf(1.0, 0.0, 0.0, 1.0), listOf(0.0, 1.0, 0.0, 1.0), listOf(0.0, 0.0, 1.0, 1.0)
        ),
        listOf(
            listOf(0.0, 1.0, 0.0, 0.3), listOf(0.0, 0.0, 1.0, 0.3), listOf(1.0, 0.0, 0.0, 0.3)
        )
    )
)

ggplot() + geomImshow(A2x3x4)
// Out:
//    <div id="Zu6Ldu"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("Zu6Ldu");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":1.5,
// "xmax":2.5,
// "color_by":"paint_c",
// "inherit_aes":false,
// "href":"...",
// "geom":"image",
// "data":{
// }
// }],
// "spec_id":"7"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=c7e0fa4c-7cea-42cd-b350-67aae639e476 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pwHduvN .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pwHduvN .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pwHduvN .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pwHduvN .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pwHduvN .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pwHduvN .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pwHduvN .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pwHduvN .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dU50Cl3 .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pwHduvN .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pwHduvN .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dU50Cl3 .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pwHduvN .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pwHduvN .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dU50Cl3 .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dU50Cl3 .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dU50Cl3 .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pwHduvN">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M8.742346662125215 0.0 L8.742346662125215 400.0 L591.2576533378748 400.0 L591.2576533378748 0.0 Z">
//     </path>
//     <g transform="translate(38.242346662125215 6.5 ) ">
//       <g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="23.25" y1="0.0" x2="23.25" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="100.75" y1="0.0" x2="100.75" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="178.25" y1="0.0" x2="178.25" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="255.75" y1="0.0" x2="255.75" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="333.25" y1="0.0" x2="333.25" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="410.75" y1="0.0" x2="410.75" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="488.25" y1="0.0" x2="488.25" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="325.5" x2="511.49999999999994" y2="325.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="248.0" x2="511.49999999999994" y2="248.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="170.5" x2="511.49999999999994" y2="170.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="93.0" x2="511.49999999999994" y2="93.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="15.5" x2="511.49999999999994" y2="15.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cbHGLDx)" clip-bounds-jfx="[rect (35.01530667574961, 0.0), (511.49999999999994, 341.0)]">
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <g>
//               <image preserveAspectRatio="none" x="23.25" y="15.5" width="465.0" height="310.0" xlink:href="..." style="image-rendering: optimizeSpeed; image-rendering: pixelated">
//
//             </g>
//           </g>
//         </g>
//         <defs>
//           <clipPath id="cbHGLDx">
//             <rect x="35.01530667574961" y="0.0" width="511.49999999999994" height="341.0">
//             </rect>
//           </clipPath>
//         </defs>
//       </g>
//       <g>
//         <g transform="translate(35.01530667574961 341.0 ) ">
//           <g transform="translate(23.25 0.0 ) ">
//             <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//             </line>
//             <g

// %% [markdown]
// ## Image specified by array

// %% [markdown]
// ### Grayscale image specified by ByteArray

// %%
val byteArrayA2x3 = RasterData.create(
    byteArrayOf(50, 150.toByte(), 200.toByte(), 200.toByte(), 100, 50),
    width = 3, height = 2, nChannels = 1
)

ggplot() + geomImshow(byteArrayA2x3)
// Out:
//    <div id="s4jJ7l"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("s4jJ7l");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"paint_c",
// "scale_mapper_kind":"color_grey",
// "name":"",
// "start":0.0,
// "end":1.0
// }],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// "paint_c":"paint_c"
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":1.5,
// "xmax":2.5,
// "color_by":"paint_c",
// "inherit_aes":false,
// "href":"...",
// "geom":"image",
// "data":{
// "paint_c":[50.0,200.0]
// }
// }],
// "spec_id":"9"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=0462ea1f-683d-4273-b909-35daab4e0142 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pTpCVzk .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pTpCVzk .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pTpCVzk .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pTpCVzk .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pTpCVzk .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pTpCVzk .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pTpCVzk .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pTpCVzk .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d5cViGv .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pTpCVzk .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pTpCVzk .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d5cViGv .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pTpCVzk .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pTpCVzk .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d5cViGv .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d5cViGv .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #d5cViGv .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pTpCVzk">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 16.14914192329607 L0.0 383.85085807670396 L600.0 383.85085807670396 L600.0 16.14914192329607 Z">
//     </path>
//     <g transform="translate(29.5 22.64914192329607 ) ">
//       <g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="21.047844283186905" y1="0.0" x2="21.047844283186905" y2="308.70171615340786" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="91.20732522714323" y1="0.0" x2="91.20732522714323" y2="308.70171615340786" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="161.36680617109954" y1="0.0" x2="161.36680617109954" y2="308.70171615340786" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="231.52628711505588" y1="0.0" x2="231.52628711505588" y2="308.70171615340786" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="301.68576805901216" y1="0.0" x2="301.68576805901216" y2="308.70171615340786" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="371.84524900296856" y1="0.0" x2="371.84524900296856" y2="308.70171615340786" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="442.00472994692484" y1="0.0" x2="442.00472994692484" y2="308.70171615340786" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="294.6698199646166" x2="463.0525742301117" y2="294.6698199646166" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="224.51033902066027" x2="463.0525742301117" y2="224.51033902066027" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="154.35085807670396" x2="463.0525742301117" y2="154.35085807670396" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="84.19137713274762" x2="463.0525742301117" y2="84.19137713274762" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="14.031896188791308" x2="463.0525742301117" y2="14.031896188791308" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#c6OhWIx)" clip-bounds-jfx="[rect (35.01530667574961, 0.0), (463.0525742301117, 308.70171615340786)]">
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <g>
//               <image preserveAspectRatio="none" x="21.047844283186905" y="14.031896188791308" width="420.9568856637379" height="280.63792377582524" xlink:href="..." styl

// %% [markdown]
// ### RGB image with alpha channel specified by IntArray
// Note that pixels are not packed - size of the array have to be equal to `width * height * nChannels`

// %%
val intArrayA2x3x4 = RasterData.create(
    listOf(
            255, 0, 0, 255, 
            0, 255, 0, 255, 
            0, 0, 255, 255,
            0, 255, 0, 80, 
            0, 0, 255, 80, 
            255, 0, 0, 80
        ).toIntArray(),
    width = 3, height = 2, nChannels = 4
)

ggplot() + geomImshow(intArrayA2x3x4)
// Out:
//    <div id="Ugx5rn"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("Ugx5rn");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":1.5,
// "xmax":2.5,
// "color_by":"paint_c",
// "inherit_aes":false,
// "href":"...",
// "geom":"image",
// "data":{
// }
// }],
// "spec_id":"11"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=ffef6454-bbf6-47d3-9c5a-55f69e89f412 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pp2jPEh .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pp2jPEh .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pp2jPEh .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pp2jPEh .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pp2jPEh .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pp2jPEh .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pp2jPEh .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pp2jPEh .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #drNU4gK .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pp2jPEh .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pp2jPEh .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #drNU4gK .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pp2jPEh .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pp2jPEh .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #drNU4gK .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #drNU4gK .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #drNU4gK .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pp2jPEh">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M8.742346662125215 0.0 L8.742346662125215 400.0 L591.2576533378748 400.0 L591.2576533378748 0.0 Z">
//     </path>
//     <g transform="translate(38.242346662125215 6.5 ) ">
//       <g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="23.25" y1="0.0" x2="23.25" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="100.75" y1="0.0" x2="100.75" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="178.25" y1="0.0" x2="178.25" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="255.75" y1="0.0" x2="255.75" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="333.25" y1="0.0" x2="333.25" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="410.75" y1="0.0" x2="410.75" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="488.25" y1="0.0" x2="488.25" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="325.5" x2="511.49999999999994" y2="325.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="248.0" x2="511.49999999999994" y2="248.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="170.5" x2="511.49999999999994" y2="170.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="93.0" x2="511.49999999999994" y2="93.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="15.5" x2="511.49999999999994" y2="15.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cXYEziq)" clip-bounds-jfx="[rect (35.01530667574961, 0.0), (511.49999999999994, 341.0)]">
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <g>
//               <image preserveAspectRatio="none" x="23.25" y="15.5" width="465.0" height="310.0" xlink:href="..." style="image-rendering: optimizeSpeed; image-rendering: pixelated">
//
//             </g>
//           </g>
//         </g>
//         <defs>
//           <clipPath id="cXYEziq">
//             <rect x="35.01530667574961" y="0.0" width="511.49999999999994" height="341.0">
//             </rect>
//           </clipPath>
//         </defs>
//       </g>
//       <g>
//         <g transform="translate(35.01530667574961 341.0 ) ">
//           <g transform="translate(23.25 0.0 ) ">
//             <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//             </line>
//             <
