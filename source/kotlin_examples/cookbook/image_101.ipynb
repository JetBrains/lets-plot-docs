// %% [markdown]
// ## geomImshow()
//
// `geomImshow()` displays an image specified by 2D or 3D array.
//
// Whether the image is grayscale or color depends on the shape of the image array:
// - (M, N) - grey-scale image
// - (M, N, 3) - color RGB image
// - (M, N, 4) - color RGB image with alpha channel
//
// By default, all values in the image array will be transformed to the range [0-255] using a linear scaler.

// %%
%useLatestDescriptors
%use lets-plot
// Out:
//    <div id="VE2OGl"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.3.2/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("VE2OGl").appendChild(div);
//            };
//            var e = document.getElementById("VE2OGl");
//            e.appendChild(script);
//        })();
//    </script>

// %% [markdown]
// ### Grayscale image

// %%
val A2x3 = RasterData.create(
    listOf(
        listOf(50, 150 ,200),
        listOf(200,100,50)
    )
)

ggplot() + geomImshow(A2x3)
// Out:
//    <div id="jx1RPm"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"paint_c",
// "scale_mapper_kind":"color_grey",
// "name":"",
// "start":0.0,
// "end":1.0
// }],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// "paint_c":"paint_c"
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":1.5,
// "xmax":2.5,
// "color_by":"paint_c",
// "href":"...",
// "geom":"image",
// "data":{
// "paint_c":[50.0,200.0]
// }
// }]
// };
//            var plotContainer = document.getElementById("jx1RPm");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %% [markdown]
// #### Grayscale image without normalization

// %%
ggplot() + geomImshow(A2x3, norm=false)
// Out:
//    <div id="5xucJy"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"paint_c",
// "scale_mapper_kind":"color_grey",
// "name":"",
// "start":0.19607843137254902,
// "end":0.7843137254901961
// }],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// "paint_c":"paint_c"
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":1.5,
// "xmax":2.5,
// "color_by":"paint_c",
// "href":"...",
// "geom":"image",
// "data":{
// "paint_c":[50.0,200.0]
// }
// }]
// };
//            var plotContainer = document.getElementById("5xucJy");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %% [markdown]
// ### RGB image
//
// M x N x 3 array

// %%
val A2x3x3 = RasterData.create(
    listOf(
        listOf(listOf(255, 0, 0), listOf(0, 255, 0), listOf(0, 0, 255)),
        listOf(listOf(0, 255, 0), listOf(0, 0, 255), listOf(255, 0, 0))
    )
)

ggplot() + geomImshow(A2x3x3)
// Out:
//    <div id="KWfXWV"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":1.5,
// "xmax":2.5,
// "color_by":"paint_c",
// "href":"...",
// "geom":"image",
// "data":{
// }
// }]
// };
//            var plotContainer = document.getElementById("KWfXWV");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %% [markdown]
// ### RGB image with alpha channel
//
// M x N x 4 array

// %%
val A2x3x4 = RasterData.create(
    listOf(
        listOf(
            listOf(1.0, 0.0, 0.0, 1.0), listOf(0.0, 1.0, 0.0, 1.0), listOf(0.0, 0.0, 1.0, 1.0)
        ),
        listOf(
            listOf(0.0, 1.0, 0.0, 0.3), listOf(0.0, 0.0, 1.0, 0.3), listOf(1.0, 0.0, 0.0, 0.3)
        )
    )
)

ggplot() + geomImshow(A2x3x4)
// Out:
//    <div id="CFhGUj"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":1.5,
// "xmax":2.5,
// "color_by":"paint_c",
// "href":"...",
// "geom":"image",
// "data":{
// }
// }]
// };
//            var plotContainer = document.getElementById("CFhGUj");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %% [markdown]
// ## Image specified by array

// %% [markdown]
// ### Grayscale image specified by ByteArray

// %%
val byteArrayA2x3 = RasterData.create(
    byteArrayOf(50, 150.toByte(), 200.toByte(), 200.toByte(), 100, 50),
    width = 3, height = 2, nChannels = 1
)

ggplot() + geomImshow(byteArrayA2x3)
// Out:
//    <div id="zfxLIE"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"paint_c",
// "scale_mapper_kind":"color_grey",
// "name":"",
// "start":0.0,
// "end":1.0
// }],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// "paint_c":"paint_c"
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":1.5,
// "xmax":2.5,
// "color_by":"paint_c",
// "href":"...",
// "geom":"image",
// "data":{
// "paint_c":[50.0,200.0]
// }
// }]
// };
//            var plotContainer = document.getElementById("zfxLIE");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %% [markdown]
// ### RGB image with alpha channel specified by IntArray
// Note that pixels are not packed - size of the array have to be equal to `width * height * nChannels`

// %%
val intArrayA2x3x4 = RasterData.create(
    listOf(
            255, 0, 0, 255, 
            0, 255, 0, 255, 
            0, 0, 255, 255,
            0, 255, 0, 80, 
            0, 0, 255, 80, 
            255, 0, 0, 80
        ).toIntArray(),
    width = 3, height = 2, nChannels = 4
)

ggplot() + geomImshow(intArrayA2x3x4)
// Out:
//    <div id="CZHYaH"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "ymin":-0.5,
// "mapping":{
// },
// "stat":"identity",
// "xmin":-0.5,
// "ymax":1.5,
// "xmax":2.5,
// "color_by":"paint_c",
// "href":"...",
// "geom":"image",
// "data":{
// }
// }]
// };
//            var plotContainer = document.getElementById("CZHYaH");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
