// %% [markdown]
// ### The `labelFormat` parameter in `geomText()`
//
// The `labelFormat` parameter specifies template for transforming value of the `label` aesthetic to a string.
//
// To learn more about formatting templates see: [Formatting](https://github.com/JetBrains/lets-plot-kotlin/blob/master/docs/formats.md).

// %%
%useLatestDescriptors
%use lets-plot
// Out:
//    <div id="fndgDg"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.4.0/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("fndgDg").appendChild(div);
//            };
//            var e = document.getElementById("fndgDg");
//            e.appendChild(script);
//        })();
//    </script>

// %%
val df = mapOf<String, Any>(
    "y" to (0 until 5),
    "z" to listOf(1.0/3, 12.5/7, -22.5/11, 2.5/7, 31.67/1.77),
    "s" to listOf("one", "two", "three", "four", "five"))

// %%
// Floating point numbers without formatting.
letsPlot(df) + geomText {y = "y"; label = "z"}
// Out:
//    <div id="UOMMTO"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "data":{
// "y":[0.0,1.0,2.0,3.0,4.0],
// "z":[0.3333333333333333,1.7857142857142858,-2.0454545454545454,0.35714285714285715,17.89265536723164]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "y":"y",
// "label":"z"
// },
// "stat":"identity",
// "position":"identity",
// "geom":"text",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"y"
// },{
// "type":"float",
// "column":"z"
// },{
// "type":"str",
// "column":"s"
// }]
// }
// };
//            var plotContainer = document.getElementById("UOMMTO");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %%
// Floating point numbers with formatting.
letsPlot(df) + geomText(labelFormat = ".3f") {y = "y"; label = "z"; }
// Out:
//    <div id="TznXTJ"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "data":{
// "y":[0.0,1.0,2.0,3.0,4.0],
// "z":[0.3333333333333333,1.7857142857142858,-2.0454545454545454,0.35714285714285715,17.89265536723164]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "y":"y",
// "label":"z"
// },
// "stat":"identity",
// "label_format":".3f",
// "position":"identity",
// "geom":"text",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"y"
// },{
// "type":"float",
// "column":"z"
// },{
// "type":"str",
// "column":"s"
// }]
// }
// };
//            var plotContainer = document.getElementById("TznXTJ");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %%
// Floating point numbers as percentage formatting.
letsPlot(df) + geomText(labelFormat = ".1%") {y = "y"; label = "z"; }
// Out:
//    <div id="x4NZPR"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "data":{
// "y":[0.0,1.0,2.0,3.0,4.0],
// "z":[0.3333333333333333,1.7857142857142858,-2.0454545454545454,0.35714285714285715,17.89265536723164]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "y":"y",
// "label":"z"
// },
// "stat":"identity",
// "label_format":".1%",
// "position":"identity",
// "geom":"text",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"y"
// },{
// "type":"float",
// "column":"z"
// },{
// "type":"str",
// "column":"s"
// }]
// }
// };
//            var plotContainer = document.getElementById("x4NZPR");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %%
// Number format as a part of a string pattern.
letsPlot(df) + geomText(labelFormat = "Ttl: \${.2f} (B)") {y = "y"; label = "z"; }
// Out:
//    <div id="Ue1lAg"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "data":{
// "y":[0.0,1.0,2.0,3.0,4.0],
// "z":[0.3333333333333333,1.7857142857142858,-2.0454545454545454,0.35714285714285715,17.89265536723164]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "y":"y",
// "label":"z"
// },
// "stat":"identity",
// "label_format":"Ttl: ${.2f} (B)",
// "position":"identity",
// "geom":"text",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"y"
// },{
// "type":"float",
// "column":"z"
// },{
// "type":"str",
// "column":"s"
// }]
// }
// };
//            var plotContainer = document.getElementById("Ue1lAg");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>

// %%
// String pattern without value formatting. "{}"
letsPlot(df) + geomText(labelFormat = "--{}--") {y = "y"; label = "s"; }
// Out:
//    <div id="T0qbYm"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//        (function() {
//            var plotSpec={
// "mapping":{
// },
// "data":{
// "s":["one","two","three","four","five"],
// "y":[0.0,1.0,2.0,3.0,4.0]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "y":"y",
// "label":"s"
// },
// "stat":"identity",
// "label_format":"--{}--",
// "position":"identity",
// "geom":"text",
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"y"
// },{
// "type":"float",
// "column":"z"
// },{
// "type":"str",
// "column":"s"
// }]
// }
// };
//            var plotContainer = document.getElementById("T0qbYm");
//            window.letsPlotCall(function() {{
//                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
//            }});
//        })();
//    </script>
