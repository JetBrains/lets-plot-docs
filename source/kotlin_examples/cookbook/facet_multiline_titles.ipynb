// %% [markdown]
// # Multi-line Labels in Facets
//
//
// The 'newline' character (`\n`) now works as a 'line break' in the facet titles.</br>
// Automatic line breaking is performed according to the  text length limit specified with parameters `labWidth` in `facetWrap()` and `xLabWidth`/`yLabWidth` in `facetGrid()`.
//
// The margins around the facet titles are controlled by the `margin` parameter in `elementText()`.</br>
// Horizontal and vertical justifications - using `hjust` and `vjust` parameter in `elementText()`.

// %%
%useLatestDescriptors
%use dataframe
%use lets-plot
// Out:
//             <div id="kotlin_out_0"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["DataFrame"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["DataFrame"] = resQueue;
//                 window["call_DataFrame"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/Kotlin/dataframe@3db46ccccaa1291c0627307d64133317f545e6ae/core/src/main/resources/init.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_DataFrame"] = function(f) {f();};
//                         window.kotlinQueues["DataFrame"].forEach(function(f) {f();});
//                         window.kotlinQueues["DataFrame"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_DataFrame"] = function(f) {};
//                         window.kotlinQueues["DataFrame"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource DataFrame';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>
//                 <style>
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme="dark"], :root [data-jp-theme-light="false"], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
//     --text-color-dark: #dddddd;
//     --text-color-medium: #b2b2b2;
//     --text-color-pale: #737373;
//     --inner-border-color: #707070;
//     --bold-border-color: #777777;
//     --link-color: #008dc0;
//     --link-color-pale: #97e1fb;
//     --link-hover: #00688e;
// }
//
// p.dataframe_description {
//     color: var(--text-color-dark);
// }
//
// table.dataframe {
//     font-family: "Helvetica Neue", Helvetica, Arial, sans-serif;
//     font-size: 12px;
//     background-color: var(--background);
//     color: var(--text-color-dark);
//     border: none;
//     border-collapse: collapse;
// }
//
// table.dataframe th, td {
//     padding: 6px;
//     border: 1px solid transparent;
//     text-align: left;
// }
//
// table.dataframe th {
//     background-color: var(--background);
//     color: var(--header-text-color);
// }
//
// table.dataframe td {
//     vertical-align: top;
//     white-space: nowrap;
// }
//
// table.dataframe th.bottomBorder {
//     border-bottom-color: var(--bold-border-color);
// }
//
// table.dataframe tbody > tr:nth-child(odd) {
//     background: var(--background-odd);
// }
//
// table.dataframe tbody > tr:nth-child(even) {
//     background: var(--background);
// }
//
// table.dataframe tbody > tr:hover {
//     background: var(--background-hover);
// }
//
// table.dataframe a {
//     cursor: pointer;
//     color: var(--link-color);
//     text-decoration: none;
// }
//
// table.dataframe tr:hover > td a {
//     color: var(--link-color-pale);
// }
//
// table.dataframe a:hover {
//     color: var(--link-hover);
//     text-decoration: underline;
// }
//
// table.dataframe img {
//     max-width: fit-content;
// }
//
// table.dataframe th.complex {
//     background-color: var(--background);
//     border: 1px solid var(--background);
// }
//
// table.dataframe .leftBorder {
//     border-left-color: var(--inner-border-color);
// }
//
// table.dataframe .rightBorder {
//     border-right-color: var(--inner-border-color);
// }
//
// table.dataframe .rightAlign {
//     text-align: right;
// }
//
// table.dataframe .expanderSvg {
//     width: 8px;
//     height: 8px;
//     margin-right: 3px;
// }
//
// table.dataframe .expander {
//     display: flex;
//     align-items: center;
// }
//
// /* formatting */
//
// table.dataframe .null {
//     color: var(--text-color-pale);
// }
//
// table.dataframe .structural {
//     color: var(--text-color-medium);
//     font-weight: bold;
// }
//
// table.dataframe .dataFrameCaption {
//     font-weight: bold;
// }
//
// table.dataframe .numbers {
//     color: var(--text-color-dark);
// }
//
// table.dataframe td:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
// table.dataframe tr:hover .formatted .structural, .null {
//     color: var(--text-color-dark);
// }
//
//
//                 </style>
//    <div id="eVdDXH"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.7.0/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("eVdDXH").appendChild(div);
//            };
//            var e = document.getElementById("eVdDXH");
//            e.appendChild(script);
//        })();
//    </script>
//             <div id="kotlin_out_1"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["letsPlotJs"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["letsPlotJs"] = resQueue;
//                 window["call_letsPlotJs"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.7.0/js-package/distr/lets-plot.min.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_1");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_letsPlotJs"] = function(f) {f();};
//                         window.kotlinQueues["letsPlotJs"].forEach(function(f) {f();});
//                         window.kotlinQueues["letsPlotJs"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_letsPlotJs"] = function(f) {};
//                         window.kotlinQueues["letsPlotJs"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource letsPlotJs';
//                         document.getElementById("kotlin_out_1").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>

// %%
LetsPlot.getInfo()
// Out:
// Lets-Plot Kotlin API v.4.11.0. Frontend: Notebook with dynamically loaded JS. Lets-Plot JS v.4.7.0.

// %%
val df = dataFrameOf("animal_type", "animal", "weight", "diet")(
    "pet", "cat", 5, "carnivore",
    "pet", "dog", 10, "carnivore",
    "pet", "rabbit", 2, "herbivore",
    "pet", "hamster", 1, "herbivore",

    "farm animal", "cow", 500, "herbivore",
    "farm animal", "pig", 100, "carnivore",
    "farm animal", "horse", 700, "herbivore",
)

// %% [markdown]
// ### Facet Labels

// %%
val p = letsPlot(df.toMap()) { x = "animal"; y = "weight" } +
    geomBar(stat = Stat.identity) +
    themeBW() +
    theme(panelGridMinor = elementBlank())

// %% [markdown]
// #### Default

// %%
p + facetWrap(facets = "animal_type", ncol = 2, scales = "free")
// Out:
//    <div id="z83iBK"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.7.0/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("z83iBK").appendChild(div);
//            };
//            var e = document.getElementById("z83iBK");
//            e.appendChild(script);
//        })();
//    </script>
//    <div id="fQGvBf"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("fQGvBf");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// "x":"animal",
// "y":"weight"
// },
// "data":{
// "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
// "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
// "animal_type":["pet","pet","pet","pet","farm animal","farm animal","farm animal"]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// }],
// "theme":{
// "name":"bw",
// "panel_grid_minor":{
// "blank":true
// }
// },
// "facet":{
// "ncol":2.0,
// "scales":"free",
// "name":"wrap",
// "dir":"h",
// "facets":"animal_type",
// "order":1.0
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"animal_type"
// },{
// "type":"str",
// "column":"animal"
// },{
// "type":"int",
// "column":"weight"
// },{
// "type":"str",
// "column":"diet"
// }]
// },
// "spec_id":"1"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=e9c3994e-80f6-4113-a877-d40508f192f8 width="100%" height="100%" style="max-width: 900.0px; max-height: 400.0px;" viewBox="0 0 900.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pw4O7of .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pw4O7of .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pw4O7of .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pw4O7of .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pw4O7of .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pw4O7of .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pw4O7of .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pw4O7of .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dj4ZIxZ .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pw4O7of .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pw4O7of .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dj4ZIxZ .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pw4O7of .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pw4O7of .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dj4ZIxZ .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dj4ZIxZ .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dj4ZIxZ .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pw4O7of">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M1.5 0.0 L1.5 400.0 L898.5 400.0 L898.5 0.0 Z">
//     </path>
//     <g transform="translate(22.5 6.0 ) ">
//       <g>
//         <rect x="29.941816366404606" y="22.0" height="332.0" width="404.0484863613295" fill="rgb(255,255,255)" fill-opacity="1.0">
//         </rect>
//         <g transform="translate(29.941816366404606 22.0 ) ">
//           <g>
//             <line x1="79.5853079196558" y1="0.0" x2="79.5853079196558" y2="332.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="202.0242431806647" y1="0.0" x2="202.0242431806647" y2="332.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="324.4631784416737" y1="0.0" x2="324.4631784416737" y2="332.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(29.941816366404606 22.0 ) ">
//           <g>
//             <line x1="0.0" y1="286.8299319727891" x2="404.0484863613295" y2="286.8299319727891" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="241.65986394557822" x2="404.0484863613295" y2="241.65986394557822" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="196.48979591836735" x2="404.0484863613295" y2="196.48979591836735" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="151.31972789115645" x2="404.0484863613295" y2="151.31972789115645" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="106.14965986394557" x2="404.0484863613295" y2="106.14965986394557" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="60.9795918367347" x2="404.0484863613295" y2="60.9795918367347" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="15.809523809523796" x2="404.0484863613295" y2="15.809523809523796" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cdboucv)" clip-bounds-jfx="[rect (29.941816366404606, 22.

// %% [markdown]
// #### Wrap Labels using `labWidth`-parameters

// %%
p + facetWrap(facets = "animal_type", ncol = 2, scales = "free", labWidth = 6)
// Out:
//    <div id="0zaEpB"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("0zaEpB");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// "x":"animal",
// "y":"weight"
// },
// "data":{
// "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
// "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
// "animal_type":["pet","pet","pet","pet","farm animal","farm animal","farm animal"]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// }],
// "theme":{
// "name":"bw",
// "panel_grid_minor":{
// "blank":true
// }
// },
// "facet":{
// "ncol":2.0,
// "scales":"free",
// "name":"wrap",
// "dir":"h",
// "labwidth":6.0,
// "facets":"animal_type",
// "order":1.0
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"animal_type"
// },{
// "type":"str",
// "column":"animal"
// },{
// "type":"int",
// "column":"weight"
// },{
// "type":"str",
// "column":"diet"
// }]
// },
// "spec_id":"3"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=8f6350ed-29a5-4ed4-848b-bef93bfe24c5 width="100%" height="100%" style="max-width: 900.0px; max-height: 400.0px;" viewBox="0 0 900.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #phYeqsu .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #phYeqsu .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #phYeqsu .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #phYeqsu .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #phYeqsu .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #phYeqsu .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #phYeqsu .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #phYeqsu .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dmXy3mm .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #phYeqsu .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #phYeqsu .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dmXy3mm .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #phYeqsu .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #phYeqsu .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dmXy3mm .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dmXy3mm .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dmXy3mm .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="phYeqsu">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M1.5 0.0 L1.5 400.0 L898.5 400.0 L898.5 0.0 Z">
//     </path>
//     <g transform="translate(22.5 6.0 ) ">
//       <g>
//         <rect x="29.941816366404606" y="35.0" height="319.0" width="404.0484863613295" fill="rgb(255,255,255)" fill-opacity="1.0">
//         </rect>
//         <g transform="translate(29.941816366404606 35.0 ) ">
//           <g>
//             <line x1="79.5853079196558" y1="0.0" x2="79.5853079196558" y2="319.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="202.0242431806647" y1="0.0" x2="202.0242431806647" y2="319.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="324.4631784416737" y1="0.0" x2="324.4631784416737" y2="319.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(29.941816366404606 35.0 ) ">
//           <g>
//             <line x1="0.0" y1="275.5986394557823" x2="404.0484863613295" y2="275.5986394557823" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="232.19727891156464" x2="404.0484863613295" y2="232.19727891156464" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="188.79591836734693" x2="404.0484863613295" y2="188.79591836734693" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="145.39455782312925" x2="404.0484863613295" y2="145.39455782312925" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="101.99319727891157" x2="404.0484863613295" y2="101.99319727891157" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="58.59183673469386" x2="404.0484863613295" y2="58.59183673469386" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="15.190476190476204" x2="404.0484863613295" y2="15.190476190476204" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cdcxMt4)" clip-bounds-jfx="[rect (29.94

// %%
p + facetGrid(x = "animal_type", y = "diet", scales = "free", xLabWidth = 6)
// Out:
//    <div id="qjG4Q1"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("qjG4Q1");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// "x":"animal",
// "y":"weight"
// },
// "data":{
// "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
// "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
// "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"],
// "animal_type":["pet","pet","pet","pet","farm animal","farm animal","farm animal"]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// }],
// "theme":{
// "name":"bw",
// "panel_grid_minor":{
// "blank":true
// }
// },
// "facet":{
// "x_labwidth":6.0,
// "scales":"free",
// "y_order":1.0,
// "name":"grid",
// "x":"animal_type",
// "y":"diet",
// "x_order":1.0
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"animal_type"
// },{
// "type":"str",
// "column":"animal"
// },{
// "type":"int",
// "column":"weight"
// },{
// "type":"str",
// "column":"diet"
// }]
// },
// "spec_id":"5"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=e000de38-f9da-4127-a800-9e32048996eb width="100%" height="100%" style="max-width: 900.0px; max-height: 600.0px;" viewBox="0 0 900.0 600.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pd78Qvm .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pd78Qvm .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pd78Qvm .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pd78Qvm .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pd78Qvm .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pd78Qvm .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pd78Qvm .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pd78Qvm .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #digkHio .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pd78Qvm .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pd78Qvm .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #digkHio .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pd78Qvm .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pd78Qvm .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #digkHio .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #digkHio .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #digkHio .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pd78Qvm">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 600.0 L900.0 600.0 L900.0 0.0 Z">
//     </path>
//     <g transform="translate(21.0 6.0 ) ">
//       <g>
//         <rect x="29.941816366404606" y="35.0" height="254.5" width="405.5290918167977" fill="rgb(255,255,255)" fill-opacity="1.0">
//         </rect>
//         <g transform="translate(29.941816366404606 35.0 ) ">
//           <g>
//             <line x1="79.87694232755106" y1="0.0" x2="79.87694232755106" y2="254.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="202.76454590839884" y1="0.0" x2="202.76454590839884" y2="254.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="325.65214948924665" y1="0.0" x2="325.65214948924665" y2="254.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(29.941816366404606 35.0 ) ">
//           <g>
//             <line x1="0.0" y1="206.02380952380952" x2="405.5290918167977" y2="206.02380952380952" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="157.54761904761904" x2="405.5290918167977" y2="157.54761904761904" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="109.07142857142858" x2="405.5290918167977" y2="109.07142857142858" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="60.5952380952381" x2="405.5290918167977" y2="60.5952380952381" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="12.119047619047649" x2="405.5290918167977" y2="12.119047619047649" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cLHYZm2)" clip-bounds-jfx="[rect (29.941816366404606, 35.0), (405.5290918167977, 254.5)]">
//         <g transform="translate(29.941816366404606 35.0 ) ">
//           <g>
//             <g>
//               <rect x="147.46512429701735" y="12.119047619047649" height="242.38095238095235" width="110.59884322276301" stroke="rgb(255,255,255)" s

// %% [markdown]
// #### Line Breaks Using `\n` in Facet Values

// %%
val df2 = df.update { animal_type }.with { it.replace(' ', '\n') }

val p2 = letsPlot(df2.toMap()) { x = "animal"; y = "weight" } +
    geomBar(stat = Stat.identity) +
    themeBW() +
    theme(panelGridMinor = elementBlank())

// %%
p2 + facetGrid(x = "animal_type", y = "diet", scales = "free")
// Out:
//    <div id="0td1Wj"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("0td1Wj");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// "x":"animal",
// "y":"weight"
// },
// "data":{
// "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
// "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
// "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"],
// "animal_type":["pet","pet","pet","pet","farm\nanimal","farm\nanimal","farm\nanimal"]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// }],
// "theme":{
// "name":"bw",
// "panel_grid_minor":{
// "blank":true
// }
// },
// "facet":{
// "scales":"free",
// "y_order":1.0,
// "name":"grid",
// "x":"animal_type",
// "y":"diet",
// "x_order":1.0
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"animal_type"
// },{
// "type":"str",
// "column":"animal"
// },{
// "type":"int",
// "column":"weight"
// },{
// "type":"str",
// "column":"diet"
// }]
// },
// "spec_id":"7"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=afb2b556-7055-43ae-b974-afd3a7fd8b50 width="100%" height="100%" style="max-width: 900.0px; max-height: 600.0px;" viewBox="0 0 900.0 600.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pAcN5wY .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pAcN5wY .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pAcN5wY .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pAcN5wY .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pAcN5wY .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pAcN5wY .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pAcN5wY .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pAcN5wY .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #d7EyDQZ .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pAcN5wY .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pAcN5wY .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #d7EyDQZ .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pAcN5wY .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pAcN5wY .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #d7EyDQZ .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #d7EyDQZ .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #d7EyDQZ .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pAcN5wY">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 600.0 L900.0 600.0 L900.0 0.0 Z">
//     </path>
//     <g transform="translate(21.0 6.0 ) ">
//       <g>
//         <rect x="29.941816366404606" y="35.0" height="254.5" width="405.5290918167977" fill="rgb(255,255,255)" fill-opacity="1.0">
//         </rect>
//         <g transform="translate(29.941816366404606 35.0 ) ">
//           <g>
//             <line x1="79.87694232755106" y1="0.0" x2="79.87694232755106" y2="254.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="202.76454590839884" y1="0.0" x2="202.76454590839884" y2="254.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="325.65214948924665" y1="0.0" x2="325.65214948924665" y2="254.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(29.941816366404606 35.0 ) ">
//           <g>
//             <line x1="0.0" y1="206.02380952380952" x2="405.5290918167977" y2="206.02380952380952" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="157.54761904761904" x2="405.5290918167977" y2="157.54761904761904" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="109.07142857142858" x2="405.5290918167977" y2="109.07142857142858" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="60.5952380952381" x2="405.5290918167977" y2="60.5952380952381" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="12.119047619047649" x2="405.5290918167977" y2="12.119047619047649" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#ctD9liL)" clip-bounds-jfx="[rect (29.941816366404606, 35.0), (405.5290918167977, 254.5)]">
//         <g transform="translate(29.941816366404606 35.0 ) ">
//           <g>
//             <g>
//               <rect x="147.46512429701735" y="12.119047619047649" height="242.38095238095235" width="110.59884322276301" stroke="rgb(255,255,255)" stroke-opacity="

// %%
p2 + facetWrap(facets = listOf("animal_type", "diet"), ncol = 4, scales = "free")
// Out:
//    <div id="NqmTvN"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("NqmTvN");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// "x":"animal",
// "y":"weight"
// },
// "data":{
// "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
// "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
// "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"],
// "animal_type":["pet","pet","pet","pet","farm\nanimal","farm\nanimal","farm\nanimal"]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// }],
// "theme":{
// "name":"bw",
// "panel_grid_minor":{
// "blank":true
// }
// },
// "facet":{
// "ncol":4.0,
// "scales":"free",
// "name":"wrap",
// "dir":"h",
// "facets":["animal_type","diet"],
// "order":1.0
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"animal_type"
// },{
// "type":"str",
// "column":"animal"
// },{
// "type":"int",
// "column":"weight"
// },{
// "type":"str",
// "column":"diet"
// }]
// },
// "spec_id":"9"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=6278c506-d8d4-46c3-8bb7-583e4f303c74 width="100%" height="100%" style="max-width: 1500.0px; max-height: 400.0px;" viewBox="0 0 1500.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #p7tgj3v .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #p7tgj3v .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #p7tgj3v .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #p7tgj3v .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #p7tgj3v .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #p7tgj3v .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #p7tgj3v .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #p7tgj3v .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dP0sZnZ .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #p7tgj3v .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #p7tgj3v .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dP0sZnZ .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #p7tgj3v .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #p7tgj3v .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dP0sZnZ .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dP0sZnZ .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dP0sZnZ .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="p7tgj3v">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M1.5000000000001137 0.0 L1.5000000000001137 400.0 L1498.5 400.0 L1498.5 0.0 Z">
//     </path>
//     <g transform="translate(22.500000000000114 6.0 ) ">
//       <g>
//         <rect x="29.941816366404606" y="54.0" height="300.0" width="332.7801137839932" fill="rgb(255,255,255)" fill-opacity="1.0">
//         </rect>
//         <g transform="translate(29.941816366404606 54.0 ) ">
//           <g>
//             <line x1="166.3900568919966" y1="0.0" x2="166.3900568919966" y2="300.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(29.941816366404606 54.0 ) ">
//           <g>
//             <line x1="0.0" y1="242.85714285714286" x2="332.7801137839932" y2="242.85714285714286" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="185.71428571428572" x2="332.7801137839932" y2="185.71428571428572" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="128.57142857142856" x2="332.7801137839932" y2="128.57142857142856" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="71.42857142857142" x2="332.7801137839932" y2="71.42857142857142" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="14.285714285714278" x2="332.7801137839932" y2="14.285714285714278" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cJAC8A2)" clip-bounds-jfx="[rect (29.941816366404606, 54.0), (332.7801137839932, 300.0)]">
//         <g transform="translate(29.941816366404606 54.0 ) ">
//           <g>
//             <g>
//               <rect x="51.196940582152806" y="14.285714285714278" height="285.7142857142857" width="230.38623261968758" stroke="rgb(255,255,255)" stroke-opacity="1.0" fill="rgb(17,142,216)" fill-opacity="1.0" stroke-width="1.6500000000000001">
//               </rect>
//             </g>
//           </g>
//         </g>
//         <defs>
//           <clipPath id="cJAC8A2">
//             <rect x="29.941816366404606" y="54.0" width="332.7801137839932" height="300.0">
//             </rect>

// %% [markdown]
// ### Text Justifications

// %%
p2 + facetWrap(facets = listOf("animal_type", "diet"), ncol = 4, scales = "free") +
    theme(stripText = elementText(hjust = 1, vjust = 1))
// Out:
//    <div id="MvOOJx"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("MvOOJx");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// "x":"animal",
// "y":"weight"
// },
// "data":{
// "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
// "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
// "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"],
// "animal_type":["pet","pet","pet","pet","farm\nanimal","farm\nanimal","farm\nanimal"]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// }],
// "theme":{
// "name":"bw",
// "panel_grid_minor":{
// "blank":true
// },
// "strip_text":{
// "hjust":1.0,
// "vjust":1.0,
// "blank":false
// }
// },
// "facet":{
// "ncol":4.0,
// "scales":"free",
// "name":"wrap",
// "dir":"h",
// "facets":["animal_type","diet"],
// "order":1.0
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"animal_type"
// },{
// "type":"str",
// "column":"animal"
// },{
// "type":"int",
// "column":"weight"
// },{
// "type":"str",
// "column":"diet"
// }]
// },
// "spec_id":"11"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=de3266b0-1911-4e1d-95f1-9b9838b635cf width="100%" height="100%" style="max-width: 1500.0px; max-height: 400.0px;" viewBox="0 0 1500.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pZefWX9 .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pZefWX9 .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pZefWX9 .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pZefWX9 .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pZefWX9 .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pZefWX9 .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pZefWX9 .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pZefWX9 .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #duOB9eU .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pZefWX9 .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pZefWX9 .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #duOB9eU .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pZefWX9 .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pZefWX9 .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #duOB9eU .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #duOB9eU .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #duOB9eU .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pZefWX9">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M1.5000000000001137 0.0 L1.5000000000001137 400.0 L1498.5 400.0 L1498.5 0.0 Z">
//     </path>
//     <g transform="translate(22.500000000000114 6.0 ) ">
//       <g>
//         <rect x="29.941816366404606" y="54.0" height="300.0" width="332.7801137839932" fill="rgb(255,255,255)" fill-opacity="1.0">
//         </rect>
//         <g transform="translate(29.941816366404606 54.0 ) ">
//           <g>
//             <line x1="166.3900568919966" y1="0.0" x2="166.3900568919966" y2="300.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(29.941816366404606 54.0 ) ">
//           <g>
//             <line x1="0.0" y1="242.85714285714286" x2="332.7801137839932" y2="242.85714285714286" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="185.71428571428572" x2="332.7801137839932" y2="185.71428571428572" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="128.57142857142856" x2="332.7801137839932" y2="128.57142857142856" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="71.42857142857142" x2="332.7801137839932" y2="71.42857142857142" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="14.285714285714278" x2="332.7801137839932" y2="14.285714285714278" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cByolhf)" clip-bounds-jfx="[rect (29.941816366404606, 54.0), (332.7801137839932, 300.0)]">
//         <g transform="translate(29.941816366404606 54.0 ) ">
//           <g>
//             <g>
//               <rect x="51.196940582152806" y="14.285714285714278" height="285.7142857142857" width="230.38623261968758" stroke="rgb(255,255,255)" stroke-opacity="1.0" fill="rgb(17,142,216)" fill-opacity="1.0" stroke-width="1.6500000000000001">
//               </rect>
//             </g>
//           </g>
//         </g>
//         <defs>
//           <clipPath id="cByolhf">
//             <rect x="29.941816366404606" y="54.0" width=

// %% [markdown]
// ### Margins Around the Text Element

// %%
p2 + facetGrid(x = "animal_type", y = "diet", scales = "free") +
    theme(stripText = elementText(margin = listOf(10, 30), hjust = 0, vjust = 1))
// Out:
//    <div id="O5iEmM"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("O5iEmM");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// "x":"animal",
// "y":"weight"
// },
// "data":{
// "animal":["cat","dog","rabbit","hamster","cow","pig","horse"],
// "weight":[5.0,10.0,2.0,1.0,500.0,100.0,700.0],
// "diet":["carnivore","carnivore","herbivore","herbivore","herbivore","carnivore","herbivore"],
// "animal_type":["pet","pet","pet","pet","farm\nanimal","farm\nanimal","farm\nanimal"]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"identity",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// }],
// "theme":{
// "name":"bw",
// "panel_grid_minor":{
// "blank":true
// },
// "strip_text":{
// "hjust":0.0,
// "vjust":1.0,
// "margin":[10.0,30.0],
// "blank":false
// }
// },
// "facet":{
// "scales":"free",
// "y_order":1.0,
// "name":"grid",
// "x":"animal_type",
// "y":"diet",
// "x_order":1.0
// },
// "data_meta":{
// "series_annotations":[{
// "type":"str",
// "column":"animal_type"
// },{
// "type":"str",
// "column":"animal"
// },{
// "type":"int",
// "column":"weight"
// },{
// "type":"str",
// "column":"diet"
// }]
// },
// "spec_id":"13"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=558190f6-be5e-4877-b786-a72fc456aafc width="100%" height="100%" style="max-width: 900.0px; max-height: 600.0px;" viewBox="0 0 900.0 600.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pxdduZz .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 16.0px;
//
// }
// #pxdduZz .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pxdduZz .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pxdduZz .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pxdduZz .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pxdduZz .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pxdduZz .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pxdduZz .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dBzwMK4 .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pxdduZz .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 15.0px;
//
// }
// #pxdduZz .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dBzwMK4 .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pxdduZz .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #pxdduZz .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dBzwMK4 .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dBzwMK4 .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
// #dBzwMK4 .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pxdduZz">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 600.0 L900.0 600.0 L900.0 0.0 Z">
//     </path>
//     <g transform="translate(21.0 6.0 ) ">
//       <g>
//         <rect x="29.941816366404606" y="49.0" height="247.5" width="378.5290918167977" fill="rgb(255,255,255)" fill-opacity="1.0">
//         </rect>
//         <g transform="translate(29.941816366404606 49.0 ) ">
//           <g>
//             <line x1="74.55876050936924" y1="0.0" x2="74.55876050936924" y2="247.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="189.26454590839882" y1="0.0" x2="189.26454590839882" y2="247.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="303.9703313074284" y1="0.0" x2="303.9703313074284" y2="247.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(29.941816366404606 49.0 ) ">
//           <g>
//             <line x1="0.0" y1="200.35714285714286" x2="378.5290918167977" y2="200.35714285714286" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="153.21428571428572" x2="378.5290918167977" y2="153.21428571428572" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="106.07142857142856" x2="378.5290918167977" y2="106.07142857142856" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="58.928571428571416" x2="378.5290918167977" y2="58.928571428571416" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//             <line x1="0.0" y1="11.785714285714278" x2="378.5290918167977" y2="11.785714285714278" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.4" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cFByr4z)" clip-bounds-jfx="[rect (29.941816366404606, 49.0), (378.5290918167977, 247.5)]">
//         <g transform="translate(29.941816366404606 49.0 ) ">
//           <g>
//             <g>
//               <rect x="137.6469424788355" y="11.785714285714278" height="235.714
