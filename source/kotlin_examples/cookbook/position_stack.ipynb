// %%
%useLatestDescriptors
%use lets-plot
// Out:
//    <div id="PSZxFH"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.1/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("PSZxFH").appendChild(div);
//            };
//            var e = document.getElementById("PSZxFH");
//            e.appendChild(script);
//        })();
//    </script>
//             <div id="kotlin_out_0"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["letsPlotJs"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["letsPlotJs"] = resQueue;
//                 window["call_letsPlotJs"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.1/js-package/distr/lets-plot.min.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_letsPlotJs"] = function(f) {f();};
//                         window.kotlinQueues["letsPlotJs"].forEach(function(f) {f();});
//                         window.kotlinQueues["letsPlotJs"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_letsPlotJs"] = function(f) {};
//                         window.kotlinQueues["letsPlotJs"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource letsPlotJs';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>

// %%
LetsPlot.getInfo()
// Out:
// Lets-Plot Kotlin API v.4.10.0. Frontend: Notebook with dynamically loaded JS. Lets-Plot JS v.4.6.1.

// %%
val data = mapOf(
    "x" to listOf(1, 1, 2, 2, 2),
    "y" to listOf(1, 3, 2, 1, -3),
    "grp" to listOf("a", "b", "a", "b", "c")
)

val p = letsPlot(data) { x = "x"; y = "y"; group = "grp" } + 
    geomBar(stat = Stat.identity, color = "pen") { fill = "grp" }  + 
    scaleFillBrewer(palette = "Pastel1") +
    theme(axisLineX = elementBlank(), axisTicks = elementBlank()) + 
    geomHLine(yintercept = 0, color = "pen", size = 0.5)

// %%
val w = 600
val h = 400

gggrid(listOf(
    p + geomLabel(position = positionStack()) { label = "y" } + ggtitle("Default"),
    p + geomLabel(position = positionStack(0.0)) { label = "y" } + ggtitle("vjust = 0.0"),
    p + geomLabel(position = positionStack(0.3)) { label = "y" } + ggtitle("vjust = 0.3"),
    p + geomLabel(position = positionStack(0.5)) { label = "y" } + ggtitle("vjust = 0.5"),
    p + geomLabel(position = positionStack(0.7)) { label = "y" } + ggtitle("vjust = 0.7"),
    p + geomLabel(position = positionStack(1.0)) { label = "y" } + ggtitle("vjust = 1.0")
), ncol = 2) + ggsize(2 * w, 3 * h)
// Out:
//    <div id="UdxJzG"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.6.1/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("UdxJzG").appendChild(div);
//            };
//            var e = document.getElementById("UdxJzG");
//            e.appendChild(script);
//        })();
//    </script>
//    <div id="B5xmL0"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("B5xmL0");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "layout":{
// "name":"grid",
// "ncol":2,
// "nrow":3,
// "fit":true,
// "align":false
// },
// "figures":[{
// "ggtitle":{
// "text":"Default"
// },
// "mapping":{
// "x":"x",
// "y":"y",
// "group":"grp"
// },
// "data":{
// "grp":["a","b","a","b","c"],
// "x":[1.0,1.0,2.0,2.0,2.0],
// "y":[1.0,3.0,2.0,1.0,-3.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Pastel1"
// }],
// "layers":[{
// "mapping":{
// "fill":"grp"
// },
// "stat":"identity",
// "color":"pen",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "yintercept":0.0,
// "color":"pen",
// "size":0.5,
// "position":"identity",
// "geom":"hline",
// "data":{
// }
// },{
// "mapping":{
// "label":"y"
// },
// "stat":"identity",
// "position":"stack",
// "geom":"label",
// "data":{
// }
// }],
// "theme":{
// "axis_ticks":{
// "blank":true
// },
// "axis_line_x":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// },{
// "type":"str",
// "column":"grp"
// }]
// },
// "spec_id":"1"
// },{
// "ggtitle":{
// "text":"vjust = 0.0"
// },
// "mapping":{
// "x":"x",
// "y":"y",
// "group":"grp"
// },
// "data":{
// "grp":["a","b","a","b","c"],
// "x":[1.0,1.0,2.0,2.0,2.0],
// "y":[1.0,3.0,2.0,1.0,-3.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Pastel1"
// }],
// "layers":[{
// "mapping":{
// "fill":"grp"
// },
// "stat":"identity",
// "color":"pen",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "yintercept":0.0,
// "color":"pen",
// "size":0.5,
// "position":"identity",
// "geom":"hline",
// "data":{
// }
// },{
// "mapping":{
// "label":"y"
// },
// "stat":"identity",
// "position":{
// "name":"stack",
// "vjust":0.0
// },
// "geom":"label",
// "data":{
// }
// }],
// "theme":{
// "axis_ticks":{
// "blank":true
// },
// "axis_line_x":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// },{
// "type":"str",
// "column":"grp"
// }]
// },
// "spec_id":"2"
// },{
// "ggtitle":{
// "text":"vjust = 0.3"
// },
// "mapping":{
// "x":"x",
// "y":"y",
// "group":"grp"
// },
// "data":{
// "grp":["a","b","a","b","c"],
// "x":[1.0,1.0,2.0,2.0,2.0],
// "y":[1.0,3.0,2.0,1.0,-3.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Pastel1"
// }],
// "layers":[{
// "mapping":{
// "fill":"grp"
// },
// "stat":"identity",
// "color":"pen",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "yintercept":0.0,
// "color":"pen",
// "size":0.5,
// "position":"identity",
// "geom":"hline",
// "data":{
// }
// },{
// "mapping":{
// "label":"y"
// },
// "stat":"identity",
// "position":{
// "name":"stack",
// "vjust":0.3
// },
// "geom":"label",
// "data":{
// }
// }],
// "theme":{
// "axis_ticks":{
// "blank":true
// },
// "axis_line_x":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// },{
// "type":"str",
// "column":"grp"
// }]
// },
// "spec_id":"3"
// },{
// "ggtitle":{
// "text":"vjust = 0.5"
// },
// "mapping":{
// "x":"x",
// "y":"y",
// "group":"grp"
// },
// "data":{
// "grp":["a","b","a","b","c"],
// "x":[1.0,1.0,2.0,2.0,2.0],
// "y":[1.0,3.0,2.0,1.0,-3.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Pastel1"
// }],
// "layers":[{
// "mapping":{
// "fill":"grp"
// },
// "stat":"identity",
// "color":"pen",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "yintercept":0.0,
// "color":"pen",
// "size":0.5,
// "position":"identity",
// "geom":"hline",
// "data":{
// }
// },{
// "mapping":{
// "label":"y"
// },
// "stat":"identity",
// "position":{
// "name":"stack",
// "vjust":0.5
// },
// "geom":"label",
// "data":{
// }
// }],
// "theme":{
// "axis_ticks":{
// "blank":true
// },
// "axis_line_x":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// },{
// "type":"str",
// "column":"grp"
// }]
// },
// "spec_id":"4"
// },{
// "ggtitle":{
// "text":"vjust = 0.7"
// },
// "mapping":{
// "x":"x",
// "y":"y",
// "group":"grp"
// },
// "data":{
// "grp":["a","b","a","b","c"],
// "x":[1.0,1.0,2.0,2.0,2.0],
// "y":[1.0,3.0,2.0,1.0,-3.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Pastel1"
// }],
// "layers":[{
// "mapping":{
// "fill":"grp"
// },
// "stat":"identity",
// "color":"pen",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "yintercept":0.0,
// "color":"pen",
// "size":0.5,
// "position":"identity",
// "geom":"hline",
// "data":{
// }
// },{
// "mapping":{
// "label":"y"
// },
// "stat":"identity",
// "position":{
// "name":"stack",
// "vjust":0.7
// },
// "geom":"label",
// "data":{
// }
// }],
// "theme":{
// "axis_ticks":{
// "blank":true
// },
// "axis_line_x":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// },{
// "type":"str",
// "column":"grp"
// }]
// },
// "spec_id":"5"
// },{
// "ggtitle":{
// "text":"vjust = 1.0"
// },
// "mapping":{
// "x":"x",
// "y":"y",
// "group":"grp"
// },
// "data":{
// "grp":["a","b","a","b","c"],
// "x":[1.0,1.0,2.0,2.0,2.0],
// "y":[1.0,3.0,2.0,1.0,-3.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Pastel1"
// }],
// "layers":[{
// "mapping":{
// "fill":"grp"
// },
// "stat":"identity",
// "color":"pen",
// "position":"stack",
// "geom":"bar",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "yintercept":0.0,
// "color":"pen",
// "size":0.5,
// "position":"identity",
// "geom":"hline",
// "data":{
// }
// },{
// "mapping":{
// "label":"y"
// },
// "stat":"identity",
// "position":{
// "name":"stack",
// "vjust":1.0
// },
// "geom":"label",
// "data":{
// }
// }],
// "theme":{
// "axis_ticks":{
// "blank":true
// },
// "axis_line_x":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// },{
// "type":"str",
// "column":"grp"
// }]
// },
// "spec_id":"6"
// }],
// "ggsize":{
// "width":1200.0,
// "height":1200.0
// },
// "kind":"subplots"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=5f1a8318-349b-4a53-b661-0dd1fb99cb76 width="100%" height="100%" style="max-width: 1200.0px; max-height: 1200.0px;" viewBox="0 0 1200.0 1200.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #psvYP3i .plot-title {
// fill:

// %%
// position = "fill"

letsPlot(data) { x = "x"; y = "y"; group = "grp" } + 
    geomBar(stat = Stat.identity, position = positionFill(), color = "pen") { fill = "grp" }  + 
    scaleFillBrewer(palette = "Pastel1") +
    geomText(position = positionFill(0.5)) { label = "y" } +
    theme(axisLineX = elementBlank(), axisTicks = elementBlank()) + 
    geomHLine(yintercept = 0, color = "pen", size = 0.5)
// Out:
//    <div id="1tLXDs"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: "MIN",
//        height_mode: "SCALED",
//        width: null,
//        height: null
//    };
//
//    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
//    if (preferredWidth !== undefined) {
//        sizing = {
//            width_mode: 'FIXED',
//            height_mode: 'SCALED',
//            width: parseFloat(preferredWidth)
//        };
//    }
//
//    const containerDiv = document.getElementById("1tLXDs");
//    let fig = null;
//
//    function renderPlot() {
//        if (fig === null) {
//            const plotSpec = {
// "mapping":{
// "x":"x",
// "y":"y",
// "group":"grp"
// },
// "data":{
// "grp":["a","b","a","b","c"],
// "x":[1.0,1.0,2.0,2.0,2.0],
// "y":[1.0,3.0,2.0,1.0,-3.0]
// },
// "kind":"plot",
// "scales":[{
// "aesthetic":"fill",
// "scale_mapper_kind":"color_brewer",
// "palette":"Pastel1"
// }],
// "layers":[{
// "mapping":{
// "fill":"grp"
// },
// "stat":"identity",
// "color":"pen",
// "position":"fill",
// "geom":"bar",
// "data":{
// }
// },{
// "mapping":{
// "label":"y"
// },
// "stat":"identity",
// "position":{
// "name":"fill",
// "vjust":0.5
// },
// "geom":"text",
// "data":{
// }
// },{
// "mapping":{
// },
// "stat":"identity",
// "yintercept":0.0,
// "color":"pen",
// "size":0.5,
// "position":"identity",
// "geom":"hline",
// "data":{
// }
// }],
// "theme":{
// "axis_ticks":{
// "blank":true
// },
// "axis_line_x":{
// "blank":true
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// },{
// "type":"str",
// "column":"grp"
// }]
// },
// "spec_id":"13"
// };
//            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
//        } else {
//            fig.updateView({});
//        }
//    }
//
//    const renderImmediately =
//        forceImmediateRender || (
//            sizing.width_mode === 'FIXED' &&
//            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
//        );
//
//    if (renderImmediately) {
//        renderPlot();
//    }
//
//    if (!renderImmediately || responsive) {
//        // Set up observer for initial sizing or continuous monitoring
//        var observer = new ResizeObserver(function(entries) {
//            for (let entry of entries) {
//                if (entry.contentBoxSize &&
//                    entry.contentBoxSize[0].inlineSize > 0) {
//                    if (!responsive && observer) {
//                        observer.disconnect();
//                        observer = null;
//                    }
//                    renderPlot();
//                    if (!responsive) {
//                        break;
//                    }
//                }
//            }
//        });
//
//        observer.observe(containerDiv);
//    }
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=48e72986-eb08-4519-a565-f233095c899c width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pq6FBKu .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pq6FBKu .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pq6FBKu .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pq6FBKu .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pq6FBKu .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pq6FBKu .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pq6FBKu .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pq6FBKu .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dDqjDb9 .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pq6FBKu .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pq6FBKu .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dDqjDb9 .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pq6FBKu .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pq6FBKu .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dDqjDb9 .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dDqjDb9 .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dDqjDb9 .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pq6FBKu">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M0.0 0.0 L0.0 400.0 L600.0 400.0 L600.0 0.0 Z">
//     </path>
//     <g transform="translate(29.5 6.5 ) ">
//       <g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="10.141862720502914" y1="0.0" x2="10.141862720502914" y2="345.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="122.82922628164641" y1="0.0" x2="122.82922628164641" y2="345.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="235.5165898427899" y1="0.0" x2="235.5165898427899" y2="345.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="348.2039534039334" y1="0.0" x2="348.2039534039334" y2="345.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="460.89131696507695" y1="0.0" x2="460.89131696507695" y2="345.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="329.3181818181818" x2="471.0331796855799" y2="329.3181818181818" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="250.9090909090909" x2="471.0331796855799" y2="250.9090909090909" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="172.5" x2="471.0331796855799" y2="172.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="94.0909090909091" x2="471.0331796855799" y2="94.0909090909091" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="15.681818181818187" x2="471.0331796855799" y2="15.681818181818187" stroke="rgb(233,233,233)" stroke-opacity="1.0" strok
