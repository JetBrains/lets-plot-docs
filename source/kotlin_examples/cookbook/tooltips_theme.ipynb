// %%
%useLatestDescriptors
%use lets-plot
// Out:
//    <div id="eb0tBj"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.2/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("eb0tBj").appendChild(div);
//            };
//            var e = document.getElementById("eb0tBj");
//            e.appendChild(script);
//        })();
//    </script>
//             <div id="kotlin_out_0"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["letsPlotJs"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["letsPlotJs"] = resQueue;
//                 window["call_letsPlotJs"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.2/js-package/distr/lets-plot.min.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_letsPlotJs"] = function(f) {f();};
//                         window.kotlinQueues["letsPlotJs"].forEach(function(f) {f();});
//                         window.kotlinQueues["letsPlotJs"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_letsPlotJs"] = function(f) {};
//                         window.kotlinQueues["letsPlotJs"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource letsPlotJs';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>

// %%
val dat = mapOf("x" to 0..1, "y" to 0..1)
val p = letsPlot(dat) +
        geomTile(fill = "light-gray", tooltips = layerTooltips().title("Tooltip title").line("label|value")) {
            x = "x"
            y = "y"
        }
p
// Out:
//    <div id="dfkHbh"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.2/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("dfkHbh").appendChild(div);
//            };
//            var e = document.getElementById("dfkHbh");
//            e.appendChild(script);
//        })();
//    </script>
//    <div id="Ta4SnY"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("Ta4SnY");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// },
// "data":{
// "x":[0.0,1.0],
// "y":[0.0,1.0]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "stat":"identity",
// "position":"identity",
// "geom":"tile",
// "fill":"light-gray",
// "tooltips":{
// "title":"Tooltip title",
// "lines":["label|value"]
// },
// "data":{
// }
// }],
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// }]
// },
// "spec_id":"1"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=1c01a471-66ce-40c3-a84d-7a9af9a0e148 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #ptiuWkh .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #ptiuWkh .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #ptiuWkh .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #ptiuWkh .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #ptiuWkh .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #ptiuWkh .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #ptiuWkh .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #ptiuWkh .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dUd9auk .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #ptiuWkh .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #ptiuWkh .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dUd9auk .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #ptiuWkh .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #ptiuWkh .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dUd9auk .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dUd9auk .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dUd9auk .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="ptiuWkh">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M93.99234666212519 0.0 L93.99234666212519 400.0 L506.0076533378748 400.0 L506.0076533378748 0.0 Z">
//     </path>
//     <g transform="translate(123.49234666212519 6.5 ) ">
//       <g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="15.5" y1="0.0" x2="15.5" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="93.0" y1="0.0" x2="93.0" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="170.5" y1="0.0" x2="170.5" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="248.0" y1="0.0" x2="248.0" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="325.5" y1="0.0" x2="325.5" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="325.5" x2="341.0" y2="325.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="248.0" x2="341.0" y2="248.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="170.5" x2="341.0" y2="170.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="93.0" x2="341.0" y2="93.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="15.5" x2="341.0" y2="15.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cigUox4)" clip-bounds-jfx="[rect (35.01530667574961, 0.0), (341.0, 341.0)]">
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <g>
//               <g>
//                 <g >
//                   <rect fill="#c0c0c0" stroke="#ffffff" stroke-width="0.0" x="15.5" y="170.5" height="155.0" width="155.0" />
//                   <rect fill="#c0c0c0" stroke="#ffffff" stroke-width="0.0" x="170.5" y="15.5" height="155.0" width="155.0" />
//                 </g>
//               </g>
//             </g>
//           </g>
//         </g>
//         <defs>
//           <clipPath id="cigUox4">
//             <rect x="35.01530667574961" y="0.0" width="341.0" height="341.0">
//             </rect>
//           </clipPath>
//         </defs>
//       </g>
//       <g>
//         <g transform="translate(35.01530667574961 341.0 ) ">
//           <g transform="translate(15.5 0.0 ) ">
//             <line stroke-width="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" x2="0.0" y2="4.0">
//             </line>
//             <g transform="translate(0.0 7.0 ) ">
//               <text class="axis-text-x" text-anchor="middle" dy="0.7em">
//                 <tspan

// %% [markdown]
// ### Tooltip properties in theme:
//
// - `tooltip` - tooltip rectangle;
// - `tooltipText` - text in general tooltip;
// - `tooltipTitleText` - tooltip title text;
// - `axisTooltipText[X|Y]` - axis tooltip text (inherits from 'tooltipText')

// %%
p + theme(
    tooltip = elementRect(color = "#225e32", fill = "#238b45", size = 2),
    tooltipText = elementText(color = "#bae4b3"),
    tooltipTitleText = elementText(color = "#edf8e9"),
    axisTooltipTextX = elementText(color = "green")
)
// Out:
//    <div id="xxHshj"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("xxHshj");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "mapping":{
// },
// "data":{
// "x":[0.0,1.0],
// "y":[0.0,1.0]
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// "x":"x",
// "y":"y"
// },
// "stat":"identity",
// "position":"identity",
// "geom":"tile",
// "fill":"light-gray",
// "tooltips":{
// "title":"Tooltip title",
// "lines":["label|value"]
// },
// "data":{
// }
// }],
// "theme":{
// "tooltip":{
// "fill":"#238b45",
// "color":"#225e32",
// "size":2.0,
// "blank":false
// },
// "tooltip_title_text":{
// "color":"#edf8e9",
// "blank":false
// },
// "tooltip_text":{
// "color":"#bae4b3",
// "blank":false
// },
// "axis_tooltip_text_x":{
// "color":"green",
// "blank":false
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// },{
// "type":"int",
// "column":"y"
// }]
// },
// "spec_id":"3"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=ba6ba196-b5d9-46bb-bb75-0e8df5287411 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pNkDSsN .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pNkDSsN .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pNkDSsN .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pNkDSsN .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pNkDSsN .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pNkDSsN .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pNkDSsN .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pNkDSsN .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #da58W79 .axis-tooltip-text-x {
// fill: #00ff00;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pNkDSsN .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pNkDSsN .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #da58W79 .axis-tooltip-text-y {
// fill: #bae4b3;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pNkDSsN .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pNkDSsN .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #da58W79 .tooltip-text {
// fill: #bae4b3;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #da58W79 .tooltip-title {
// fill: #edf8e9;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #da58W79 .tooltip-label {
// fill: #bae4b3;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pNkDSsN">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M93.99234666212519 0.0 L93.99234666212519 400.0 L506.0076533378748 400.0 L506.0076533378748 0.0 Z">
//     </path>
//     <g transform="translate(123.49234666212519 6.5 ) ">
//       <g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="15.5" y1="0.0" x2="15.5" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="93.0" y1="0.0" x2="93.0" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="170.5" y1="0.0" x2="170.5" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="248.0" y1="0.0" x2="248.0" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="325.5" y1="0.0" x2="325.5" y2="341.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="325.5" x2="341.0" y2="325.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="248.0" x2="341.0" y2="248.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="170.5" x2="341.0" y2="170.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="93.0" x2="341.0" y2="93.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="0.0" y1="15.5" x2="341.0" y2="15.5" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//       </g>
//       <g clip-path="url(#cIoALpm)" clip-bounds-jfx="[rect (35.01530667574961, 0.0), (341.0, 341.0)]">
//         <g transform="translate(35.01530667574961 0.0 ) ">
//           <g>
//             <g>
//               <g>
//                 <g >
//                   <rect fill="#c0c0c0" stroke="#ffffff" stroke-width="0.0" x="15.5" y="170.5" height="155.0" width="155.0" />
//                   <rect fill="#c0c0c0" stroke="#ffffff" stroke-width="0.0" x="170.5" y="15.5" height="155.0" width="155.0" />
//                 </g>
//               </g>
//             </g>
//           </g>
//         </g>
//         <defs>
//           <clipPath id="cIoALpm">
//             <rect x="35.01530667574961" y="0.0" width="341.0" height="341.0">
//             </rect>
//           </clipPath>
//         </defs>
//       </g>
//       <g>
//         <g transform="translate(35.01530667574961 341.0 ) ">
//           <g transform="translate(15.5 0.0 ) ">
