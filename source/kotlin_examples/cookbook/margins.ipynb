// %% [markdown]
// # Margins
//
//
// The margins around the plot and text elements are controlled by the `plotMargin` parameter in `theme()` and the `margin` parameter in `elementText()` respectively.
//
// Now the parameters `plotMargin` and `margin` accept a number or a list of numbers.
//
// - A number or list of one number is specified: the same margin it applied to **all four sides**.
// - A list of two numbers: the first margin applies to the **top and bottom**, the second - to the **left and right**.
// - A list of three numbers: the first margin applies to the **top**, the second - to the **right and left**, the third - to the **bottom**.
// - A list of four numbers: the margins are applied to the **top, right, bottom and left** in that order.
//
// It is acceptable to use `null` for any side; in this case, the default side value for this element will be used.

// %%
%useLatestDescriptors
%use lets-plot
// Out:
//    <div id="pW29jw"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.2/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("pW29jw").appendChild(div);
//            };
//            var e = document.getElementById("pW29jw");
//            e.appendChild(script);
//        })();
//    </script>
//             <div id="kotlin_out_0"></div>
//             <script type="text/javascript">
//                             if(!window.kotlinQueues) {
//                 window.kotlinQueues = {};
//             }
//             if(!window.kotlinQueues["letsPlotJs"]) {
//                 var resQueue = [];
//                 window.kotlinQueues["letsPlotJs"] = resQueue;
//                 window["call_letsPlotJs"] = function(f) {
//                     resQueue.push(f);
//                 }
//             }
//             (function (){
//                 var modifiers = [(function(script) {
//     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.2/js-package/distr/lets-plot.min.js"
//     script.type = "text/javascript";
// })];
//                 var e = document.getElementById("kotlin_out_0");
//                 modifiers.forEach(function (gen) {
//                     var script = document.createElement("script");
//                     gen(script)
//                     script.addEventListener("load", function() {
//                         window["call_letsPlotJs"] = function(f) {f();};
//                         window.kotlinQueues["letsPlotJs"].forEach(function(f) {f();});
//                         window.kotlinQueues["letsPlotJs"] = [];
//                     }, false);
//                     script.addEventListener("error", function() {
//                         window["call_letsPlotJs"] = function(f) {};
//                         window.kotlinQueues["letsPlotJs"] = [];
//                         var div = document.createElement("div");
//                         div.style.color = 'darkred';
//                         div.textContent = 'Error loading resource letsPlotJs';
//                         document.getElementById("kotlin_out_0").appendChild(div);
//                     }, false);
//
//                     e.appendChild(script);
//                 });
//             })();
//             </script>

// %%
LetsPlot.getInfo()
// Out:
// Lets-Plot Kotlin API v.4.9.3. Frontend: Notebook with dynamically loaded JS. Lets-Plot JS v.4.5.2.

// %%
import kotlin.random.Random

val rand = Random(37)
val barData = mapOf(
    "x" to List(100) { rand.nextInt(10)}
)

val p = letsPlot(barData) {x = "x"} + 
    geomBar() + 
    ggtitle("Barchart") +
    themeLight() + 
    theme(plotBackground = elementRect(size = 4))

// %% [markdown]
// #### Plot without Margins

// %%
p
// Out:
//    <div id="z3jKyU"></div>
//    <script type="text/javascript" data-lets-plot-script="library">
//        if(!window.letsPlotCallQueue) {
//            window.letsPlotCallQueue = [];
//        };
//        window.letsPlotCall = function(f) {
//            window.letsPlotCallQueue.push(f);
//        };
//        (function() {
//            var script = document.createElement("script");
//            script.type = "text/javascript";
//            script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.2/js-package/distr/lets-plot.min.js";
//            script.onload = function() {
//                window.letsPlotCall = function(f) {f();};
//                window.letsPlotCallQueue.forEach(function(f) {f();});
//                window.letsPlotCallQueue = [];
//
//
//            };
//            script.onerror = function(event) {
//                window.letsPlotCall = function(f) {};
//                window.letsPlotCallQueue = [];
//                var div = document.createElement("div");
//                div.style.color = 'darkred';
//                div.textContent = 'Error loading Lets-Plot JS';
//                document.getElementById("z3jKyU").appendChild(div);
//            };
//            var e = document.getElementById("z3jKyU");
//            e.appendChild(script);
//        })();
//    </script>
//    <div id="fsILsm"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("fsILsm");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "ggtitle":{
// "text":"Barchart"
// },
// "mapping":{
// "x":"x"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data":{
// "..count..":[15.0,15.0,8.0,11.0,6.0,9.0,9.0,9.0,10.0,8.0],
// "x":[8.0,4.0,9.0,7.0,3.0,2.0,6.0,5.0,1.0,0.0]
// }
// }],
// "theme":{
// "name":"light",
// "plot_background":{
// "size":4.0,
// "blank":false
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// }]
// },
// "spec_id":"1"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=65702da7-ee8f-41e4-9de6-f07cc7ac6e22 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #p937Hva .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #p937Hva .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #p937Hva .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #p937Hva .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #p937Hva .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #p937Hva .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #p937Hva .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #p937Hva .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dpbrKsO .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #p937Hva .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #p937Hva .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dpbrKsO .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #p937Hva .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #p937Hva .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dpbrKsO .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dpbrKsO .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dpbrKsO .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="p937Hva">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M2.0 2.0 L2.0 398.0 L598.0 398.0 L598.0 2.0 Z">
//     </path>
//     <g transform="translate(29.5 26.5 ) ">
//       <g>
//         <rect x="25.961210910936405" y="0.0" height="321.0" width="538.0387890890636" fill="rgb(255,255,255)" fill-opacity="1.0">
//         </rect>
//         <g transform="translate(25.961210910936405 0.0 ) ">
//           <g>
//             <line x1="21.985974393446583" y1="0.0" x2="21.985974393446583" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="71.39265842366363" y1="0.0" x2="71.39265842366363" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="120.79934245388068" y1="0.0" x2="120.79934245388068" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="170.20602648409772" y1="0.0" x2="170.20602648409772" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="219.61271051431478" y1="0.0" x2="219.61271051431478" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="269.01939454453185" y1="0.0" x2="269.01939454453185" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="318.4260785747489" y1="0.0" x2="318.4260785747489" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="367.8327626049659" y1="0.0" x2="367.8327626049659" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="417.23944663518296" y1="0.0" x2="417.23944663518296" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="466.64613066540005" y1="0.0" x2="466.64613066540005" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="516.0528146956171" y1="0.0" x2="516.0528146956171" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="46.68931640855511" y1="0.0" x2="46.68931640855511" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="96.09600043877217" y1="0.0" x2="96.09600043877217" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="145.5026844689892" y1="0.0" x2="145.5026844689892" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="194.90936849920627" y1="0.0" x2="194.90936849920627" y2="321.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill=

// %% [markdown]
// #### Margins Around the Plot

// %%
gggrid(
    listOf(
        p + theme(plotMargin = 40) + ggtitle("plotMargin=40 (all sides)"),
        p + theme(plotMargin = listOf(40, 20)) + 
            ggtitle("plotMargin=[40,20]\n(top/bottom, left/right)"),
        p + theme(plotMargin = listOf(40, 20, 10)) + 
            ggtitle("plotMargin=[40,20,10]\n(top, left/right, bottom)"),
        p + theme(plotMargin = listOf(40, 10, 10, 20)) + 
            ggtitle("plotMargin=[40,10,10,20]\n(top, right, bottom, left)")
    ),
    ncol=2
)
// Out:
//    <div id="NzHvR4"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("NzHvR4");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "layout":{
// "name":"grid",
// "ncol":2,
// "nrow":2,
// "fit":true,
// "align":false
// },
// "figures":[{
// "ggtitle":{
// "text":"plotMargin=40 (all sides)"
// },
// "mapping":{
// "x":"x"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data":{
// "..count..":[15.0,15.0,8.0,11.0,6.0,9.0,9.0,9.0,10.0,8.0],
// "x":[8.0,4.0,9.0,7.0,3.0,2.0,6.0,5.0,1.0,0.0]
// }
// }],
// "theme":{
// "name":"light",
// "plot_background":{
// "size":4.0,
// "blank":false
// },
// "plot_margin":40.0
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// }]
// },
// "spec_id":"3"
// },{
// "ggtitle":{
// "text":"plotMargin=[40,20]\n(top/bottom, left/right)"
// },
// "mapping":{
// "x":"x"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data":{
// "..count..":[15.0,15.0,8.0,11.0,6.0,9.0,9.0,9.0,10.0,8.0],
// "x":[8.0,4.0,9.0,7.0,3.0,2.0,6.0,5.0,1.0,0.0]
// }
// }],
// "theme":{
// "name":"light",
// "plot_background":{
// "size":4.0,
// "blank":false
// },
// "plot_margin":[40.0,20.0]
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// }]
// },
// "spec_id":"4"
// },{
// "ggtitle":{
// "text":"plotMargin=[40,20,10]\n(top, left/right, bottom)"
// },
// "mapping":{
// "x":"x"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data":{
// "..count..":[15.0,15.0,8.0,11.0,6.0,9.0,9.0,9.0,10.0,8.0],
// "x":[8.0,4.0,9.0,7.0,3.0,2.0,6.0,5.0,1.0,0.0]
// }
// }],
// "theme":{
// "name":"light",
// "plot_background":{
// "size":4.0,
// "blank":false
// },
// "plot_margin":[40.0,20.0,10.0]
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// }]
// },
// "spec_id":"5"
// },{
// "ggtitle":{
// "text":"plotMargin=[40,10,10,20]\n(top, right, bottom, left)"
// },
// "mapping":{
// "x":"x"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data":{
// "..count..":[15.0,15.0,8.0,11.0,6.0,9.0,9.0,9.0,10.0,8.0],
// "x":[8.0,4.0,9.0,7.0,3.0,2.0,6.0,5.0,1.0,0.0]
// }
// }],
// "theme":{
// "name":"light",
// "plot_background":{
// "size":4.0,
// "blank":false
// },
// "plot_margin":[40.0,10.0,10.0,20.0]
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// }]
// },
// "spec_id":"6"
// }],
// "kind":"subplots"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=6bdbaad2-c070-477b-8e60-d1f1ef66fa0f width="100%" height="100%" style="max-width: 900.0px; max-height: 600.0px;" viewBox="0 0 900.0 600.0" preserveAspectRatio="xMinYMin meet">
//   <g id="pV0Ynsl">
//     <rect x="0.0" y="0.0" height="600.0" width="900.0" fill="rgb(255,255,255)" fill-opacity="1.0" stroke="rgb(71,71,71)" stroke-opacity="1.0" stroke-width="0.0">
//     </rect>
//   </g>
//   <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" width="448.0" height="298.0" x="0.0" y="0.0">
//     <style type="text/css">
//     .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pMaIBfc .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pMaIBfc .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pMaIBfc .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pMaIBfc .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pMaIBfc .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pMaIBfc .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pMaIBfc .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pMaIBfc .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dHAVMH1 .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pMaIBfc .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pMaIBfc .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dHAVMH1 .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pMaIBfc .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pMaIBfc .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dHAVMH1 .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dHAVMH1 .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dHAVMH1 .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//     </style>
//     <g id="pMaIBfc">
//       <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M2.0 2.0 L2.0 296.0 L446.0 296.0 L446.0 2.0 Z">
//       </path>
//       <g transform="translate(69.5 66.5 ) ">
//         <g>
//           <rect x="25.961210910936405" y="0.0" height="139.0" width="306.0387890890636" fill="rgb(255,255,255)" fill-opacity="1.0">
//           </rect>
//           <g transform="translate(25.961210910936405 0.0 ) ">
//             <g>
//               <line x1="54.65982045713763" y1="0.0" x2="54.65982045713763" y2="139.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//               </line>
//               <line x1="110.86529136422001" y1="0.0" x2="110.86529136422001" y2="139.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//               </line>
//               <line x1="167.0707622713024" y1="0.0" x2="167.0707622713024" y2="139.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//               </line>
//               <line x1="223.276233178

// %% [markdown]
// #### Margins Around the Text Element

// %%
p + theme(plotTitle = elementText(margin=40),
          axisTitle = elementText(margin=listOf(20, 20))) +
    ggtitle("plotTitle=40 -> top/bottom=40,\n" +
            "axisTitle=[20,20] -> top/right=20")
// Out:
//    <div id="QfSqYR"></div>
//    <script type="text/javascript" data-lets-plot-script="plot">
//
//    (function() {
//    // ----------
//
//    var containerDiv = document.getElementById("QfSqYR");
//    var observer = new ResizeObserver(function(entries) {
//        for (let entry of entries) {
//            var width = containerDiv.clientWidth
//            if (entry.contentBoxSize && width > 0) {
//
//                // Render plot
//                if (observer) {
//                    observer.disconnect();
//                    observer = null;
//                }
//
//                var plotSpec={
// "ggtitle":{
// "text":"plotTitle=40 -> top/bottom=40,\naxisTitle=[20,20] -> top/right=20"
// },
// "mapping":{
// "x":"x"
// },
// "data":{
// },
// "kind":"plot",
// "scales":[],
// "layers":[{
// "mapping":{
// },
// "stat":"count",
// "position":"stack",
// "geom":"bar",
// "data":{
// "..count..":[15.0,15.0,8.0,11.0,6.0,9.0,9.0,9.0,10.0,8.0],
// "x":[8.0,4.0,9.0,7.0,3.0,2.0,6.0,5.0,1.0,0.0]
// }
// }],
// "theme":{
// "name":"light",
// "plot_background":{
// "size":4.0,
// "blank":false
// },
// "plot_title":{
// "margin":40.0,
// "blank":false
// },
// "axis_title":{
// "margin":[20.0,20.0],
// "blank":false
// }
// },
// "data_meta":{
// "series_annotations":[{
// "type":"int",
// "column":"x"
// }]
// },
// "spec_id":"11"
// };
//                window.letsPlotCall(function() {
//
//                var toolbar = null;
//                var plotContainer = containerDiv;
//
//                    var options = {
//                        sizing: {
//                            width_mode: "min",
//                            height_mode: "scaled",
//                            width: width
//                        }
//                    };
//                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
//                    if (toolbar) {
//                      toolbar.bind(fig);
//                    }
//                });
//
//                break;
//            }
//        }
//    });
//
//    observer.observe(containerDiv);
//
//    // ----------
//    })();
//
//    </script>                <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" display="block" class="plt-container" id=22d3b98d-aab8-4d74-8b04-424da37660e2 width="100%" height="100%" style="max-width: 600.0px; max-height: 400.0px;" viewBox="0 0 600.0 400.0" preserveAspectRatio="xMinYMin meet">
//   <style type="text/css">
//   .plt-container {
//    font-family: Lucida Grande, sans-serif;
//    user-select: none;
//    -webkit-user-select: none;
//    -moz-user-select: none;
//    -ms-user-select: none;
// }
// text {
//    text-rendering: optimizeLegibility;
// }
// #pKupbO9 .plot-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 16.0px;
//
// }
// #pKupbO9 .plot-subtitle {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pKupbO9 .plot-caption {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pKupbO9 .hyperlink-element {
// fill: #118ed8;
// font-weight: normal;
//    font-style: normal;
// }
// #pKupbO9 .legend-title {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pKupbO9 .legend-item {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pKupbO9 .axis-title-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pKupbO9 .axis-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dmou822 .axis-tooltip-text-x {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pKupbO9 .axis-title-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 15.0px;
//
// }
// #pKupbO9 .axis-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dmou822 .axis-tooltip-text-y {
// fill: #ffffff;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pKupbO9 .facet-strip-text-x {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #pKupbO9 .facet-strip-text-y {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dmou822 .tooltip-text {
// fill: #474747;
// font-weight: normal;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dmou822 .tooltip-title {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
// #dmou822 .tooltip-label {
// fill: #474747;
// font-weight: bold;
//    font-style: normal;font-family: Lucida Grande, sans-serif;
// font-size: 13.0px;
//
// }
//
//   </style>
//   <g id="pKupbO9">
//     <path fill-rule="evenodd" fill="rgb(255,255,255)" fill-opacity="1.0" d="M2.0 2.0 L2.0 398.0 L598.0 398.0 L598.0 2.0 Z">
//     </path>
//     <g transform="translate(61.5 118.5 ) ">
//       <g>
//         <rect x="25.961210910936405" y="0.0" height="197.0" width="506.0387890890636" fill="rgb(255,255,255)" fill-opacity="1.0">
//         </rect>
//         <g transform="translate(25.961210910936405 0.0 ) ">
//           <g>
//             <line x1="90.38066526889153" y1="0.0" x2="90.38066526889153" y2="197.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="183.31708199782884" y1="0.0" x2="183.31708199782884" y2="197.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="276.2534987267661" y1="0.0" x2="276.2534987267661" y2="197.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="369.18991545570344" y1="0.0" x2="369.18991545570344" y2="197.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="462.1263321846407" y1="0.0" x2="462.1263321846407" y2="197.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="43.912456904422875" y1="0.0" x2="43.912456904422875" y2="197.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="136.84887363336017" y1="0.0" x2="136.84887363336017" y2="197.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="229.78529036229747" y1="0.0" x2="229.78529036229747" y2="197.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="322.7217070912348" y1="0.0" x2="322.7217070912348" y2="197.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//             <line x1="415.6581238201721" y1="0.0" x2="415.6581238201721" y2="197.0" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="1.0" fill="none">
//             </line>
//           </g>
//         </g>
//         <g transform="translate(25.961210910936405 0.0 ) ">
//           <g>
//             <line x1="0.0" y1="165.73015873015873" x2="506.0387890890636" y2="165.73015873015873" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="0.0" y1="103.19047619047619" x2="506.0387890890636" y2="103.19047619047619" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="0.0" y1="40.650793650793645" x2="506.0387890890636" y2="40.650793650793645" stroke="rgb(233,233,233)" stroke-opacity="1.0" stroke-width="0.5" fill="none">
//             </line>
//             <line x1="0.0" y1="134.46031
